# %%
# 导入工具包
from PIL import Image
import numpy as np
import torchvision
from torch.utils.data import DataLoader
import torch

# %%
train_data = torchvision.datasets.MNIST(
    root = './mnist',
    # train = True 为 训练集，6w张照片；train = False 为 测试集，1w张照片
    train = True,
    download=True
    # download 在第一次加载数据集时需要指定为 True，后面就不需要了，即从./mnist 目录中加载
    # download = True
) # 通过此句，现 6W 中张照片均在 train_data 中，每一张照片都是 28 * 28 大小

# 构建可迭代的数据装载器，这里我们设置的 batch_size = 1，即一次循环，读取一张图片
train_loader = DataLoader(dataset=train_data, batch_size=1, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 192080865.44it/s]
# Extracting ./mnist/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 49222142.96it/s]
# Extracting ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 44728310.68it/s]
# Extracting ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1739297.80it/s]
# Extracting ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw

# %%
def img_show(img):
    pil = Image.fromarray(np.uint(img))
    pil.show()

# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
# 分批次训练，一批 64 个
BATCH_SIZE = 64
# 所有样本训练 3 次
EPOCHS = 3
# 学习率设置为 0.0006
LEARN_RATE = 6e-4

# 若当前 Pytorch 版本以及电脑支持GPU，则使用 GPU 训练，否则使用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# 训练集数据加载
train_data = torchvision.datasets.MNIST(
    root='./mnist',
    train=True,
    transform=torchvision.transforms.ToTensor()
)
# 构建训练集的数据装载器，一次迭代有 BATCH_SIZE 张图片
train_loader = DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)

# 测试集数据加载
test_data = torchvision.datasets.MNIST(
    root='./mnist',
    train=False,
    transform=torchvision.transforms.ToTensor()
)
# 构建测试集的数据加载器，一次迭代 1 张图片，我们一张一张的测试
test_loader = DataLoader(dataset=test_data, batch_size=1, shuffle = True)

# %%
"""
此处我们定义了一个 3 层的网络
隐藏层 1：40 个神经元
隐藏层 2：20 个神经元
输出层：10 个神经元
"""
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        # 隐藏层 1，使用 sigmoid 激活函数
        self.layer1 = nn.Sequential(
            nn.Linear(784, 40),
            nn.Sigmoid()
        )
        # 隐藏层 2，使用 sigmoid 激活函数
        self.layer2 = nn.Sequential(
            nn.Linear(40, 20),
            nn.Sigmoid()
        )
        # 输出层
        self.layer_out = nn.Linear(20, 10)

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        self.out = self.layer_out(x)
        return self.out

# %%
# 实例化DNN，并将模型放在 GPU 训练
model = DNN().to(device)
# 同样，将损失函数放在 GPU
loss_fn = nn.MSELoss(reduction='mean').to(device)
#大数据常用Adam优化器，参数需要model的参数，以及学习率
optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE)

# %%
for epoch in range(EPOCHS):
    # 加载训练数据
    for step, data in enumerate(train_loader):
        x, y = data
        """
        因为此时的训练集即 x 大小为 （BATCH_SIZE, 1, 28, 28）
        因此这里需要一个形状转换为（BATCH_SIZE, 784）;
        y 中代表的是每张照片对应的数字，而我们输出的是 10 个神经元，
        即代表每个数字的概率
        因此这里将 y 也转换为该数字对应的 one-hot形式来表示
        """
        x = x.view(x.size(0), 784)
        yy = np.zeros((x.size(0), 10))
        for j in range(x.size(0)):
            yy[j][y[j].item()] = 1
        yy = torch.from_numpy(yy)
        yy = yy.float()
        x, yy = x.to(device), yy.to(device)

        # 调用模型预测
        output = model(x).to(device)
        # 计算损失值
        loss = loss_fn(output, yy)
        # 输出看一下损失变化
        print(f'EPOCH({epoch})   loss = {loss.item()}')
        # 每一次循环之前，将梯度清零
        optimizer.zero_grad()
        # 反向传播
        loss.backward()
        # 梯度下降，更新参数
        optimizer.step()
# Out:
# EPOCH(0)   loss = 0.2225799262523651
# EPOCH(0)   loss = 0.20510371029376984
# EPOCH(0)   loss = 0.1990753710269928
# EPOCH(0)   loss = 0.20555846393108368
# EPOCH(0)   loss = 0.19732172787189484
# EPOCH(0)   loss = 0.18653002381324768
# EPOCH(0)   loss = 0.17645931243896484
# EPOCH(0)   loss = 0.1719667613506317
# EPOCH(0)   loss = 0.17414575815200806
# EPOCH(0)   loss = 0.17915859818458557
# EPOCH(0)   loss = 0.17049366235733032
# EPOCH(0)   loss = 0.16227462887763977
# EPOCH(0)   loss = 0.16656319797039032
# EPOCH(0)   loss = 0.15101471543312073
# EPOCH(0)   loss = 0.14999613165855408
# EPOCH(0)   loss = 0.14728406071662903
# EPOCH(0)   loss = 0.14207802712917328
# EPOCH(0)   loss = 0.1471279412508011
# EPOCH(0)   loss = 0.14282070100307465
# EPOCH(0)   loss = 0.1293415129184723
# EPOCH(0)   loss = 0.12704333662986755
# EPOCH(0)   loss = 0.12669816613197327
# EPOCH(0)   loss = 0.13012880086898804
# EPOCH(0)   loss = 0.1286575049161911
# EPOCH(0)   loss = 0.12279461324214935
# EPOCH(0)   loss = 0.12215769290924072
# EPOCH(0)   loss = 0.12467513233423233
# EPOCH(0)   loss = 0.12069026380777359
# EPOCH(0)   loss = 0.11696221679449081
# EPOCH(0)   loss = 0.11388393491506577
# EPOCH(0)   loss = 0.11647766828536987
# EPOCH(0)   loss = 0.10885103046894073
# EPOCH(0)   loss = 0.10764546692371368
# EPOCH(0)   loss = 0.10684166848659515
# EPOCH(0)   loss = 0.10549058020114899
# EPOCH(0)   loss = 0.10968928039073944
# EPOCH(0)   loss = 0.10533920675516129
# EPOCH(0)   loss = 0.1037786453962326
# EPOCH(0)   loss = 0.09814468771219254
# EPOCH(0)   loss = 0.09850206971168518
# EPOCH(0)   loss = 0.09784664958715439
# EPOCH(0)   loss = 0.09689029306173325
# EPOCH(0)   loss = 0.10093434154987335
# EPOCH(0)   loss = 0.09486498683691025
# EPOCH(0)   loss = 0.09696726500988007
# EPOCH(0)   loss = 0.09598267078399658
# EPOCH(0)   loss = 0.09493391960859299
# EPOCH(0)   loss = 0.09528972953557968
# EPOCH(0)   loss = 0.0953143760561943
# EPOCH(0)   loss = 0.09595326334238052
# EPOCH(0)   loss = 0.0914040133357048
# EPOCH(0)   loss = 0.09329335391521454
# EPOCH(0)   loss = 0.0952146053314209
# EPOCH(0)   loss = 0.09140174090862274
# EPOCH(0)   loss = 0.09378811717033386
# EPOCH(0)   loss = 0.09135331213474274
# EPOCH(0)   loss = 0.09173940122127533
# EPOCH(0)   loss = 0.0921555906534195
# EPOCH(0)   loss = 0.09052793681621552
# EPOCH(0)   loss = 0.09049595892429352
# EPOCH(0)   loss = 0.09109314531087875
# EPOCH(0)   loss = 0.090492844581604
# EPOCH(0)   loss = 0.08809973299503326
# EPOCH(0)   loss = 0.09000437706708908
# EPOCH(0)   loss = 0.0903991162776947
# EPOCH(0)   loss = 0.08945523202419281
# EPOCH(0)   loss = 0.08961884677410126
# EPOCH(0)   loss = 0.09101441502571106
# EPOCH(0)   loss = 0.08673258125782013
# EPOCH(0)   loss = 0.08941104263067245
# EPOCH(0)   loss = 0.08812881261110306
# EPOCH(0)   loss = 0.08804957568645477
# EPOCH(0)   loss = 0.09028838574886322
# EPOCH(0)   loss = 0.0888308435678482
# EPOCH(0)   loss = 0.08772653341293335
# EPOCH(0)   loss = 0.08646588027477264
# EPOCH(0)   loss = 0.0875677838921547
# EPOCH(0)   loss = 0.08809739351272583
# EPOCH(0)   loss = 0.08732520043849945
# EPOCH(0)   loss = 0.08699275553226471
# EPOCH(0)   loss = 0.08675257861614227
# EPOCH(0)   loss = 0.08787063509225845
# EPOCH(0)   loss = 0.08726491779088974
# EPOCH(0)   loss = 0.0870557352900505
# EPOCH(0)   loss = 0.08583786338567734
# EPOCH(0)   loss = 0.08682604879140854
# EPOCH(0)   loss = 0.08691283315420151
# EPOCH(0)   loss = 0.08595956861972809
# EPOCH(0)   loss = 0.08662395179271698
# EPOCH(0)   loss = 0.08595792949199677
# EPOCH(0)   loss = 0.08657022565603256
# EPOCH(0)   loss = 0.08585715293884277
# EPOCH(0)   loss = 0.08563552796840668
# EPOCH(0)   loss = 0.08594836294651031
# EPOCH(0)   loss = 0.08701816946268082
# EPOCH(0)   loss = 0.08572755753993988
# EPOCH(0)   loss = 0.08569330722093582
# EPOCH(0)   loss = 0.0844978541135788
# EPOCH(0)   loss = 0.08506876230239868
# EPOCH(0)   loss = 0.08519113063812256
# EPOCH(0)   loss = 0.08460351824760437
# EPOCH(0)   loss = 0.08491623401641846
# EPOCH(0)   loss = 0.08553089201450348
# EPOCH(0)   loss = 0.08575846254825592
# EPOCH(0)   loss = 0.08489969372749329
# EPOCH(0)   loss = 0.08500300347805023
# EPOCH(0)   loss = 0.08432979881763458
# EPOCH(0)   loss = 0.08386169373989105
# EPOCH(0)   loss = 0.0843132734298706
# EPOCH(0)   loss = 0.08379513770341873
# EPOCH(0)   loss = 0.08381698280572891
# EPOCH(0)   loss = 0.08403527736663818
# EPOCH(0)   loss = 0.08443458378314972
# EPOCH(0)   loss = 0.08459019660949707
# EPOCH(0)   loss = 0.08390001207590103
# EPOCH(0)   loss = 0.08376817405223846
# EPOCH(0)   loss = 0.0831923857331276
# EPOCH(0)   loss = 0.08331502974033356
# EPOCH(0)   loss = 0.08282919228076935
# EPOCH(0)   loss = 0.08348773419857025
# EPOCH(0)   loss = 0.08263392746448517
# EPOCH(0)   loss = 0.08280786126852036
# EPOCH(0)   loss = 0.08481466770172119
# EPOCH(0)   loss = 0.08375720679759979
# EPOCH(0)   loss = 0.08401764929294586
# EPOCH(0)   loss = 0.08325425535440445
# EPOCH(0)   loss = 0.08234818279743195
# EPOCH(0)   loss = 0.08153585344552994
# EPOCH(0)   loss = 0.08255934715270996
# EPOCH(0)   loss = 0.0825062021613121
# EPOCH(0)   loss = 0.08099667727947235
# EPOCH(0)   loss = 0.08210476487874985
# EPOCH(0)   loss = 0.08086593449115753
# EPOCH(0)   loss = 0.08249398320913315
# EPOCH(0)   loss = 0.08118990808725357
# EPOCH(0)   loss = 0.08319617062807083
# EPOCH(0)   loss = 0.08085919916629791
# EPOCH(0)   loss = 0.08311811834573746
# EPOCH(0)   loss = 0.08190084993839264
# EPOCH(0)   loss = 0.08254344761371613
# EPOCH(0)   loss = 0.08079559355974197
# EPOCH(0)   loss = 0.08310186117887497
# EPOCH(0)   loss = 0.08276022970676422
# EPOCH(0)   loss = 0.08085940778255463
# EPOCH(0)   loss = 0.08148977905511856
# EPOCH(0)   loss = 0.08120521157979965
# EPOCH(0)   loss = 0.08053745329380035
# EPOCH(0)   loss = 0.08080123364925385
# EPOCH(0)   loss = 0.08194933831691742
# EPOCH(0)   loss = 0.08037237077951431
# EPOCH(0)   loss = 0.08038179576396942
# EPOCH(0)   loss = 0.08107174932956696
# EPOCH(0)   loss = 0.08016224950551987
# EPOCH(0)   loss = 0.08223618566989899
# EPOCH(0)   loss = 0.08031065762042999
# EPOCH(0)   loss = 0.08071108162403107
# EPOCH(0)   loss = 0.07936526834964752
# EPOCH(0)   loss = 0.0797293558716774
# EPOCH(0)   loss = 0.07914602011442184
# EPOCH(0)   loss = 0.08188635110855103
# EPOCH(0)   loss = 0.07858209311962128
# EPOCH(0)   loss = 0.07972048968076706
# EPOCH(0)   loss = 0.07971560955047607
# EPOCH(0)   loss = 0.07960431277751923
# EPOCH(0)   loss = 0.07944167405366898
# EPOCH(0)   loss = 0.08029408752918243
# EPOCH(0)   loss = 0.07977093756198883
# EPOCH(0)   loss = 0.07911374419927597
# EPOCH(0)   loss = 0.07913047075271606
# EPOCH(0)   loss = 0.0782904103398323
# EPOCH(0)   loss = 0.0793314129114151
# EPOCH(0)   loss = 0.07775299996137619
# EPOCH(0)   loss = 0.07857421785593033
# EPOCH(0)   loss = 0.07795355468988419
# EPOCH(0)   loss = 0.07737869024276733
# EPOCH(0)   loss = 0.07922255247831345
# EPOCH(0)   loss = 0.07974644005298615
# EPOCH(0)   loss = 0.0779871791601181
# EPOCH(0)   loss = 0.07787538319826126
# EPOCH(0)   loss = 0.07808162271976471
# EPOCH(0)   loss = 0.07846622169017792
# EPOCH(0)   loss = 0.07871352136135101
# EPOCH(0)   loss = 0.07715832442045212
# EPOCH(0)   loss = 0.07928916811943054
# EPOCH(0)   loss = 0.07800156623125076
# EPOCH(0)   loss = 0.07774104177951813
# EPOCH(0)   loss = 0.07841062545776367
# EPOCH(0)   loss = 0.07715833187103271
# EPOCH(0)   loss = 0.07753167301416397
# EPOCH(0)   loss = 0.07584072649478912
# EPOCH(0)   loss = 0.0766429454088211
# EPOCH(0)   loss = 0.07693858444690704
# EPOCH(0)   loss = 0.07634831964969635
# EPOCH(0)   loss = 0.07749464362859726
# EPOCH(0)   loss = 0.07683030515909195
# EPOCH(0)   loss = 0.07554397732019424
# EPOCH(0)   loss = 0.0757402554154396
# EPOCH(0)   loss = 0.07546457648277283
# EPOCH(0)   loss = 0.07552938908338547
# EPOCH(0)   loss = 0.07701121270656586
# EPOCH(0)   loss = 0.07484020292758942
# EPOCH(0)   loss = 0.07618126273155212
# EPOCH(0)   loss = 0.07628431916236877
# EPOCH(0)   loss = 0.07347853481769562
# EPOCH(0)   loss = 0.07455763220787048
# EPOCH(0)   loss = 0.07394849509000778
# EPOCH(0)   loss = 0.07382647693157196
# EPOCH(0)   loss = 0.07586105912923813
# EPOCH(0)   loss = 0.07546712458133698
# EPOCH(0)   loss = 0.07505472749471664
# EPOCH(0)   loss = 0.07680846750736237
# EPOCH(0)   loss = 0.07513834536075592
# EPOCH(0)   loss = 0.07539382576942444
# EPOCH(0)   loss = 0.07366696745157242
# EPOCH(0)   loss = 0.07465562224388123
# EPOCH(0)   loss = 0.07289348542690277
# EPOCH(0)   loss = 0.07506350427865982
# EPOCH(0)   loss = 0.074747234582901
# EPOCH(0)   loss = 0.074488565325737
# EPOCH(0)   loss = 0.0721738189458847
# EPOCH(0)   loss = 0.07490147650241852
# EPOCH(0)   loss = 0.07450155913829803
# EPOCH(0)   loss = 0.07484602928161621
# EPOCH(0)   loss = 0.07410349696874619
# EPOCH(0)   loss = 0.07137630134820938
# EPOCH(0)   loss = 0.07410880923271179
# EPOCH(0)   loss = 0.07290024310350418
# EPOCH(0)   loss = 0.07366302609443665
# EPOCH(0)   loss = 0.0736696645617485
# EPOCH(0)   loss = 0.06943243741989136
# EPOCH(0)   loss = 0.07409749180078506
# EPOCH(0)   loss = 0.07226604223251343
# EPOCH(0)   loss = 0.0723470002412796
# EPOCH(0)   loss = 0.07224661856889725
# EPOCH(0)   loss = 0.07283973693847656
# EPOCH(0)   loss = 0.07177089899778366
# EPOCH(0)   loss = 0.07352427393198013
# EPOCH(0)   loss = 0.07013805955648422
# EPOCH(0)   loss = 0.07102971524000168
# EPOCH(0)   loss = 0.07182890921831131
# EPOCH(0)   loss = 0.07423653453588486
# EPOCH(0)   loss = 0.07119434326887131
# EPOCH(0)   loss = 0.07165001332759857
# EPOCH(0)   loss = 0.07284040004014969
# EPOCH(0)   loss = 0.07154154032468796
# EPOCH(0)   loss = 0.07058505713939667
# EPOCH(0)   loss = 0.07239389419555664
# EPOCH(0)   loss = 0.06921807676553726
# EPOCH(0)   loss = 0.07329685986042023
# EPOCH(0)   loss = 0.07094921916723251
# EPOCH(0)   loss = 0.06829595565795898
# EPOCH(0)   loss = 0.06985171884298325
# EPOCH(0)   loss = 0.07088359445333481
# EPOCH(0)   loss = 0.06988371908664703
# EPOCH(0)   loss = 0.07096979767084122
# EPOCH(0)   loss = 0.07092583924531937
# EPOCH(0)   loss = 0.07134144008159637
# EPOCH(0)   loss = 0.07112118601799011
# EPOCH(0)   loss = 0.06964074075222015
# EPOCH(0)   loss = 0.06997188180685043
# EPOCH(0)   loss = 0.06784132122993469
# EPOCH(0)   loss = 0.07201416790485382
# EPOCH(0)   loss = 0.0674620121717453
# EPOCH(0)   loss = 0.0694112777709961
# EPOCH(0)   loss = 0.070063017308712
# EPOCH(0)   loss = 0.06845450401306152
# EPOCH(0)   loss = 0.06895248591899872
# EPOCH(0)   loss = 0.07123821973800659
# EPOCH(0)   loss = 0.0724237859249115
# EPOCH(0)   loss = 0.06859520822763443
# EPOCH(0)   loss = 0.0686051994562149
# EPOCH(0)   loss = 0.0697690099477768
# EPOCH(0)   loss = 0.06990158557891846
# EPOCH(0)   loss = 0.06932003796100616
# EPOCH(0)   loss = 0.07053709030151367
# EPOCH(0)   loss = 0.06882210075855255
# EPOCH(0)   loss = 0.06876294314861298
# EPOCH(0)   loss = 0.06979083269834518
# EPOCH(0)   loss = 0.06721793115139008
# EPOCH(0)   loss = 0.06788494437932968
# EPOCH(0)   loss = 0.06812462210655212
# EPOCH(0)   loss = 0.06625555455684662
# EPOCH(0)   loss = 0.06744039058685303
# EPOCH(0)   loss = 0.06948097795248032
# EPOCH(0)   loss = 0.06798291951417923
# EPOCH(0)   loss = 0.06813172996044159
# EPOCH(0)   loss = 0.07044424116611481
# EPOCH(0)   loss = 0.06650816649198532
# EPOCH(0)   loss = 0.06882588565349579
# EPOCH(0)   loss = 0.0667625218629837
# EPOCH(0)   loss = 0.06639989465475082
# EPOCH(0)   loss = 0.06700731813907623
# EPOCH(0)   loss = 0.06738148629665375
# EPOCH(0)   loss = 0.06476764380931854
# EPOCH(0)   loss = 0.06665034592151642
# EPOCH(0)   loss = 0.06687377393245697
# EPOCH(0)   loss = 0.06601385772228241
# EPOCH(0)   loss = 0.06861473619937897
# EPOCH(0)   loss = 0.06676442176103592
# EPOCH(0)   loss = 0.0646747499704361
# EPOCH(0)   loss = 0.06674612313508987
# EPOCH(0)   loss = 0.06468256562948227
# EPOCH(0)   loss = 0.065536268055439
# EPOCH(0)   loss = 0.0680399090051651
# EPOCH(0)   loss = 0.0658254474401474
# EPOCH(0)   loss = 0.06545066833496094
# EPOCH(0)   loss = 0.06363870203495026
# EPOCH(0)   loss = 0.06544684618711472
# EPOCH(0)   loss = 0.06921251118183136
# EPOCH(0)   loss = 0.06562583148479462
# EPOCH(0)   loss = 0.0670216754078865
# EPOCH(0)   loss = 0.0658513531088829
# EPOCH(0)   loss = 0.06382813304662704
# EPOCH(0)   loss = 0.0660410225391388
# EPOCH(0)   loss = 0.06360869109630585
# EPOCH(0)   loss = 0.06696318089962006
# EPOCH(0)   loss = 0.06204988434910774
# EPOCH(0)   loss = 0.06647840887308121
# EPOCH(0)   loss = 0.0657244324684143
# EPOCH(0)   loss = 0.06602147966623306
# EPOCH(0)   loss = 0.06357953697443008
# EPOCH(0)   loss = 0.06245201826095581
# EPOCH(0)   loss = 0.0639575645327568
# EPOCH(0)   loss = 0.06531678140163422
# EPOCH(0)   loss = 0.06333984434604645
# EPOCH(0)   loss = 0.06545410305261612
# EPOCH(0)   loss = 0.0633428543806076
# EPOCH(0)   loss = 0.06315231323242188
# EPOCH(0)   loss = 0.05990147590637207
# EPOCH(0)   loss = 0.06455735862255096
# EPOCH(0)   loss = 0.061007458716630936
# EPOCH(0)   loss = 0.06381477415561676
# EPOCH(0)   loss = 0.062301475554704666
# EPOCH(0)   loss = 0.0642755925655365
# EPOCH(0)   loss = 0.06207879260182381
# EPOCH(0)   loss = 0.06422241777181625
# EPOCH(0)   loss = 0.06016117334365845
# EPOCH(0)   loss = 0.0678156167268753
# EPOCH(0)   loss = 0.06728721410036087
# EPOCH(0)   loss = 0.06372439116239548
# EPOCH(0)   loss = 0.06295441836118698
# EPOCH(0)   loss = 0.06082036346197128
# EPOCH(0)   loss = 0.06278719007968903
# EPOCH(0)   loss = 0.06196166202425957
# EPOCH(0)   loss = 0.06223316863179207
# EPOCH(0)   loss = 0.06169891357421875
# EPOCH(0)   loss = 0.06273351609706879
# EPOCH(0)   loss = 0.06212576478719711
# EPOCH(0)   loss = 0.061042916029691696
# EPOCH(0)   loss = 0.06468631327152252
# EPOCH(0)   loss = 0.06483269482851028
# EPOCH(0)   loss = 0.06114203482866287
# EPOCH(0)   loss = 0.06090504676103592
# EPOCH(0)   loss = 0.06332068890333176
# EPOCH(0)   loss = 0.06044523045420647
# EPOCH(0)   loss = 0.06360460072755814
# EPOCH(0)   loss = 0.06221836805343628
# EPOCH(0)   loss = 0.06467762589454651
# EPOCH(0)   loss = 0.06281641125679016
# EPOCH(0)   loss = 0.06389321386814117
# EPOCH(0)   loss = 0.05920177698135376
# EPOCH(0)   loss = 0.06343211233615875
# EPOCH(0)   loss = 0.06097006797790527
# EPOCH(0)   loss = 0.05824919417500496
# EPOCH(0)   loss = 0.0617879219353199
# EPOCH(0)   loss = 0.06135055422782898
# EPOCH(0)   loss = 0.060693345963954926
# EPOCH(0)   loss = 0.06133270263671875
# EPOCH(0)   loss = 0.06116681173443794
# EPOCH(0)   loss = 0.06083773449063301
# EPOCH(0)   loss = 0.06156320497393608
# EPOCH(0)   loss = 0.06172701716423035
# EPOCH(0)   loss = 0.0604313388466835
# EPOCH(0)   loss = 0.06228814646601677
# EPOCH(0)   loss = 0.060894925147295
# EPOCH(0)   loss = 0.06015307828783989
# EPOCH(0)   loss = 0.06180097535252571
# EPOCH(0)   loss = 0.05945683270692825
# EPOCH(0)   loss = 0.05985987186431885
# EPOCH(0)   loss = 0.06153618171811104
# EPOCH(0)   loss = 0.06057034805417061
# EPOCH(0)   loss = 0.05969000607728958
# EPOCH(0)   loss = 0.06129203364253044
# EPOCH(0)   loss = 0.06013629585504532
# EPOCH(0)   loss = 0.05947411060333252
# EPOCH(0)   loss = 0.05398251861333847
# EPOCH(0)   loss = 0.057238269597291946
# EPOCH(0)   loss = 0.059835612773895264
# EPOCH(0)   loss = 0.05593598634004593
# EPOCH(0)   loss = 0.05603576824069023
# EPOCH(0)   loss = 0.05584583804011345
# EPOCH(0)   loss = 0.057429950684309006
# EPOCH(0)   loss = 0.06505025178194046
# EPOCH(0)   loss = 0.05728336423635483
# EPOCH(0)   loss = 0.06007479876279831
# EPOCH(0)   loss = 0.057046256959438324
# EPOCH(0)   loss = 0.058818984776735306
# EPOCH(0)   loss = 0.05985785648226738
# EPOCH(0)   loss = 0.06240971013903618
# EPOCH(0)   loss = 0.058232925832271576
# EPOCH(0)   loss = 0.058288853615522385
# EPOCH(0)   loss = 0.05998216196894646
# EPOCH(0)   loss = 0.057345855981111526
# EPOCH(0)   loss = 0.057965029031038284
# EPOCH(0)   loss = 0.055898118764162064
# EPOCH(0)   loss = 0.05579718202352524
# EPOCH(0)   loss = 0.05895271897315979
# EPOCH(0)   loss = 0.05983833223581314
# EPOCH(0)   loss = 0.05975375697016716
# EPOCH(0)   loss = 0.059170108288526535
# EPOCH(0)   loss = 0.06010518595576286
# EPOCH(0)   loss = 0.05714905261993408
# EPOCH(0)   loss = 0.05834021419286728
# EPOCH(0)   loss = 0.060130469501018524
# EPOCH(0)   loss = 0.054524172097444534
# EPOCH(0)   loss = 0.058949314057826996
# EPOCH(0)   loss = 0.061289601027965546
# EPOCH(0)   loss = 0.057266950607299805
# EPOCH(0)   loss = 0.06507901847362518
# EPOCH(0)   loss = 0.056750304996967316
# EPOCH(0)   loss = 0.055575549602508545
# EPOCH(0)   loss = 0.059198230504989624
# EPOCH(0)   loss = 0.055155616253614426
# EPOCH(0)   loss = 0.0558326318860054
# EPOCH(0)   loss = 0.057455290108919144
# EPOCH(0)   loss = 0.055091340094804764
# EPOCH(0)   loss = 0.055916041135787964
# EPOCH(0)   loss = 0.05818527936935425
# EPOCH(0)   loss = 0.05452694743871689
# EPOCH(0)   loss = 0.0574311800301075
# EPOCH(0)   loss = 0.055382467806339264
# EPOCH(0)   loss = 0.05472254753112793
# EPOCH(0)   loss = 0.057910047471523285
# EPOCH(0)   loss = 0.05607873201370239
# EPOCH(0)   loss = 0.05585728958249092
# EPOCH(0)   loss = 0.0597384050488472
# EPOCH(0)   loss = 0.05260099098086357
# EPOCH(0)   loss = 0.05587078258395195
# EPOCH(0)   loss = 0.04997478052973747
# EPOCH(0)   loss = 0.05908360332250595
# EPOCH(0)   loss = 0.05889911577105522
# EPOCH(0)   loss = 0.05577956885099411
# EPOCH(0)   loss = 0.05515889450907707
# EPOCH(0)   loss = 0.05718076974153519
# EPOCH(0)   loss = 0.05347180366516113
# EPOCH(0)   loss = 0.055937349796295166
# EPOCH(0)   loss = 0.06051908805966377
# EPOCH(0)   loss = 0.0580318346619606
# EPOCH(0)   loss = 0.05567352846264839
# EPOCH(0)   loss = 0.05782641842961311
# EPOCH(0)   loss = 0.05490132421255112
# EPOCH(0)   loss = 0.053279079496860504
# EPOCH(0)   loss = 0.05420541763305664
# EPOCH(0)   loss = 0.05635879188776016
# EPOCH(0)   loss = 0.05667394399642944
# EPOCH(0)   loss = 0.05260590836405754
# EPOCH(0)   loss = 0.05314401537179947
# EPOCH(0)   loss = 0.05473462864756584
# EPOCH(0)   loss = 0.051612257957458496
# EPOCH(0)   loss = 0.05725529044866562
# EPOCH(0)   loss = 0.05275978520512581
# EPOCH(0)   loss = 0.052572913467884064
# EPOCH(0)   loss = 0.05173731595277786
# EPOCH(0)   loss = 0.05302093178033829
# EPOCH(0)   loss = 0.0571962408721447
# EPOCH(0)   loss = 0.0549011304974556
# EPOCH(0)   loss = 0.05456665903329849
# EPOCH(0)   loss = 0.05691215395927429
# EPOCH(0)   loss = 0.05911652371287346
# EPOCH(0)   loss = 0.05367574095726013
# EPOCH(0)   loss = 0.05255768820643425
# EPOCH(0)   loss = 0.05373435467481613
# EPOCH(0)   loss = 0.051765210926532745
# EPOCH(0)   loss = 0.05374253913760185
# EPOCH(0)   loss = 0.05163728445768356
# EPOCH(0)   loss = 0.05233149603009224
# EPOCH(0)   loss = 0.05627993866801262
# EPOCH(0)   loss = 0.05487193539738655
# EPOCH(0)   loss = 0.0544591061770916
# EPOCH(0)   loss = 0.056131552904844284
# EPOCH(0)   loss = 0.056581396609544754
# EPOCH(0)   loss = 0.0556965246796608
# EPOCH(0)   loss = 0.05427974462509155
# EPOCH(0)   loss = 0.055615972727537155
# EPOCH(0)   loss = 0.05558747798204422
# EPOCH(0)   loss = 0.05267006903886795
# EPOCH(0)   loss = 0.054077159613370895
# EPOCH(0)   loss = 0.048235971480607986
# EPOCH(0)   loss = 0.05318834260106087
# EPOCH(0)   loss = 0.0505630187690258
# EPOCH(0)   loss = 0.051655273884534836
# EPOCH(0)   loss = 0.048848673701286316
# EPOCH(0)   loss = 0.055380601435899734
# EPOCH(0)   loss = 0.054238639771938324
# EPOCH(0)   loss = 0.05345308035612106
# EPOCH(0)   loss = 0.05335155874490738
# EPOCH(0)   loss = 0.0534847266972065
# EPOCH(0)   loss = 0.0553591325879097
# EPOCH(0)   loss = 0.05261548236012459
# EPOCH(0)   loss = 0.057563625276088715
# EPOCH(0)   loss = 0.05423814058303833
# EPOCH(0)   loss = 0.053464125841856
# EPOCH(0)   loss = 0.05401187017560005
# EPOCH(0)   loss = 0.052165258675813675
# EPOCH(0)   loss = 0.050297100096940994
# EPOCH(0)   loss = 0.0558491125702858
# EPOCH(0)   loss = 0.053567416965961456
# EPOCH(0)   loss = 0.05112844705581665
# EPOCH(0)   loss = 0.053794968873262405
# EPOCH(0)   loss = 0.04755890369415283
# EPOCH(0)   loss = 0.05337802320718765
# EPOCH(0)   loss = 0.05029872804880142
# EPOCH(0)   loss = 0.04678128659725189
# EPOCH(0)   loss = 0.051954131573438644
# EPOCH(0)   loss = 0.053584061563014984
# EPOCH(0)   loss = 0.04975779354572296
# EPOCH(0)   loss = 0.05752941220998764
# EPOCH(0)   loss = 0.04835418611764908
# EPOCH(0)   loss = 0.053204767405986786
# EPOCH(0)   loss = 0.051270972937345505
# EPOCH(0)   loss = 0.05641382187604904
# EPOCH(0)   loss = 0.05019139498472214
# EPOCH(0)   loss = 0.0500287190079689
# EPOCH(0)   loss = 0.055181991308927536
# EPOCH(0)   loss = 0.05343371629714966
# EPOCH(0)   loss = 0.04837824031710625
# EPOCH(0)   loss = 0.0503818579018116
# EPOCH(0)   loss = 0.04810512810945511
# EPOCH(0)   loss = 0.0445149801671505
# EPOCH(0)   loss = 0.04894496127963066
# EPOCH(0)   loss = 0.048839252442121506
# EPOCH(0)   loss = 0.05291593074798584
# EPOCH(0)   loss = 0.048046547919511795
# EPOCH(0)   loss = 0.04787854105234146
# EPOCH(0)   loss = 0.05102816969156265
# EPOCH(0)   loss = 0.0520382821559906
# EPOCH(0)   loss = 0.05297303944826126
# EPOCH(0)   loss = 0.05285907909274101
# EPOCH(0)   loss = 0.0537378191947937
# EPOCH(0)   loss = 0.04632923752069473
# EPOCH(0)   loss = 0.04888404533267021
# EPOCH(0)   loss = 0.05408353731036186
# EPOCH(0)   loss = 0.05261768028140068
# EPOCH(0)   loss = 0.05071635916829109
# EPOCH(0)   loss = 0.05085479095578194
# EPOCH(0)   loss = 0.05076579377055168
# EPOCH(0)   loss = 0.054088614881038666
# EPOCH(0)   loss = 0.04879196733236313
# EPOCH(0)   loss = 0.04934984818100929
# EPOCH(0)   loss = 0.043354906141757965
# EPOCH(0)   loss = 0.05235903710126877
# EPOCH(0)   loss = 0.055448781698942184
# EPOCH(0)   loss = 0.048526786267757416
# EPOCH(0)   loss = 0.053272951394319534
# EPOCH(0)   loss = 0.054027341306209564
# EPOCH(0)   loss = 0.04437143728137016
# EPOCH(0)   loss = 0.050012778490781784
# EPOCH(0)   loss = 0.05215325951576233
# EPOCH(0)   loss = 0.04697557911276817
# EPOCH(0)   loss = 0.0477413646876812
# EPOCH(0)   loss = 0.044234827160835266
# EPOCH(0)   loss = 0.04887856915593147
# EPOCH(0)   loss = 0.04669623821973801
# EPOCH(0)   loss = 0.0474444255232811
# EPOCH(0)   loss = 0.0474235825240612
# EPOCH(0)   loss = 0.0484497956931591
# EPOCH(0)   loss = 0.04348430037498474
# EPOCH(0)   loss = 0.04609472304582596
# EPOCH(0)   loss = 0.05007844418287277
# EPOCH(0)   loss = 0.04720069840550423
# EPOCH(0)   loss = 0.04980993643403053
# EPOCH(0)   loss = 0.04675402119755745
# EPOCH(0)   loss = 0.0476251021027565
# EPOCH(0)   loss = 0.043870627880096436
# EPOCH(0)   loss = 0.04836517572402954
# EPOCH(0)   loss = 0.045868322253227234
# EPOCH(0)   loss = 0.05121665075421333
# EPOCH(0)   loss = 0.04876298829913139
# EPOCH(0)   loss = 0.05213870480656624
# EPOCH(0)   loss = 0.05123046785593033
# EPOCH(0)   loss = 0.04766897112131119
# EPOCH(0)   loss = 0.04802072048187256
# EPOCH(0)   loss = 0.04600515216588974
# EPOCH(0)   loss = 0.04762560874223709
# EPOCH(0)   loss = 0.04844517260789871
# EPOCH(0)   loss = 0.04666748642921448
# EPOCH(0)   loss = 0.048277996480464935
# EPOCH(0)   loss = 0.046009112149477005
# EPOCH(0)   loss = 0.0434514656662941
# EPOCH(0)   loss = 0.0483272559940815
# EPOCH(0)   loss = 0.0475982204079628
# EPOCH(0)   loss = 0.04951438307762146
# EPOCH(0)   loss = 0.04280539229512215
# EPOCH(0)   loss = 0.05240309238433838
# EPOCH(0)   loss = 0.05174444243311882
# EPOCH(0)   loss = 0.047992534935474396
# EPOCH(0)   loss = 0.05130166932940483
# EPOCH(0)   loss = 0.047439251095056534
# EPOCH(0)   loss = 0.046587973833084106
# EPOCH(0)   loss = 0.046740300953388214
# EPOCH(0)   loss = 0.0442558228969574
# EPOCH(0)   loss = 0.04830954223871231
# EPOCH(0)   loss = 0.047401588410139084
# EPOCH(0)   loss = 0.04320565611124039
# EPOCH(0)   loss = 0.0523211844265461
# EPOCH(0)   loss = 0.05383046716451645
# EPOCH(0)   loss = 0.050549548119306564
# EPOCH(0)   loss = 0.050180524587631226
# EPOCH(0)   loss = 0.04985760152339935
# EPOCH(0)   loss = 0.047787729650735855
# EPOCH(0)   loss = 0.04367340728640556
# EPOCH(0)   loss = 0.04086769372224808
# EPOCH(0)   loss = 0.0465892069041729
# EPOCH(0)   loss = 0.045960910618305206
# EPOCH(0)   loss = 0.04442914202809334
# EPOCH(0)   loss = 0.046402882784605026
# EPOCH(0)   loss = 0.04588967561721802
# EPOCH(0)   loss = 0.046253323554992676
# EPOCH(0)   loss = 0.04494820162653923
# EPOCH(0)   loss = 0.05320616811513901
# EPOCH(0)   loss = 0.04532570391893387
# EPOCH(0)   loss = 0.04330011457204819
# EPOCH(0)   loss = 0.04685434699058533
# EPOCH(0)   loss = 0.048418719321489334
# EPOCH(0)   loss = 0.04758294299244881
# EPOCH(0)   loss = 0.04563257470726967
# EPOCH(0)   loss = 0.04241733253002167
# EPOCH(0)   loss = 0.04753277450799942
# EPOCH(0)   loss = 0.0490763783454895
# EPOCH(0)   loss = 0.04677952826023102
# EPOCH(0)   loss = 0.049439217895269394
# EPOCH(0)   loss = 0.047819994390010834
# EPOCH(0)   loss = 0.04947590455412865
# EPOCH(0)   loss = 0.047794416546821594
# EPOCH(0)   loss = 0.04529707878828049
# EPOCH(0)   loss = 0.04958473891019821
# EPOCH(0)   loss = 0.04199237376451492
# EPOCH(0)   loss = 0.04552784562110901
# EPOCH(0)   loss = 0.04853073135018349
# EPOCH(0)   loss = 0.045315347611904144
# EPOCH(0)   loss = 0.04252607747912407
# EPOCH(0)   loss = 0.05078238248825073
# EPOCH(0)   loss = 0.046607401221990585
# EPOCH(0)   loss = 0.045479707419872284
# EPOCH(0)   loss = 0.04142523556947708
# EPOCH(0)   loss = 0.04861118271946907
# EPOCH(0)   loss = 0.0443899929523468
# EPOCH(0)   loss = 0.04621576517820358
# EPOCH(0)   loss = 0.04580362141132355
# EPOCH(0)   loss = 0.04527262970805168
# EPOCH(0)   loss = 0.04501556232571602
# EPOCH(0)   loss = 0.05088069289922714
# EPOCH(0)   loss = 0.046582043170928955
# EPOCH(0)   loss = 0.04621037095785141
# EPOCH(0)   loss = 0.04777887091040611
# EPOCH(0)   loss = 0.04339616373181343
# EPOCH(0)   loss = 0.04468975216150284
# EPOCH(0)   loss = 0.04622513800859451
# EPOCH(0)   loss = 0.04361584782600403
# EPOCH(0)   loss = 0.048573512583971024
# EPOCH(0)   loss = 0.044567953795194626
# EPOCH(0)   loss = 0.050781428813934326
# EPOCH(0)   loss = 0.04712210223078728
# EPOCH(0)   loss = 0.05058585852384567
# EPOCH(0)   loss = 0.046789973974227905
# EPOCH(0)   loss = 0.04279686138033867
# EPOCH(0)   loss = 0.04556625708937645
# EPOCH(0)   loss = 0.04278583079576492
# EPOCH(0)   loss = 0.042208120226860046
# EPOCH(0)   loss = 0.04244563356041908
# EPOCH(0)   loss = 0.04337912052869797
# EPOCH(0)   loss = 0.04448304325342178
# EPOCH(0)   loss = 0.044059090316295624
# EPOCH(0)   loss = 0.04242362082004547
# EPOCH(0)   loss = 0.044509001076221466
# EPOCH(0)   loss = 0.045347101986408234
# EPOCH(0)   loss = 0.045822255313396454
# EPOCH(0)   loss = 0.041618578135967255
# EPOCH(0)   loss = 0.04205859452486038
# EPOCH(0)   loss = 0.04328123852610588
# EPOCH(0)   loss = 0.047555118799209595
# EPOCH(0)   loss = 0.04321933910250664
# EPOCH(0)   loss = 0.04495406150817871
# EPOCH(0)   loss = 0.04072267562150955
# EPOCH(0)   loss = 0.04106364771723747
# EPOCH(0)   loss = 0.040388546884059906
# EPOCH(0)   loss = 0.04066092520952225
# EPOCH(0)   loss = 0.04369208216667175
# EPOCH(0)   loss = 0.04359404370188713
# EPOCH(0)   loss = 0.03905147314071655
# EPOCH(0)   loss = 0.04425550252199173
# EPOCH(0)   loss = 0.0402691587805748
# EPOCH(0)   loss = 0.0431271567940712
# EPOCH(0)   loss = 0.04167354106903076
# EPOCH(0)   loss = 0.04767082259058952
# EPOCH(0)   loss = 0.03763044252991676
# EPOCH(0)   loss = 0.04412982240319252
# EPOCH(0)   loss = 0.04538873955607414
# EPOCH(0)   loss = 0.0409136563539505
# EPOCH(0)   loss = 0.048452310264110565
# EPOCH(0)   loss = 0.04280013218522072
# EPOCH(0)   loss = 0.04197131469845772
# EPOCH(0)   loss = 0.04226616770029068
# EPOCH(0)   loss = 0.04854491353034973
# EPOCH(0)   loss = 0.04165113344788551
# EPOCH(0)   loss = 0.04858005791902542
# EPOCH(0)   loss = 0.03419705480337143
# EPOCH(0)   loss = 0.038551367819309235
# EPOCH(0)   loss = 0.04222725331783295
# EPOCH(0)   loss = 0.04302418231964111
# EPOCH(0)   loss = 0.0466960109770298
# EPOCH(0)   loss = 0.04261108115315437
# EPOCH(0)   loss = 0.04419849440455437
# EPOCH(0)   loss = 0.04423891752958298
# EPOCH(0)   loss = 0.04573606327176094
# EPOCH(0)   loss = 0.049332838505506516
# EPOCH(0)   loss = 0.040808387100696564
# EPOCH(0)   loss = 0.04243505001068115
# EPOCH(0)   loss = 0.03757614642381668
# EPOCH(0)   loss = 0.04688370227813721
# EPOCH(0)   loss = 0.04083254933357239
# EPOCH(0)   loss = 0.044009365141391754
# EPOCH(0)   loss = 0.03847834840416908
# EPOCH(0)   loss = 0.03872046247124672
# EPOCH(0)   loss = 0.04667026549577713
# EPOCH(0)   loss = 0.03697706013917923
# EPOCH(0)   loss = 0.03571202605962753
# EPOCH(0)   loss = 0.04337251931428909
# EPOCH(0)   loss = 0.04161161929368973
# EPOCH(0)   loss = 0.038911961019039154
# EPOCH(0)   loss = 0.04272957146167755
# EPOCH(0)   loss = 0.041465647518634796
# EPOCH(0)   loss = 0.04426022246479988
# EPOCH(0)   loss = 0.04413052648305893
# EPOCH(0)   loss = 0.041320525109767914
# EPOCH(0)   loss = 0.04943856596946716
# EPOCH(0)   loss = 0.038345303386449814
# EPOCH(0)   loss = 0.045549504458904266
# EPOCH(0)   loss = 0.038719091564416885
# EPOCH(0)   loss = 0.04469100013375282
# EPOCH(0)   loss = 0.03953061252832413
# EPOCH(0)   loss = 0.04442502185702324
# EPOCH(0)   loss = 0.04216330498456955
# EPOCH(0)   loss = 0.03697389364242554
# EPOCH(0)   loss = 0.043002624064683914
# EPOCH(0)   loss = 0.046260394155979156
# EPOCH(0)   loss = 0.04597654193639755
# EPOCH(0)   loss = 0.04232586920261383
# EPOCH(0)   loss = 0.04038885235786438
# EPOCH(0)   loss = 0.048399195075035095
# EPOCH(0)   loss = 0.03888767585158348
# EPOCH(0)   loss = 0.04369577020406723
# EPOCH(0)   loss = 0.03651653975248337
# EPOCH(0)   loss = 0.04468206688761711
# EPOCH(0)   loss = 0.05089278891682625
# EPOCH(0)   loss = 0.042447518557310104
# EPOCH(0)   loss = 0.04253134876489639
# EPOCH(0)   loss = 0.04303979128599167
# EPOCH(0)   loss = 0.04103466868400574
# EPOCH(0)   loss = 0.04141165688633919
# EPOCH(0)   loss = 0.0411088801920414
# EPOCH(0)   loss = 0.03881179168820381
# EPOCH(0)   loss = 0.043056461960077286
# EPOCH(0)   loss = 0.04339689761400223
# EPOCH(0)   loss = 0.0358848050236702
# EPOCH(0)   loss = 0.04180504381656647
# EPOCH(0)   loss = 0.03549017757177353
# EPOCH(0)   loss = 0.041029177606105804
# EPOCH(0)   loss = 0.04314294829964638
# EPOCH(0)   loss = 0.04268023371696472
# EPOCH(0)   loss = 0.04499916359782219
# EPOCH(0)   loss = 0.045291658490896225
# EPOCH(0)   loss = 0.041966743767261505
# EPOCH(0)   loss = 0.04042980819940567
# EPOCH(0)   loss = 0.04094630852341652
# EPOCH(0)   loss = 0.03964750096201897
# EPOCH(0)   loss = 0.043534062802791595
# EPOCH(0)   loss = 0.03948351368308067
# EPOCH(0)   loss = 0.03975702077150345
# EPOCH(0)   loss = 0.0400569811463356
# EPOCH(0)   loss = 0.04233518987894058
# EPOCH(0)   loss = 0.04039251059293747
# EPOCH(0)   loss = 0.043071646243333817
# EPOCH(0)   loss = 0.040897902101278305
# EPOCH(0)   loss = 0.037327516824007034
# EPOCH(0)   loss = 0.03677482157945633
# EPOCH(0)   loss = 0.04729492589831352
# EPOCH(0)   loss = 0.03789285570383072
# EPOCH(0)   loss = 0.043944425880908966
# EPOCH(0)   loss = 0.04031958803534508
# EPOCH(0)   loss = 0.04249678924679756
# EPOCH(0)   loss = 0.03830020874738693
# EPOCH(0)   loss = 0.0375220812857151
# EPOCH(0)   loss = 0.04318198561668396
# EPOCH(0)   loss = 0.037813931703567505
# EPOCH(0)   loss = 0.04196334630250931
# EPOCH(0)   loss = 0.03948027640581131
# EPOCH(0)   loss = 0.038736794143915176
# EPOCH(0)   loss = 0.03921929746866226
# EPOCH(0)   loss = 0.04386717453598976
# EPOCH(0)   loss = 0.038050439208745956
# EPOCH(0)   loss = 0.04118353873491287
# EPOCH(0)   loss = 0.035948462784290314
# EPOCH(0)   loss = 0.037627507001161575
# EPOCH(0)   loss = 0.04244677349925041
# EPOCH(0)   loss = 0.04137348011136055
# EPOCH(0)   loss = 0.04349566996097565
# EPOCH(0)   loss = 0.03487080708146095
# EPOCH(0)   loss = 0.04522579163312912
# EPOCH(0)   loss = 0.03610773757100105
# EPOCH(0)   loss = 0.041695382446050644
# EPOCH(0)   loss = 0.038007818162441254
# EPOCH(0)   loss = 0.0429471917450428
# EPOCH(0)   loss = 0.040460072457790375
# EPOCH(0)   loss = 0.03715275600552559
# EPOCH(0)   loss = 0.04243312403559685
# EPOCH(0)   loss = 0.04092242568731308
# EPOCH(0)   loss = 0.038346003741025925
# EPOCH(0)   loss = 0.03384958952665329
# EPOCH(0)   loss = 0.037696827203035355
# EPOCH(0)   loss = 0.039931852370500565
# EPOCH(0)   loss = 0.03599498048424721
# EPOCH(0)   loss = 0.03653871268033981
# EPOCH(0)   loss = 0.04188070073723793
# EPOCH(0)   loss = 0.038699470460414886
# EPOCH(0)   loss = 0.04020099341869354
# EPOCH(0)   loss = 0.04596487805247307
# EPOCH(0)   loss = 0.042614441365003586
# EPOCH(0)   loss = 0.040205229073762894
# EPOCH(0)   loss = 0.03657769039273262
# EPOCH(0)   loss = 0.03954727575182915
# EPOCH(0)   loss = 0.036536794155836105
# EPOCH(0)   loss = 0.0349227711558342
# EPOCH(0)   loss = 0.03353768587112427
# EPOCH(0)   loss = 0.03739054128527641
# EPOCH(0)   loss = 0.041663214564323425
# EPOCH(0)   loss = 0.03637810796499252
# EPOCH(0)   loss = 0.038331665098667145
# EPOCH(0)   loss = 0.03807532414793968
# EPOCH(0)   loss = 0.03653264790773392
# EPOCH(0)   loss = 0.037244535982608795
# EPOCH(0)   loss = 0.0379423163831234
# EPOCH(0)   loss = 0.038863405585289
# EPOCH(0)   loss = 0.041688013821840286
# EPOCH(0)   loss = 0.04138626903295517
# EPOCH(0)   loss = 0.034544937312603
# EPOCH(0)   loss = 0.034668248146772385
# EPOCH(0)   loss = 0.03470554202795029
# EPOCH(0)   loss = 0.042977847158908844
# EPOCH(0)   loss = 0.03142467513680458
# EPOCH(0)   loss = 0.03526459261775017
# EPOCH(0)   loss = 0.039098843932151794
# EPOCH(0)   loss = 0.04421782121062279
# EPOCH(0)   loss = 0.03679994121193886
# EPOCH(0)   loss = 0.03390968218445778
# EPOCH(0)   loss = 0.03875736519694328
# EPOCH(0)   loss = 0.036806754767894745
# EPOCH(0)   loss = 0.04081078618764877
# EPOCH(0)   loss = 0.04491806775331497
# EPOCH(0)   loss = 0.0374552384018898
# EPOCH(0)   loss = 0.038505833595991135
# EPOCH(0)   loss = 0.04507562890648842
# EPOCH(0)   loss = 0.04250470921397209
# EPOCH(0)   loss = 0.04057740047574043
# EPOCH(0)   loss = 0.03735997900366783
# EPOCH(0)   loss = 0.04223934933543205
# EPOCH(0)   loss = 0.03935850411653519
# EPOCH(0)   loss = 0.041955072432756424
# EPOCH(0)   loss = 0.03924962133169174
# EPOCH(0)   loss = 0.03824750334024429
# EPOCH(0)   loss = 0.0366353876888752
# EPOCH(0)   loss = 0.036251090466976166
# EPOCH(0)   loss = 0.0336877815425396
# EPOCH(0)   loss = 0.03738066926598549
# EPOCH(0)   loss = 0.03632263094186783
# EPOCH(0)   loss = 0.041271477937698364
# EPOCH(0)   loss = 0.038090772926807404
# EPOCH(0)   loss = 0.03190229460597038
# EPOCH(0)   loss = 0.049078185111284256
# EPOCH(0)   loss = 0.03912690281867981
# EPOCH(0)   loss = 0.03964943066239357
# EPOCH(0)   loss = 0.04109231382608414
# EPOCH(0)   loss = 0.043028574436903
# EPOCH(0)   loss = 0.03353387489914894
# EPOCH(0)   loss = 0.03576122596859932
# EPOCH(0)   loss = 0.035489462316036224
# EPOCH(0)   loss = 0.0338594913482666
# EPOCH(0)   loss = 0.03890836983919144
# EPOCH(0)   loss = 0.039243340492248535
# EPOCH(0)   loss = 0.03324057534337044
# EPOCH(0)   loss = 0.03940809518098831
# EPOCH(0)   loss = 0.035013943910598755
# EPOCH(0)   loss = 0.0380081906914711
# EPOCH(0)   loss = 0.038086649030447006
# EPOCH(0)   loss = 0.04180512577295303
# EPOCH(0)   loss = 0.036518797278404236
# EPOCH(0)   loss = 0.04362768307328224
# EPOCH(0)   loss = 0.035936880856752396
# EPOCH(0)   loss = 0.03744182735681534
# EPOCH(0)   loss = 0.033548057079315186
# EPOCH(0)   loss = 0.04315892606973648
# EPOCH(0)   loss = 0.03704826906323433
# EPOCH(0)   loss = 0.032867152243852615
# EPOCH(0)   loss = 0.034722454845905304
# EPOCH(0)   loss = 0.03678135573863983
# EPOCH(0)   loss = 0.0409480556845665
# EPOCH(0)   loss = 0.03858532756567001
# EPOCH(0)   loss = 0.03540180251002312
# EPOCH(0)   loss = 0.03242841735482216
# EPOCH(0)   loss = 0.04403875023126602
# EPOCH(0)   loss = 0.037753693759441376
# EPOCH(0)   loss = 0.03708381578326225
# EPOCH(0)   loss = 0.035283781588077545
# EPOCH(0)   loss = 0.03200528398156166
# EPOCH(0)   loss = 0.03536919876933098
# EPOCH(0)   loss = 0.037478283047676086
# EPOCH(0)   loss = 0.02867884561419487
# EPOCH(0)   loss = 0.04749036580324173
# EPOCH(0)   loss = 0.03559023141860962
# EPOCH(0)   loss = 0.037259504199028015
# EPOCH(0)   loss = 0.03693675249814987
# EPOCH(0)   loss = 0.03760993853211403
# EPOCH(0)   loss = 0.03777278587222099
# EPOCH(0)   loss = 0.03865407779812813
# EPOCH(0)   loss = 0.03510807827115059
# EPOCH(0)   loss = 0.041039470583200455
# EPOCH(0)   loss = 0.0408422015607357
# EPOCH(0)   loss = 0.03817395120859146
# EPOCH(0)   loss = 0.031982045620679855
# EPOCH(0)   loss = 0.04110083729028702
# EPOCH(0)   loss = 0.03240653872489929
# EPOCH(0)   loss = 0.040437083691358566
# EPOCH(0)   loss = 0.044888757169246674
# EPOCH(0)   loss = 0.04283132404088974
# EPOCH(0)   loss = 0.03527342155575752
# EPOCH(0)   loss = 0.04586154595017433
# EPOCH(0)   loss = 0.03974621370434761
# EPOCH(0)   loss = 0.036599766463041306
# EPOCH(1)   loss = 0.03524046391248703
# EPOCH(1)   loss = 0.032997243106365204
# EPOCH(1)   loss = 0.036943793296813965
# EPOCH(1)   loss = 0.031670160591602325
# EPOCH(1)   loss = 0.04264895245432854
# EPOCH(1)   loss = 0.03817274793982506
# EPOCH(1)   loss = 0.0419943667948246
# EPOCH(1)   loss = 0.03917734697461128
# EPOCH(1)   loss = 0.032255496829748154
# EPOCH(1)   loss = 0.04273899272084236
# EPOCH(1)   loss = 0.03986382111907005
# EPOCH(1)   loss = 0.035827260464429855
# EPOCH(1)   loss = 0.04155879095196724
# EPOCH(1)   loss = 0.03541698306798935
# EPOCH(1)   loss = 0.03243520110845566
# EPOCH(1)   loss = 0.04372058063745499
# EPOCH(1)   loss = 0.0363999605178833
# EPOCH(1)   loss = 0.03967372328042984
# EPOCH(1)   loss = 0.044581007212400436
# EPOCH(1)   loss = 0.03774403780698776
# EPOCH(1)   loss = 0.03985157236456871
# EPOCH(1)   loss = 0.039191849529743195
# EPOCH(1)   loss = 0.03638315945863724
# EPOCH(1)   loss = 0.03366994857788086
# EPOCH(1)   loss = 0.03641698509454727
# EPOCH(1)   loss = 0.04141303151845932
# EPOCH(1)   loss = 0.0362904891371727
# EPOCH(1)   loss = 0.04008076339960098
# EPOCH(1)   loss = 0.030217405408620834
# EPOCH(1)   loss = 0.03649448975920677
# EPOCH(1)   loss = 0.03786877542734146
# EPOCH(1)   loss = 0.03948061913251877
# EPOCH(1)   loss = 0.03792580962181091
# EPOCH(1)   loss = 0.03167181834578514
# EPOCH(1)   loss = 0.03548819571733475
# EPOCH(1)   loss = 0.04139183461666107
# EPOCH(1)   loss = 0.03787671774625778
# EPOCH(1)   loss = 0.034600500017404556
# EPOCH(1)   loss = 0.038770802319049835
# EPOCH(1)   loss = 0.037509068846702576
# EPOCH(1)   loss = 0.037340711802244186
# EPOCH(1)   loss = 0.035102229565382004
# EPOCH(1)   loss = 0.033272240310907364
# EPOCH(1)   loss = 0.03859413415193558
# EPOCH(1)   loss = 0.03669212758541107
# EPOCH(1)   loss = 0.03501003980636597
# EPOCH(1)   loss = 0.03514697775244713
# EPOCH(1)   loss = 0.03648397698998451
# EPOCH(1)   loss = 0.0349670872092247
# EPOCH(1)   loss = 0.04176805540919304
# EPOCH(1)   loss = 0.04151229187846184
# EPOCH(1)   loss = 0.03564630076289177
# EPOCH(1)   loss = 0.03423767909407616
# EPOCH(1)   loss = 0.04013017937541008
# EPOCH(1)   loss = 0.03524273261427879
# EPOCH(1)   loss = 0.03689650446176529
# EPOCH(1)   loss = 0.039437588304281235
# EPOCH(1)   loss = 0.029636915773153305
# EPOCH(1)   loss = 0.03649856522679329
# EPOCH(1)   loss = 0.04211491346359253
# EPOCH(1)   loss = 0.037682466208934784
# EPOCH(1)   loss = 0.0343017615377903
# EPOCH(1)   loss = 0.02979489229619503
# EPOCH(1)   loss = 0.03130723163485527
# EPOCH(1)   loss = 0.03476323187351227
# EPOCH(1)   loss = 0.03705365210771561
# EPOCH(1)   loss = 0.03093559481203556
# EPOCH(1)   loss = 0.03899203985929489
# EPOCH(1)   loss = 0.038034483790397644
# EPOCH(1)   loss = 0.03761550411581993
# EPOCH(1)   loss = 0.03672849386930466
# EPOCH(1)   loss = 0.037297945469617844
# EPOCH(1)   loss = 0.039936456829309464
# EPOCH(1)   loss = 0.03318267688155174
# EPOCH(1)   loss = 0.037990864366292953
# EPOCH(1)   loss = 0.035663582384586334
# EPOCH(1)   loss = 0.03714299574494362
# EPOCH(1)   loss = 0.033812474459409714
# EPOCH(1)   loss = 0.03998038172721863
# EPOCH(1)   loss = 0.031976476311683655
# EPOCH(1)   loss = 0.03548913449048996
# EPOCH(1)   loss = 0.037285227328538895
# EPOCH(1)   loss = 0.03672919422388077
# EPOCH(1)   loss = 0.03487204387784004
# EPOCH(1)   loss = 0.032076191157102585
# EPOCH(1)   loss = 0.03341704234480858
# EPOCH(1)   loss = 0.04453079029917717
# EPOCH(1)   loss = 0.03250601887702942
# EPOCH(1)   loss = 0.03930942341685295
# EPOCH(1)   loss = 0.036326535046100616
# EPOCH(1)   loss = 0.03746115416288376
# EPOCH(1)   loss = 0.03973425179719925
# EPOCH(1)   loss = 0.035616494715213776
# EPOCH(1)   loss = 0.03216265141963959
# EPOCH(1)   loss = 0.036520522087812424
# EPOCH(1)   loss = 0.0345182940363884
# EPOCH(1)   loss = 0.033515967428684235
# EPOCH(1)   loss = 0.033550333231687546
# EPOCH(1)   loss = 0.03878510743379593
# EPOCH(1)   loss = 0.03137694671750069
# EPOCH(1)   loss = 0.03917521983385086
# EPOCH(1)   loss = 0.03345351666212082
# EPOCH(1)   loss = 0.0364539697766304
# EPOCH(1)   loss = 0.035171184688806534
# EPOCH(1)   loss = 0.036133844405412674
# EPOCH(1)   loss = 0.035347193479537964
# EPOCH(1)   loss = 0.03601045534014702
# EPOCH(1)   loss = 0.03809591382741928
# EPOCH(1)   loss = 0.037099748849868774
# EPOCH(1)   loss = 0.0379168726503849
# EPOCH(1)   loss = 0.03222181648015976
# EPOCH(1)   loss = 0.03361165151000023
# EPOCH(1)   loss = 0.030976057052612305
# EPOCH(1)   loss = 0.03707020729780197
# EPOCH(1)   loss = 0.03400170058012009
# EPOCH(1)   loss = 0.03391358256340027
# EPOCH(1)   loss = 0.03486943989992142
# EPOCH(1)   loss = 0.03353302180767059
# EPOCH(1)   loss = 0.03471067547798157
# EPOCH(1)   loss = 0.035154856741428375
# EPOCH(1)   loss = 0.03348339721560478
# EPOCH(1)   loss = 0.030877819284796715
# EPOCH(1)   loss = 0.030778884887695312
# EPOCH(1)   loss = 0.03300538659095764
# EPOCH(1)   loss = 0.038337159901857376
# EPOCH(1)   loss = 0.0382472388446331
# EPOCH(1)   loss = 0.036385901272296906
# EPOCH(1)   loss = 0.033782608807086945
# EPOCH(1)   loss = 0.035302240401506424
# EPOCH(1)   loss = 0.03461991250514984
# EPOCH(1)   loss = 0.036048222333192825
# EPOCH(1)   loss = 0.03241322189569473
# EPOCH(1)   loss = 0.03847111016511917
# EPOCH(1)   loss = 0.03725609928369522
# EPOCH(1)   loss = 0.033553075045347214
# EPOCH(1)   loss = 0.04118040204048157
# EPOCH(1)   loss = 0.030610177665948868
# EPOCH(1)   loss = 0.03265226259827614
# EPOCH(1)   loss = 0.034396879374980927
# EPOCH(1)   loss = 0.040852777659893036
# EPOCH(1)   loss = 0.028698652982711792
# EPOCH(1)   loss = 0.0316409133374691
# EPOCH(1)   loss = 0.035627443343400955
# EPOCH(1)   loss = 0.03784582391381264
# EPOCH(1)   loss = 0.03475441783666611
# EPOCH(1)   loss = 0.02825089916586876
# EPOCH(1)   loss = 0.03147270902991295
# EPOCH(1)   loss = 0.03722076117992401
# EPOCH(1)   loss = 0.0352088026702404
# EPOCH(1)   loss = 0.0377485416829586
# EPOCH(1)   loss = 0.041460730135440826
# EPOCH(1)   loss = 0.03462865948677063
# EPOCH(1)   loss = 0.030321326106786728
# EPOCH(1)   loss = 0.02948381006717682
# EPOCH(1)   loss = 0.03546196594834328
# EPOCH(1)   loss = 0.03851298242807388
# EPOCH(1)   loss = 0.040315259248018265
# EPOCH(1)   loss = 0.033147234469652176
# EPOCH(1)   loss = 0.03333327919244766
# EPOCH(1)   loss = 0.03580377623438835
# EPOCH(1)   loss = 0.0338253453373909
# EPOCH(1)   loss = 0.032069846987724304
# EPOCH(1)   loss = 0.03701230138540268
# EPOCH(1)   loss = 0.03879687562584877
# EPOCH(1)   loss = 0.03702067956328392
# EPOCH(1)   loss = 0.03391844779253006
# EPOCH(1)   loss = 0.03290531039237976
# EPOCH(1)   loss = 0.03161033242940903
# EPOCH(1)   loss = 0.03778907284140587
# EPOCH(1)   loss = 0.034219227731227875
# EPOCH(1)   loss = 0.03972936421632767
# EPOCH(1)   loss = 0.03916143625974655
# EPOCH(1)   loss = 0.030784443020820618
# EPOCH(1)   loss = 0.039129696786403656
# EPOCH(1)   loss = 0.03411029279232025
# EPOCH(1)   loss = 0.03394932672381401
# EPOCH(1)   loss = 0.039201393723487854
# EPOCH(1)   loss = 0.030688678845763206
# EPOCH(1)   loss = 0.03758200630545616
# EPOCH(1)   loss = 0.029242778196930885
# EPOCH(1)   loss = 0.040092915296554565
# EPOCH(1)   loss = 0.033558107912540436
# EPOCH(1)   loss = 0.03334488719701767
# EPOCH(1)   loss = 0.030457478016614914
# EPOCH(1)   loss = 0.03409198671579361
# EPOCH(1)   loss = 0.03778752312064171
# EPOCH(1)   loss = 0.032038480043411255
# EPOCH(1)   loss = 0.035344529896974564
# EPOCH(1)   loss = 0.03620072454214096
# EPOCH(1)   loss = 0.03509841114282608
# EPOCH(1)   loss = 0.029775217175483704
# EPOCH(1)   loss = 0.02917603589594364
# EPOCH(1)   loss = 0.03132615238428116
# EPOCH(1)   loss = 0.03531079739332199
# EPOCH(1)   loss = 0.028182050213217735
# EPOCH(1)   loss = 0.02898206189274788
# EPOCH(1)   loss = 0.03314006328582764
# EPOCH(1)   loss = 0.04089439660310745
# EPOCH(1)   loss = 0.03596419841051102
# EPOCH(1)   loss = 0.030428549274802208
# EPOCH(1)   loss = 0.02864963375031948
# EPOCH(1)   loss = 0.03996185213327408
# EPOCH(1)   loss = 0.03138360753655434
# EPOCH(1)   loss = 0.037954941391944885
# EPOCH(1)   loss = 0.031036531552672386
# EPOCH(1)   loss = 0.03697574883699417
# EPOCH(1)   loss = 0.03418395668268204
# EPOCH(1)   loss = 0.03122136928141117
# EPOCH(1)   loss = 0.028476685285568237
# EPOCH(1)   loss = 0.03530687093734741
# EPOCH(1)   loss = 0.03249999135732651
# EPOCH(1)   loss = 0.040688496083021164
# EPOCH(1)   loss = 0.03655184060335159
# EPOCH(1)   loss = 0.03471831977367401
# EPOCH(1)   loss = 0.030481362715363503
# EPOCH(1)   loss = 0.031735267490148544
# EPOCH(1)   loss = 0.030950486660003662
# EPOCH(1)   loss = 0.029910599812865257
# EPOCH(1)   loss = 0.02366812899708748
# EPOCH(1)   loss = 0.031179722398519516
# EPOCH(1)   loss = 0.030669182538986206
# EPOCH(1)   loss = 0.031105462461709976
# EPOCH(1)   loss = 0.03381531313061714
# EPOCH(1)   loss = 0.032948922365903854
# EPOCH(1)   loss = 0.029228651896119118
# EPOCH(1)   loss = 0.0337492972612381
# EPOCH(1)   loss = 0.037984974682331085
# EPOCH(1)   loss = 0.03025788627564907
# EPOCH(1)   loss = 0.03919368237257004
# EPOCH(1)   loss = 0.03503159433603287
# EPOCH(1)   loss = 0.02963973954319954
# EPOCH(1)   loss = 0.02787281572818756
# EPOCH(1)   loss = 0.026469480246305466
# EPOCH(1)   loss = 0.036520928144454956
# EPOCH(1)   loss = 0.031184053048491478
# EPOCH(1)   loss = 0.035531383007764816
# EPOCH(1)   loss = 0.035353872925043106
# EPOCH(1)   loss = 0.030215000733733177
# EPOCH(1)   loss = 0.039629917591810226
# EPOCH(1)   loss = 0.03064073622226715
# EPOCH(1)   loss = 0.033232737332582474
# EPOCH(1)   loss = 0.0351484939455986
# EPOCH(1)   loss = 0.03436150401830673
# EPOCH(1)   loss = 0.03158951550722122
# EPOCH(1)   loss = 0.032252490520477295
# EPOCH(1)   loss = 0.026008471846580505
# EPOCH(1)   loss = 0.03585686534643173
# EPOCH(1)   loss = 0.027565497905015945
# EPOCH(1)   loss = 0.029211750254034996
# EPOCH(1)   loss = 0.03264348953962326
# EPOCH(1)   loss = 0.03678368404507637
# EPOCH(1)   loss = 0.03140518441796303
# EPOCH(1)   loss = 0.030041474848985672
# EPOCH(1)   loss = 0.04361947625875473
# EPOCH(1)   loss = 0.03159160166978836
# EPOCH(1)   loss = 0.03169425576925278
# EPOCH(1)   loss = 0.03330028057098389
# EPOCH(1)   loss = 0.030589625239372253
# EPOCH(1)   loss = 0.03277995064854622
# EPOCH(1)   loss = 0.028636585921049118
# EPOCH(1)   loss = 0.03413868695497513
# EPOCH(1)   loss = 0.03326333314180374
# EPOCH(1)   loss = 0.03368798643350601
# EPOCH(1)   loss = 0.02704017236828804
# EPOCH(1)   loss = 0.030292045325040817
# EPOCH(1)   loss = 0.031238656491041183
# EPOCH(1)   loss = 0.03446177393198013
# EPOCH(1)   loss = 0.0349489226937294
# EPOCH(1)   loss = 0.03313581272959709
# EPOCH(1)   loss = 0.03176473453640938
# EPOCH(1)   loss = 0.029208943247795105
# EPOCH(1)   loss = 0.03510018810629845
# EPOCH(1)   loss = 0.0373038724064827
# EPOCH(1)   loss = 0.032292187213897705
# EPOCH(1)   loss = 0.03179352730512619
# EPOCH(1)   loss = 0.027011241763830185
# EPOCH(1)   loss = 0.03500483185052872
# EPOCH(1)   loss = 0.034231677651405334
# EPOCH(1)   loss = 0.024588514119386673
# EPOCH(1)   loss = 0.02874882146716118
# EPOCH(1)   loss = 0.02932601049542427
# EPOCH(1)   loss = 0.036495141685009
# EPOCH(1)   loss = 0.03515516594052315
# EPOCH(1)   loss = 0.03167689964175224
# EPOCH(1)   loss = 0.03794705867767334
# EPOCH(1)   loss = 0.03176547586917877
# EPOCH(1)   loss = 0.030727500095963478
# EPOCH(1)   loss = 0.03401022404432297
# EPOCH(1)   loss = 0.042923394590616226
# EPOCH(1)   loss = 0.03137598931789398
# EPOCH(1)   loss = 0.03347555920481682
# EPOCH(1)   loss = 0.023345772176980972
# EPOCH(1)   loss = 0.038464728742837906
# EPOCH(1)   loss = 0.03445904329419136
# EPOCH(1)   loss = 0.03246710076928139
# EPOCH(1)   loss = 0.03360021114349365
# EPOCH(1)   loss = 0.026873573660850525
# EPOCH(1)   loss = 0.03488391637802124
# EPOCH(1)   loss = 0.027028735727071762
# EPOCH(1)   loss = 0.03224801644682884
# EPOCH(1)   loss = 0.03461417183279991
# EPOCH(1)   loss = 0.029286522418260574
# EPOCH(1)   loss = 0.02798243798315525
# EPOCH(1)   loss = 0.03156580403447151
# EPOCH(1)   loss = 0.02767239883542061
# EPOCH(1)   loss = 0.03654970973730087
# EPOCH(1)   loss = 0.02694469317793846
# EPOCH(1)   loss = 0.03446730598807335
# EPOCH(1)   loss = 0.02875296212732792
# EPOCH(1)   loss = 0.03187128156423569
# EPOCH(1)   loss = 0.03516959771513939
# EPOCH(1)   loss = 0.033599354326725006
# EPOCH(1)   loss = 0.03137318417429924
# EPOCH(1)   loss = 0.03117692470550537
# EPOCH(1)   loss = 0.029466312378644943
# EPOCH(1)   loss = 0.0304575152695179
# EPOCH(1)   loss = 0.029790127649903297
# EPOCH(1)   loss = 0.03507215529680252
# EPOCH(1)   loss = 0.028624262660741806
# EPOCH(1)   loss = 0.03631081059575081
# EPOCH(1)   loss = 0.038592517375946045
# ...
# EPOCH(2)   loss = 0.01644488237798214
# EPOCH(2)   loss = 0.02550911344587803
# EPOCH(2)   loss = 0.014085936360061169
# EPOCH(2)   loss = 0.02034772001206875
# EPOCH(2)   loss = 0.018412280827760696
# EPOCH(2)   loss = 0.021778618916869164
# EPOCH(2)   loss = 0.017282363027334213
# EPOCH(2)   loss = 0.019186701625585556
# EPOCH(2)   loss = 0.01592549867928028
# EPOCH(2)   loss = 0.023036351427435875
# EPOCH(2)   loss = 0.019158538430929184
# EPOCH(2)   loss = 0.02176174521446228
# EPOCH(2)   loss = 0.01710228994488716
# EPOCH(2)   loss = 0.02055005542933941
# EPOCH(2)   loss = 0.017254041507840157
# EPOCH(2)   loss = 0.020896045491099358
# EPOCH(2)   loss = 0.018676068633794785
# EPOCH(2)   loss = 0.0204634852707386
# EPOCH(2)   loss = 0.01794651336967945
# EPOCH(2)   loss = 0.030257323756814003
# EPOCH(2)   loss = 0.020305948331952095
# EPOCH(2)   loss = 0.024865832179784775
# EPOCH(2)   loss = 0.01986602321267128
# EPOCH(2)   loss = 0.014419564977288246
# EPOCH(2)   loss = 0.025552159175276756
# EPOCH(2)   loss = 0.021465694531798363
# EPOCH(2)   loss = 0.017893033102154732
# EPOCH(2)   loss = 0.01797100342810154
# EPOCH(2)   loss = 0.02018474042415619
# EPOCH(2)   loss = 0.023384440690279007
# EPOCH(2)   loss = 0.0243290476500988
# EPOCH(2)   loss = 0.021677125245332718
# EPOCH(2)   loss = 0.021254483610391617
# EPOCH(2)   loss = 0.022853432223200798
# EPOCH(2)   loss = 0.02342681586742401
# EPOCH(2)   loss = 0.02407253533601761
# EPOCH(2)   loss = 0.020061921328306198
# EPOCH(2)   loss = 0.021794289350509644
# EPOCH(2)   loss = 0.018500391393899918
# EPOCH(2)   loss = 0.026513490825891495
# EPOCH(2)   loss = 0.017415480688214302
# EPOCH(2)   loss = 0.02577941119670868
# EPOCH(2)   loss = 0.01674255169928074
# EPOCH(2)   loss = 0.018855880945920944
# EPOCH(2)   loss = 0.01606045477092266
# EPOCH(2)   loss = 0.018729735165834427
# EPOCH(2)   loss = 0.01667962595820427
# EPOCH(2)   loss = 0.017160065472126007
# EPOCH(2)   loss = 0.020226454362273216
# EPOCH(2)   loss = 0.022009456530213356
# EPOCH(2)   loss = 0.025446724146604538
# EPOCH(2)   loss = 0.012278567999601364
# EPOCH(2)   loss = 0.016635920852422714
# EPOCH(2)   loss = 0.016417305916547775
# EPOCH(2)   loss = 0.01666155457496643
# EPOCH(2)   loss = 0.019342724233865738
# EPOCH(2)   loss = 0.02263634465634823
# EPOCH(2)   loss = 0.018812645226716995
# EPOCH(2)   loss = 0.014440092258155346
# EPOCH(2)   loss = 0.0146692069247365
# EPOCH(2)   loss = 0.015308922156691551
# EPOCH(2)   loss = 0.01712108962237835
# EPOCH(2)   loss = 0.020727908238768578
# EPOCH(2)   loss = 0.018416190519928932
# EPOCH(2)   loss = 0.02284456603229046
# EPOCH(2)   loss = 0.017982106655836105
# EPOCH(2)   loss = 0.018827270716428757
# EPOCH(2)   loss = 0.021354559808969498
# EPOCH(2)   loss = 0.02143549919128418
# EPOCH(2)   loss = 0.020360741764307022
# EPOCH(2)   loss = 0.015441338531672955
# EPOCH(2)   loss = 0.015953291207551956
# EPOCH(2)   loss = 0.02054164744913578
# EPOCH(2)   loss = 0.01571829989552498
# EPOCH(2)   loss = 0.01554457563906908
# EPOCH(2)   loss = 0.023526305332779884
# EPOCH(2)   loss = 0.02356301061809063
# EPOCH(2)   loss = 0.01102254819124937
# EPOCH(2)   loss = 0.013592889532446861
# EPOCH(2)   loss = 0.02007099986076355
# EPOCH(2)   loss = 0.014432852156460285
# EPOCH(2)   loss = 0.018338650465011597
# EPOCH(2)   loss = 0.025261232629418373
# EPOCH(2)   loss = 0.019646411761641502
# EPOCH(2)   loss = 0.0249332282692194
# EPOCH(2)   loss = 0.017860153689980507
# EPOCH(2)   loss = 0.020386070013046265
# EPOCH(2)   loss = 0.02016076073050499
# EPOCH(2)   loss = 0.015902044251561165
# EPOCH(2)   loss = 0.013438694179058075
# EPOCH(2)   loss = 0.015895012766122818
# EPOCH(2)   loss = 0.016725314781069756
# EPOCH(2)   loss = 0.02151832915842533
# EPOCH(2)   loss = 0.024926725775003433
# EPOCH(2)   loss = 0.01685149595141411
# EPOCH(2)   loss = 0.013995069079101086
# EPOCH(2)   loss = 0.017430415377020836
# EPOCH(2)   loss = 0.022124746814370155
# EPOCH(2)   loss = 0.01903534308075905
# EPOCH(2)   loss = 0.01968441903591156
# EPOCH(2)   loss = 0.017862899228930473
# EPOCH(2)   loss = 0.017700161784887314
# EPOCH(2)   loss = 0.020999576896429062
# EPOCH(2)   loss = 0.023053670302033424
# EPOCH(2)   loss = 0.017072971910238266
# EPOCH(2)   loss = 0.014828796498477459
# EPOCH(2)   loss = 0.020500417798757553
# EPOCH(2)   loss = 0.016148295253515244
# EPOCH(2)   loss = 0.021333307027816772
# EPOCH(2)   loss = 0.01326783187687397
# EPOCH(2)   loss = 0.014617634937167168
# EPOCH(2)   loss = 0.0148619394749403
# EPOCH(2)   loss = 0.02208849973976612
# EPOCH(2)   loss = 0.017444021999835968
# EPOCH(2)   loss = 0.01866845041513443
# EPOCH(2)   loss = 0.023703834041953087
# EPOCH(2)   loss = 0.02209988236427307
# EPOCH(2)   loss = 0.017577480524778366
# EPOCH(2)   loss = 0.018769502639770508
# EPOCH(2)   loss = 0.017099663615226746
# EPOCH(2)   loss = 0.014440760016441345
# EPOCH(2)   loss = 0.019039634615182877
# EPOCH(2)   loss = 0.015013724565505981
# EPOCH(2)   loss = 0.01726371794939041
# EPOCH(2)   loss = 0.019614756107330322
# EPOCH(2)   loss = 0.018456146121025085
# EPOCH(2)   loss = 0.01768193393945694
# EPOCH(2)   loss = 0.02026279829442501
# EPOCH(2)   loss = 0.014573737978935242
# EPOCH(2)   loss = 0.0206072349101305
# EPOCH(2)   loss = 0.01799163781106472
# EPOCH(2)   loss = 0.02084413170814514
# EPOCH(2)   loss = 0.022918006405234337
# EPOCH(2)   loss = 0.018156275153160095
# EPOCH(2)   loss = 0.022831551730632782
# EPOCH(2)   loss = 0.02163296937942505
# EPOCH(2)   loss = 0.02100718766450882
# EPOCH(2)   loss = 0.01746312528848648
# EPOCH(2)   loss = 0.024306584149599075
# EPOCH(2)   loss = 0.02374224178493023
# EPOCH(2)   loss = 0.02523479424417019
# EPOCH(2)   loss = 0.019501909613609314
# EPOCH(2)   loss = 0.009935307316482067
# EPOCH(2)   loss = 0.018751824274659157
# EPOCH(2)   loss = 0.015908246859908104
# EPOCH(2)   loss = 0.013170110061764717
# EPOCH(2)   loss = 0.012921899557113647
# EPOCH(2)   loss = 0.020233523100614548
# EPOCH(2)   loss = 0.015960419550538063
# EPOCH(2)   loss = 0.02680566906929016
# EPOCH(2)   loss = 0.020043635740876198
# EPOCH(2)   loss = 0.014058127999305725
# EPOCH(2)   loss = 0.02269097790122032
# EPOCH(2)   loss = 0.016658689826726913
# EPOCH(2)   loss = 0.02049953117966652
# EPOCH(2)   loss = 0.01615029200911522
# EPOCH(2)   loss = 0.016325384378433228
# EPOCH(2)   loss = 0.02018573507666588
# EPOCH(2)   loss = 0.020181231200695038
# EPOCH(2)   loss = 0.017168421298265457
# EPOCH(2)   loss = 0.013779248110949993
# EPOCH(2)   loss = 0.02058175578713417
# EPOCH(2)   loss = 0.023839768022298813
# EPOCH(2)   loss = 0.019234584644436836
# EPOCH(2)   loss = 0.026324382051825523
# EPOCH(2)   loss = 0.021586960181593895
# EPOCH(2)   loss = 0.022149773314595222
# EPOCH(2)   loss = 0.01576102152466774
# EPOCH(2)   loss = 0.015938380733132362
# EPOCH(2)   loss = 0.014776361174881458
# EPOCH(2)   loss = 0.021333927288651466
# EPOCH(2)   loss = 0.01735101081430912
# EPOCH(2)   loss = 0.015080692246556282
# EPOCH(2)   loss = 0.011601225472986698
# EPOCH(2)   loss = 0.018210669979453087
# EPOCH(2)   loss = 0.018318599089980125
# EPOCH(2)   loss = 0.013774067163467407
# EPOCH(2)   loss = 0.018281493335962296
# EPOCH(2)   loss = 0.01891232468187809
# EPOCH(2)   loss = 0.017371857538819313
# EPOCH(2)   loss = 0.016082042828202248
# EPOCH(2)   loss = 0.01821577176451683
# EPOCH(2)   loss = 0.018795572221279144
# EPOCH(2)   loss = 0.014387249946594238
# EPOCH(2)   loss = 0.016534507274627686
# EPOCH(2)   loss = 0.019037632271647453
# EPOCH(2)   loss = 0.023065442219376564
# EPOCH(2)   loss = 0.020148422569036484
# EPOCH(2)   loss = 0.017647583037614822
# EPOCH(2)   loss = 0.020398491993546486
# EPOCH(2)   loss = 0.015796314924955368
# EPOCH(2)   loss = 0.014711558818817139
# EPOCH(2)   loss = 0.028437474742531776
# EPOCH(2)   loss = 0.0248310174793005
# EPOCH(2)   loss = 0.023448480293154716
# EPOCH(2)   loss = 0.026304855942726135
# EPOCH(2)   loss = 0.01578231155872345
# EPOCH(2)   loss = 0.018471425399184227
# EPOCH(2)   loss = 0.019819756969809532
# EPOCH(2)   loss = 0.01916196011006832
# EPOCH(2)   loss = 0.016867684200406075
# EPOCH(2)   loss = 0.022688422352075577
# EPOCH(2)   loss = 0.013793031685054302
# EPOCH(2)   loss = 0.01636623963713646
# EPOCH(2)   loss = 0.02174006961286068
# EPOCH(2)   loss = 0.01650768145918846
# EPOCH(2)   loss = 0.01640516333281994
# EPOCH(2)   loss = 0.014574587345123291
# EPOCH(2)   loss = 0.018738800659775734
# EPOCH(2)   loss = 0.016351420432329178
# EPOCH(2)   loss = 0.018109066411852837
# EPOCH(2)   loss = 0.015500495210289955
# EPOCH(2)   loss = 0.02048768475651741
# EPOCH(2)   loss = 0.01840311288833618
# EPOCH(2)   loss = 0.021778594702482224
# EPOCH(2)   loss = 0.01350291259586811
# EPOCH(2)   loss = 0.014887982979416847
# EPOCH(2)   loss = 0.01645512320101261
# EPOCH(2)   loss = 0.014659421518445015
# EPOCH(2)   loss = 0.01974187046289444
# EPOCH(2)   loss = 0.015817787498235703
# EPOCH(2)   loss = 0.026078075170516968
# EPOCH(2)   loss = 0.017295777797698975
# EPOCH(2)   loss = 0.019796153530478477
# EPOCH(2)   loss = 0.025312725454568863
# EPOCH(2)   loss = 0.022115152329206467
# EPOCH(2)   loss = 0.017347296699881554
# EPOCH(2)   loss = 0.017460249364376068
# EPOCH(2)   loss = 0.018143337219953537
# EPOCH(2)   loss = 0.02577057108283043
# EPOCH(2)   loss = 0.021644659340381622
# EPOCH(2)   loss = 0.020937155932188034
# EPOCH(2)   loss = 0.019563734531402588
# EPOCH(2)   loss = 0.026150483638048172
# EPOCH(2)   loss = 0.023449687287211418
# EPOCH(2)   loss = 0.019996877759695053
# EPOCH(2)   loss = 0.025369565933942795
# EPOCH(2)   loss = 0.020754393190145493
# EPOCH(2)   loss = 0.012301092967391014
# EPOCH(2)   loss = 0.023915013298392296
# EPOCH(2)   loss = 0.02002285048365593
# EPOCH(2)   loss = 0.020893607288599014
# EPOCH(2)   loss = 0.02246187999844551
# EPOCH(2)   loss = 0.01839674450457096
# EPOCH(2)   loss = 0.015970494598150253
# EPOCH(2)   loss = 0.013693195767700672
# EPOCH(2)   loss = 0.01721409149467945
# EPOCH(2)   loss = 0.017475550994277
# EPOCH(2)   loss = 0.018968988209962845
# EPOCH(2)   loss = 0.018112344667315483
# EPOCH(2)   loss = 0.017898503690958023
# EPOCH(2)   loss = 0.01773824915289879
# EPOCH(2)   loss = 0.016355272382497787
# EPOCH(2)   loss = 0.020778020843863487
# EPOCH(2)   loss = 0.028773942962288857
# EPOCH(2)   loss = 0.016743119806051254
# EPOCH(2)   loss = 0.0188799649477005
# EPOCH(2)   loss = 0.014763951301574707
# EPOCH(2)   loss = 0.014707979746162891
# EPOCH(2)   loss = 0.02137470617890358
# EPOCH(2)   loss = 0.021990593522787094
# EPOCH(2)   loss = 0.021941903978586197
# EPOCH(2)   loss = 0.013329202309250832
# EPOCH(2)   loss = 0.016725584864616394
# EPOCH(2)   loss = 0.01730058342218399
# EPOCH(2)   loss = 0.021151220425963402
# EPOCH(2)   loss = 0.018245337530970573
# EPOCH(2)   loss = 0.018728289753198624
# EPOCH(2)   loss = 0.01550774835050106
# EPOCH(2)   loss = 0.020482808351516724
# EPOCH(2)   loss = 0.01314680464565754
# EPOCH(2)   loss = 0.02439415454864502
# EPOCH(2)   loss = 0.018668821081519127
# EPOCH(2)   loss = 0.022436777129769325
# EPOCH(2)   loss = 0.015345269814133644
# EPOCH(2)   loss = 0.03333412483334541
# EPOCH(2)   loss = 0.012961344793438911
# EPOCH(2)   loss = 0.019167400896549225
# EPOCH(2)   loss = 0.0202962514013052
# EPOCH(2)   loss = 0.016071302816271782
# EPOCH(2)   loss = 0.01894903928041458
# EPOCH(2)   loss = 0.026483118534088135
# EPOCH(2)   loss = 0.015437786467373371
# EPOCH(2)   loss = 0.01689189486205578
# EPOCH(2)   loss = 0.020939208567142487
# EPOCH(2)   loss = 0.025182466953992844
# EPOCH(2)   loss = 0.01936899684369564
# EPOCH(2)   loss = 0.01692425273358822
# EPOCH(2)   loss = 0.022791622206568718
# EPOCH(2)   loss = 0.017045434564352036
# EPOCH(2)   loss = 0.023022616282105446
# EPOCH(2)   loss = 0.01867833361029625
# EPOCH(2)   loss = 0.02731468714773655
# EPOCH(2)   loss = 0.017076406627893448
# EPOCH(2)   loss = 0.01456208061426878
# EPOCH(2)   loss = 0.021015692502260208
# EPOCH(2)   loss = 0.016937758773565292
# EPOCH(2)   loss = 0.019700925797224045
# EPOCH(2)   loss = 0.01947666145861149
# EPOCH(2)   loss = 0.020006870850920677
# EPOCH(2)   loss = 0.017985353246331215
# EPOCH(2)   loss = 0.020473893731832504
# EPOCH(2)   loss = 0.02190661057829857
# EPOCH(2)   loss = 0.022383032366633415
# EPOCH(2)   loss = 0.023483049124479294
# EPOCH(2)   loss = 0.021084925159811974
# EPOCH(2)   loss = 0.02721603587269783
# EPOCH(2)   loss = 0.017225569114089012
# EPOCH(2)   loss = 0.015841620042920113
# EPOCH(2)   loss = 0.01332932896912098
# EPOCH(2)   loss = 0.021250175312161446
# EPOCH(2)   loss = 0.02603035792708397
# EPOCH(2)   loss = 0.01453210599720478
# EPOCH(2)   loss = 0.018182775005698204
# EPOCH(2)   loss = 0.01710401102900505
# EPOCH(2)   loss = 0.01741248369216919
# EPOCH(2)   loss = 0.016465405002236366
# EPOCH(2)   loss = 0.018886109814047813
# EPOCH(2)   loss = 0.026209410279989243
# EPOCH(2)   loss = 0.014251923188567162
# EPOCH(2)   loss = 0.015745436772704124
# EPOCH(2)   loss = 0.008834242820739746
# EPOCH(2)   loss = 0.027283290401101112
# EPOCH(2)   loss = 0.023991893976926804
# EPOCH(2)   loss = 0.02363581582903862
# EPOCH(2)   loss = 0.01647612452507019
# EPOCH(2)   loss = 0.01846276968717575
# EPOCH(2)   loss = 0.01886659860610962
# EPOCH(2)   loss = 0.0231150034815073
# EPOCH(2)   loss = 0.01665913313627243
# EPOCH(2)   loss = 0.015763964504003525
# EPOCH(2)   loss = 0.019476640969514847
# EPOCH(2)   loss = 0.019816838204860687
# EPOCH(2)   loss = 0.01985813118517399
# EPOCH(2)   loss = 0.02022203803062439
# EPOCH(2)   loss = 0.009191331453621387
# EPOCH(2)   loss = 0.021753719076514244
# EPOCH(2)   loss = 0.01784970983862877
# EPOCH(2)   loss = 0.016346406191587448
# EPOCH(2)   loss = 0.024223094806075096
# EPOCH(2)   loss = 0.013530595228075981
# EPOCH(2)   loss = 0.018415380269289017
# EPOCH(2)   loss = 0.018076123669743538
# EPOCH(2)   loss = 0.017227359116077423
# EPOCH(2)   loss = 0.020892878994345665
# EPOCH(2)   loss = 0.022834010422229767
# EPOCH(2)   loss = 0.02509731613099575
# EPOCH(2)   loss = 0.015360387973487377
# EPOCH(2)   loss = 0.021433977410197258
# EPOCH(2)   loss = 0.023248333483934402
# EPOCH(2)   loss = 0.016113344579935074
# EPOCH(2)   loss = 0.016901645809412003
# EPOCH(2)   loss = 0.017814762890338898
# EPOCH(2)   loss = 0.012282202951610088
# EPOCH(2)   loss = 0.019570376724004745
# EPOCH(2)   loss = 0.013295881450176239
# EPOCH(2)   loss = 0.016797591000795364
# EPOCH(2)   loss = 0.012074552476406097
# EPOCH(2)   loss = 0.0250483937561512
# EPOCH(2)   loss = 0.017977163195610046
# EPOCH(2)   loss = 0.023464161902666092
# EPOCH(2)   loss = 0.017438940703868866
# EPOCH(2)   loss = 0.013653604313731194
# EPOCH(2)   loss = 0.016905665397644043
# EPOCH(2)   loss = 0.024123093113303185
# EPOCH(2)   loss = 0.01348752249032259
# EPOCH(2)   loss = 0.027351949363946915
# EPOCH(2)   loss = 0.014193008653819561
# EPOCH(2)   loss = 0.01567261852324009
# EPOCH(2)   loss = 0.014432920143008232
# EPOCH(2)   loss = 0.01541260164231062
# EPOCH(2)   loss = 0.015067210420966148
# EPOCH(2)   loss = 0.019117483869194984
# EPOCH(2)   loss = 0.01492193154990673
# EPOCH(2)   loss = 0.021434243768453598
# EPOCH(2)   loss = 0.013063875027000904
# EPOCH(2)   loss = 0.022734593600034714
# EPOCH(2)   loss = 0.019562430679798126
# EPOCH(2)   loss = 0.01833321526646614
# EPOCH(2)   loss = 0.017196789383888245
# EPOCH(2)   loss = 0.015114666894078255
# EPOCH(2)   loss = 0.01595676876604557
# EPOCH(2)   loss = 0.018048442900180817
# EPOCH(2)   loss = 0.024092257022857666
# EPOCH(2)   loss = 0.019378697499632835
# EPOCH(2)   loss = 0.015016796067357063
# EPOCH(2)   loss = 0.011754974722862244
# EPOCH(2)   loss = 0.019082559272646904
# EPOCH(2)   loss = 0.016287975013256073
# EPOCH(2)   loss = 0.018910732120275497
# EPOCH(2)   loss = 0.02291851118206978
# EPOCH(2)   loss = 0.022033512592315674
# EPOCH(2)   loss = 0.012825866229832172
# EPOCH(2)   loss = 0.023924091830849648
# EPOCH(2)   loss = 0.024363305419683456
# EPOCH(2)   loss = 0.015691645443439484
# EPOCH(2)   loss = 0.01437829714268446
# EPOCH(2)   loss = 0.01361561007797718
# EPOCH(2)   loss = 0.021269675344228745
# EPOCH(2)   loss = 0.019970044493675232
# EPOCH(2)   loss = 0.015049993991851807
# EPOCH(2)   loss = 0.01475998293608427
# EPOCH(2)   loss = 0.017380982637405396
# EPOCH(2)   loss = 0.01951904594898224
# EPOCH(2)   loss = 0.015398670919239521
# EPOCH(2)   loss = 0.02293713018298149
# EPOCH(2)   loss = 0.014262894168496132
# EPOCH(2)   loss = 0.021464668214321136
# EPOCH(2)   loss = 0.02298842743039131
# EPOCH(2)   loss = 0.017784029245376587
# EPOCH(2)   loss = 0.015518033877015114
# EPOCH(2)   loss = 0.017892977222800255
# EPOCH(2)   loss = 0.018572773784399033

# %%
sum = 0
# test：
for i, data in enumerate(test_loader):

    x, y = data
    # 这里 仅对 x 进行处理
    x = x.view(x.size(0), 784)
    x, y = x.to(device), y.to(device)
    res = model(x).to(device)
    # 得到 模型预测值
    r = torch.argmax(res)
    # 标签，即真实值
    l = y.item()
    sum += 1 if r == l else 0
    print(f'test({i})     DNN:{r} -- label:{l}')

print('accuracy：', sum / 10000)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# test(5001)     DNN:8 -- label:8
# test(5002)     DNN:3 -- label:3
# test(5003)     DNN:2 -- label:2
# test(5004)     DNN:1 -- label:1
# test(5005)     DNN:3 -- label:3
# test(5006)     DNN:6 -- label:6
# test(5007)     DNN:3 -- label:3
# test(5008)     DNN:9 -- label:9
# test(5009)     DNN:1 -- label:1
# test(5010)     DNN:7 -- label:7
# test(5011)     DNN:1 -- label:1
# test(5012)     DNN:7 -- label:7
# test(5013)     DNN:6 -- label:6
# test(5014)     DNN:8 -- label:8
# test(5015)     DNN:0 -- label:0
# test(5016)     DNN:5 -- label:5
# test(5017)     DNN:3 -- label:3
# test(5018)     DNN:2 -- label:2
# test(5019)     DNN:5 -- label:5
# test(5020)     DNN:7 -- label:7
# test(5021)     DNN:6 -- label:6
# test(5022)     DNN:3 -- label:3
# test(5023)     DNN:0 -- label:0
# test(5024)     DNN:0 -- label:0
# test(5025)     DNN:2 -- label:6
# test(5026)     DNN:2 -- label:2
# test(5027)     DNN:1 -- label:1
# test(5028)     DNN:2 -- label:2
# test(5029)     DNN:8 -- label:8
# test(5030)     DNN:6 -- label:6
# test(5031)     DNN:7 -- label:7
# test(5032)     DNN:9 -- label:9
# test(5033)     DNN:7 -- label:7
# test(5034)     DNN:1 -- label:1
# test(5035)     DNN:5 -- label:5
# test(5036)     DNN:6 -- label:6
# test(5037)     DNN:2 -- label:2
# test(5038)     DNN:1 -- label:1
# test(5039)     DNN:4 -- label:4
# test(5040)     DNN:7 -- label:7
# test(5041)     DNN:1 -- label:1
# test(5042)     DNN:0 -- label:0
# test(5043)     DNN:7 -- label:7
# test(5044)     DNN:1 -- label:1
# test(5045)     DNN:1 -- label:1
# test(5046)     DNN:8 -- label:8
# test(5047)     DNN:0 -- label:0
# test(5048)     DNN:2 -- label:2
# test(5049)     DNN:6 -- label:4
# test(5050)     DNN:8 -- label:8
# test(5051)     DNN:2 -- label:2
# test(5052)     DNN:3 -- label:3
# test(5053)     DNN:1 -- label:1
# test(5054)     DNN:5 -- label:5
# test(5055)     DNN:6 -- label:6
# test(5056)     DNN:5 -- label:5
# test(5057)     DNN:9 -- label:9
# test(5058)     DNN:5 -- label:5
# test(5059)     DNN:8 -- label:8
# test(5060)     DNN:6 -- label:6
# test(5061)     DNN:8 -- label:8
# test(5062)     DNN:4 -- label:4
# test(5063)     DNN:4 -- label:4
# test(5064)     DNN:1 -- label:1
# test(5065)     DNN:1 -- label:1
# test(5066)     DNN:8 -- label:3
# test(5067)     DNN:4 -- label:4
# test(5068)     DNN:9 -- label:9
# test(5069)     DNN:1 -- label:1
# test(5070)     DNN:2 -- label:2
# test(5071)     DNN:5 -- label:5
# test(5072)     DNN:1 -- label:1
# test(5073)     DNN:0 -- label:0
# test(5074)     DNN:0 -- label:0
# test(5075)     DNN:0 -- label:0
# test(5076)     DNN:0 -- label:0
# test(5077)     DNN:8 -- label:9
# test(5078)     DNN:9 -- label:7
# test(5079)     DNN:1 -- label:1
# test(5080)     DNN:1 -- label:1
# test(5081)     DNN:7 -- label:7
# test(5082)     DNN:1 -- label:1
# test(5083)     DNN:0 -- label:0
# test(5084)     DNN:1 -- label:1
# test(5085)     DNN:1 -- label:1
# test(5086)     DNN:1 -- label:1
# test(5087)     DNN:7 -- label:7
# test(5088)     DNN:6 -- label:6
# test(5089)     DNN:7 -- label:7
# test(5090)     DNN:0 -- label:0
# test(5091)     DNN:4 -- label:4
# test(5092)     DNN:9 -- label:9
# test(5093)     DNN:4 -- label:4
# test(5094)     DNN:2 -- label:2
# test(5095)     DNN:9 -- label:7
# test(5096)     DNN:3 -- label:3
# test(5097)     DNN:0 -- label:0
# test(5098)     DNN:2 -- label:2
# test(5099)     DNN:8 -- label:2
# test(5100)     DNN:9 -- label:9
# test(5101)     DNN:3 -- label:3
# test(5102)     DNN:9 -- label:9
# test(5103)     DNN:6 -- label:6
# test(5104)     DNN:3 -- label:3
# test(5105)     DNN:7 -- label:7
# test(5106)     DNN:3 -- label:3
# test(5107)     DNN:9 -- label:9
# test(5108)     DNN:4 -- label:4
# test(5109)     DNN:0 -- label:0
# test(5110)     DNN:2 -- label:2
# test(5111)     DNN:2 -- label:2
# test(5112)     DNN:2 -- label:2
# test(5113)     DNN:1 -- label:1
# test(5114)     DNN:7 -- label:7
# test(5115)     DNN:4 -- label:4
# test(5116)     DNN:9 -- label:9
# test(5117)     DNN:6 -- label:5
# test(5118)     DNN:7 -- label:7
# test(5119)     DNN:4 -- label:9
# test(5120)     DNN:8 -- label:3
# test(5121)     DNN:8 -- label:8
# test(5122)     DNN:7 -- label:7
# test(5123)     DNN:7 -- label:7
# test(5124)     DNN:3 -- label:5
# test(5125)     DNN:4 -- label:4
# test(5126)     DNN:7 -- label:7
# test(5127)     DNN:8 -- label:8
# test(5128)     DNN:8 -- label:8
# test(5129)     DNN:1 -- label:1
# test(5130)     DNN:5 -- label:5
# test(5131)     DNN:7 -- label:7
# test(5132)     DNN:4 -- label:4
# test(5133)     DNN:7 -- label:9
# test(5134)     DNN:4 -- label:4
# test(5135)     DNN:5 -- label:5
# test(5136)     DNN:8 -- label:8
# test(5137)     DNN:5 -- label:5
# test(5138)     DNN:4 -- label:4
# test(5139)     DNN:1 -- label:1
# test(5140)     DNN:7 -- label:7
# test(5141)     DNN:7 -- label:7
# test(5142)     DNN:0 -- label:0
# test(5143)     DNN:4 -- label:4
# test(5144)     DNN:5 -- label:5
# test(5145)     DNN:7 -- label:7
# test(5146)     DNN:5 -- label:5
# test(5147)     DNN:3 -- label:3
# test(5148)     DNN:0 -- label:0
# test(5149)     DNN:3 -- label:3
# test(5150)     DNN:9 -- label:9
# test(5151)     DNN:3 -- label:3
# test(5152)     DNN:3 -- label:3
# test(5153)     DNN:0 -- label:0
# test(5154)     DNN:4 -- label:4
# test(5155)     DNN:7 -- label:9
# test(5156)     DNN:6 -- label:6
# test(5157)     DNN:7 -- label:7
# test(5158)     DNN:4 -- label:4
# test(5159)     DNN:3 -- label:3
# test(5160)     DNN:0 -- label:0
# test(5161)     DNN:1 -- label:1
# test(5162)     DNN:6 -- label:6
# test(5163)     DNN:0 -- label:0
# test(5164)     DNN:2 -- label:2
# test(5165)     DNN:4 -- label:4
# test(5166)     DNN:4 -- label:4
# test(5167)     DNN:6 -- label:6
# test(5168)     DNN:9 -- label:9
# test(5169)     DNN:2 -- label:2
# test(5170)     DNN:4 -- label:4
# test(5171)     DNN:8 -- label:8
# test(5172)     DNN:6 -- label:6
# test(5173)     DNN:6 -- label:6
# test(5174)     DNN:1 -- label:1
# test(5175)     DNN:3 -- label:3
# test(5176)     DNN:7 -- label:7
# test(5177)     DNN:0 -- label:0
# test(5178)     DNN:0 -- label:0
# test(5179)     DNN:1 -- label:1
# test(5180)     DNN:6 -- label:6
# test(5181)     DNN:1 -- label:7
# test(5182)     DNN:8 -- label:3
# test(5183)     DNN:5 -- label:5
# test(5184)     DNN:9 -- label:9
# test(5185)     DNN:3 -- label:3
# test(5186)     DNN:0 -- label:0
# test(5187)     DNN:9 -- label:9
# test(5188)     DNN:3 -- label:2
# test(5189)     DNN:7 -- label:7
# test(5190)     DNN:5 -- label:5
# test(5191)     DNN:7 -- label:7
# test(5192)     DNN:1 -- label:1
# test(5193)     DNN:2 -- label:2
# test(5194)     DNN:9 -- label:9
# test(5195)     DNN:5 -- label:5
# test(5196)     DNN:1 -- label:1
# test(5197)     DNN:7 -- label:7
# test(5198)     DNN:9 -- label:9
# test(5199)     DNN:9 -- label:9
# test(5200)     DNN:7 -- label:7
# test(5201)     DNN:1 -- label:1
# test(5202)     DNN:6 -- label:6
# test(5203)     DNN:2 -- label:2
# test(5204)     DNN:8 -- label:8
# test(5205)     DNN:3 -- label:3
# test(5206)     DNN:0 -- label:9
# test(5207)     DNN:3 -- label:3
# test(5208)     DNN:3 -- label:3
# test(5209)     DNN:1 -- label:1
# test(5210)     DNN:5 -- label:5
# test(5211)     DNN:3 -- label:9
# test(5212)     DNN:7 -- label:7
# test(5213)     DNN:3 -- label:3
# test(5214)     DNN:4 -- label:7
# test(5215)     DNN:2 -- label:2
# test(5216)     DNN:1 -- label:1
# test(5217)     DNN:8 -- label:8
# test(5218)     DNN:1 -- label:1
# test(5219)     DNN:4 -- label:4
# test(5220)     DNN:5 -- label:5
# test(5221)     DNN:9 -- label:9
# test(5222)     DNN:0 -- label:0
# test(5223)     DNN:7 -- label:8
# test(5224)     DNN:9 -- label:9
# test(5225)     DNN:0 -- label:0
# test(5226)     DNN:2 -- label:2
# test(5227)     DNN:9 -- label:9
# test(5228)     DNN:7 -- label:7
# test(5229)     DNN:7 -- label:7
# test(5230)     DNN:8 -- label:3
# test(5231)     DNN:2 -- label:2
# test(5232)     DNN:8 -- label:8
# test(5233)     DNN:9 -- label:9
# test(5234)     DNN:8 -- label:8
# test(5235)     DNN:2 -- label:2
# test(5236)     DNN:4 -- label:4
# test(5237)     DNN:7 -- label:7
# test(5238)     DNN:3 -- label:9
# test(5239)     DNN:8 -- label:8
# test(5240)     DNN:4 -- label:9
# test(5241)     DNN:7 -- label:2
# test(5242)     DNN:9 -- label:9
# test(5243)     DNN:1 -- label:1
# test(5244)     DNN:2 -- label:2
# test(5245)     DNN:1 -- label:1
# test(5246)     DNN:4 -- label:4
# test(5247)     DNN:7 -- label:7
# test(5248)     DNN:0 -- label:0
# test(5249)     DNN:0 -- label:0
# test(5250)     DNN:3 -- label:3
# test(5251)     DNN:2 -- label:2
# test(5252)     DNN:1 -- label:1
# test(5253)     DNN:4 -- label:4
# test(5254)     DNN:3 -- label:3
# test(5255)     DNN:8 -- label:8
# test(5256)     DNN:5 -- label:5
# test(5257)     DNN:2 -- label:2
# test(5258)     DNN:1 -- label:1
# test(5259)     DNN:6 -- label:6
# test(5260)     DNN:5 -- label:5
# test(5261)     DNN:7 -- label:7
# test(5262)     DNN:7 -- label:7
# test(5263)     DNN:5 -- label:5
# test(5264)     DNN:7 -- label:7
# test(5265)     DNN:8 -- label:1
# test(5266)     DNN:8 -- label:8
# test(5267)     DNN:2 -- label:2
# test(5268)     DNN:5 -- label:5
# test(5269)     DNN:5 -- label:5
# test(5270)     DNN:1 -- label:1
# test(5271)     DNN:1 -- label:1
# test(5272)     DNN:5 -- label:5
# test(5273)     DNN:2 -- label:2
# test(5274)     DNN:7 -- label:7
# test(5275)     DNN:5 -- label:5
# test(5276)     DNN:1 -- label:1
# test(5277)     DNN:5 -- label:5
# test(5278)     DNN:1 -- label:1
# test(5279)     DNN:3 -- label:3
# test(5280)     DNN:5 -- label:5
# test(5281)     DNN:4 -- label:4
# test(5282)     DNN:3 -- label:3
# test(5283)     DNN:9 -- label:9
# test(5284)     DNN:8 -- label:8
# test(5285)     DNN:1 -- label:1
# test(5286)     DNN:1 -- label:1
# test(5287)     DNN:9 -- label:9
# test(5288)     DNN:2 -- label:2
# test(5289)     DNN:3 -- label:3
# test(5290)     DNN:8 -- label:8
# test(5291)     DNN:3 -- label:3
# test(5292)     DNN:9 -- label:9
# test(5293)     DNN:2 -- label:2
# test(5294)     DNN:9 -- label:8
# test(5295)     DNN:0 -- label:0
# test(5296)     DNN:8 -- label:8
# test(5297)     DNN:3 -- label:3
# test(5298)     DNN:4 -- label:6
# test(5299)     DNN:9 -- label:9
# test(5300)     DNN:7 -- label:7
# test(5301)     DNN:5 -- label:5
# test(5302)     DNN:3 -- label:3
# test(5303)     DNN:9 -- label:9
# test(5304)     DNN:7 -- label:7
# test(5305)     DNN:9 -- label:9
# test(5306)     DNN:4 -- label:4
# test(5307)     DNN:2 -- label:2
# test(5308)     DNN:8 -- label:8
# test(5309)     DNN:1 -- label:1
# test(5310)     DNN:9 -- label:9
# test(5311)     DNN:1 -- label:1
# test(5312)     DNN:9 -- label:9
# test(5313)     DNN:6 -- label:6
# test(5314)     DNN:3 -- label:3
# test(5315)     DNN:2 -- label:2
# test(5316)     DNN:0 -- label:0
# test(5317)     DNN:3 -- label:5
# test(5318)     DNN:4 -- label:4
# test(5319)     DNN:9 -- label:9
# test(5320)     DNN:0 -- label:0
# test(5321)     DNN:4 -- label:4
# test(5322)     DNN:2 -- label:2
# test(5323)     DNN:3 -- label:3
# test(5324)     DNN:9 -- label:9
# test(5325)     DNN:0 -- label:5
# test(5326)     DNN:9 -- label:9
# test(5327)     DNN:2 -- label:2
# test(5328)     DNN:7 -- label:7
# test(5329)     DNN:9 -- label:7
# test(5330)     DNN:4 -- label:4
# test(5331)     DNN:4 -- label:4
# test(5332)     DNN:5 -- label:5
# test(5333)     DNN:1 -- label:1
# test(5334)     DNN:9 -- label:9
# test(5335)     DNN:4 -- label:4
# test(5336)     DNN:8 -- label:8
# test(5337)     DNN:1 -- label:1
# test(5338)     DNN:6 -- label:6
# test(5339)     DNN:6 -- label:6
# test(5340)     DNN:7 -- label:7
# test(5341)     DNN:8 -- label:8
# test(5342)     DNN:4 -- label:4
# test(5343)     DNN:1 -- label:1
# test(5344)     DNN:3 -- label:3
# test(5345)     DNN:7 -- label:3
# test(5346)     DNN:4 -- label:4
# test(5347)     DNN:8 -- label:8
# test(5348)     DNN:7 -- label:7
# test(5349)     DNN:4 -- label:4
# test(5350)     DNN:6 -- label:8
# test(5351)     DNN:4 -- label:4
# test(5352)     DNN:0 -- label:0
# test(5353)     DNN:2 -- label:2
# test(5354)     DNN:6 -- label:6
# test(5355)     DNN:7 -- label:7
# test(5356)     DNN:1 -- label:1
# test(5357)     DNN:0 -- label:0
# test(5358)     DNN:7 -- label:7
# test(5359)     DNN:6 -- label:6
# test(5360)     DNN:8 -- label:8
# test(5361)     DNN:4 -- label:4
# test(5362)     DNN:6 -- label:6
# test(5363)     DNN:1 -- label:1
# test(5364)     DNN:7 -- label:7
# test(5365)     DNN:1 -- label:1
# test(5366)     DNN:7 -- label:7
# test(5367)     DNN:8 -- label:8
# test(5368)     DNN:3 -- label:3
# test(5369)     DNN:3 -- label:3
# test(5370)     DNN:7 -- label:7
# test(5371)     DNN:3 -- label:3
# test(5372)     DNN:4 -- label:4
# test(5373)     DNN:4 -- label:4
# test(5374)     DNN:6 -- label:6
# test(5375)     DNN:1 -- label:1
# test(5376)     DNN:3 -- label:3
# test(5377)     DNN:3 -- label:3
# test(5378)     DNN:3 -- label:3
# test(5379)     DNN:4 -- label:7
# test(5380)     DNN:8 -- label:8
# test(5381)     DNN:4 -- label:4
# test(5382)     DNN:7 -- label:7
# test(5383)     DNN:7 -- label:7
# test(5384)     DNN:8 -- label:8
# test(5385)     DNN:9 -- label:9
# test(5386)     DNN:6 -- label:6
# test(5387)     DNN:1 -- label:1
# test(5388)     DNN:6 -- label:6
# test(5389)     DNN:6 -- label:6
# test(5390)     DNN:7 -- label:7
# test(5391)     DNN:2 -- label:2
# test(5392)     DNN:2 -- label:2
# test(5393)     DNN:1 -- label:1
# test(5394)     DNN:2 -- label:2
# test(5395)     DNN:4 -- label:4
# test(5396)     DNN:3 -- label:3
# test(5397)     DNN:7 -- label:7
# test(5398)     DNN:5 -- label:5
# test(5399)     DNN:9 -- label:9
# test(5400)     DNN:2 -- label:2
# test(5401)     DNN:0 -- label:0
# test(5402)     DNN:5 -- label:5
# test(5403)     DNN:9 -- label:9
# test(5404)     DNN:6 -- label:6
# test(5405)     DNN:0 -- label:0
# test(5406)     DNN:8 -- label:8
# test(5407)     DNN:1 -- label:1
# test(5408)     DNN:5 -- label:5
# test(5409)     DNN:9 -- label:4
# test(5410)     DNN:9 -- label:4
# test(5411)     DNN:8 -- label:8
# test(5412)     DNN:9 -- label:9
# test(5413)     DNN:1 -- label:1
# test(5414)     DNN:0 -- label:0
# test(5415)     DNN:5 -- label:5
# test(5416)     DNN:9 -- label:9
# test(5417)     DNN:8 -- label:8
# test(5418)     DNN:3 -- label:3
# test(5419)     DNN:0 -- label:0
# test(5420)     DNN:3 -- label:3
# test(5421)     DNN:7 -- label:7
# test(5422)     DNN:5 -- label:5
# test(5423)     DNN:9 -- label:9
# test(5424)     DNN:1 -- label:1
# test(5425)     DNN:3 -- label:3
# test(5426)     DNN:1 -- label:1
# test(5427)     DNN:2 -- label:2
# test(5428)     DNN:5 -- label:5
# test(5429)     DNN:9 -- label:9
# test(5430)     DNN:8 -- label:8
# test(5431)     DNN:9 -- label:8
# test(5432)     DNN:6 -- label:6
# test(5433)     DNN:6 -- label:6
# test(5434)     DNN:6 -- label:6
# test(5435)     DNN:2 -- label:2
# test(5436)     DNN:4 -- label:4
# test(5437)     DNN:4 -- label:4
# test(5438)     DNN:1 -- label:1
# test(5439)     DNN:8 -- label:8
# test(5440)     DNN:2 -- label:2
# test(5441)     DNN:7 -- label:2
# test(5442)     DNN:7 -- label:7
# test(5443)     DNN:3 -- label:5
# test(5444)     DNN:3 -- label:3
# test(5445)     DNN:0 -- label:0
# test(5446)     DNN:4 -- label:4
# test(5447)     DNN:7 -- label:7
# test(5448)     DNN:2 -- label:4
# test(5449)     DNN:3 -- label:3
# test(5450)     DNN:9 -- label:9
# test(5451)     DNN:2 -- label:2
# test(5452)     DNN:2 -- label:2
# test(5453)     DNN:5 -- label:5
# test(5454)     DNN:9 -- label:9
# test(5455)     DNN:0 -- label:9
# test(5456)     DNN:2 -- label:2
# test(5457)     DNN:6 -- label:6
# test(5458)     DNN:5 -- label:5
# test(5459)     DNN:4 -- label:4
# test(5460)     DNN:3 -- label:5
# test(5461)     DNN:7 -- label:7
# test(5462)     DNN:4 -- label:4
# test(5463)     DNN:8 -- label:8
# test(5464)     DNN:1 -- label:1
# test(5465)     DNN:4 -- label:4
# test(5466)     DNN:1 -- label:1
# test(5467)     DNN:6 -- label:6
# test(5468)     DNN:6 -- label:6
# test(5469)     DNN:3 -- label:3
# test(5470)     DNN:2 -- label:2
# test(5471)     DNN:5 -- label:5
# test(5472)     DNN:1 -- label:1
# test(5473)     DNN:9 -- label:9
# test(5474)     DNN:8 -- label:8
# test(5475)     DNN:1 -- label:1
# test(5476)     DNN:5 -- label:5
# test(5477)     DNN:2 -- label:2
# test(5478)     DNN:8 -- label:8
# test(5479)     DNN:2 -- label:2
# test(5480)     DNN:8 -- label:3
# test(5481)     DNN:9 -- label:9
# test(5482)     DNN:8 -- label:8
# test(5483)     DNN:1 -- label:1
# test(5484)     DNN:1 -- label:1
# test(5485)     DNN:0 -- label:5
# test(5486)     DNN:2 -- label:2
# test(5487)     DNN:8 -- label:8
# test(5488)     DNN:3 -- label:3
# test(5489)     DNN:1 -- label:7
# test(5490)     DNN:2 -- label:2
# test(5491)     DNN:7 -- label:7
# test(5492)     DNN:0 -- label:0
# test(5493)     DNN:8 -- label:8
# test(5494)     DNN:5 -- label:5
# test(5495)     DNN:2 -- label:2
# test(5496)     DNN:0 -- label:0
# test(5497)     DNN:0 -- label:0
# test(5498)     DNN:9 -- label:9
# test(5499)     DNN:1 -- label:1
# test(5500)     DNN:6 -- label:6
# test(5501)     DNN:6 -- label:5
# test(5502)     DNN:6 -- label:6
# test(5503)     DNN:9 -- label:9
# test(5504)     DNN:6 -- label:6
# test(5505)     DNN:8 -- label:8
# test(5506)     DNN:6 -- label:6
# test(5507)     DNN:0 -- label:0
# test(5508)     DNN:5 -- label:5
# test(5509)     DNN:7 -- label:7
# test(5510)     DNN:1 -- label:1
# test(5511)     DNN:9 -- label:9
# test(5512)     DNN:8 -- label:8
# test(5513)     DNN:8 -- label:8
# test(5514)     DNN:1 -- label:1
# test(5515)     DNN:1 -- label:1
# test(5516)     DNN:2 -- label:2
# test(5517)     DNN:1 -- label:1
# test(5518)     DNN:3 -- label:3
# test(5519)     DNN:8 -- label:8
# test(5520)     DNN:7 -- label:7
# test(5521)     DNN:2 -- label:2
# test(5522)     DNN:6 -- label:6
# test(5523)     DNN:7 -- label:7
# test(5524)     DNN:3 -- label:3
# test(5525)     DNN:4 -- label:4
# test(5526)     DNN:4 -- label:4
# test(5527)     DNN:6 -- label:6
# test(5528)     DNN:5 -- label:5
# test(5529)     DNN:5 -- label:5
# test(5530)     DNN:2 -- label:2
# test(5531)     DNN:7 -- label:7
# test(5532)     DNN:6 -- label:6
# test(5533)     DNN:9 -- label:9
# test(5534)     DNN:6 -- label:6
# test(5535)     DNN:2 -- label:3
# test(5536)     DNN:1 -- label:1
# test(5537)     DNN:2 -- label:2
# test(5538)     DNN:5 -- label:8
# test(5539)     DNN:1 -- label:1
# test(5540)     DNN:3 -- label:3
# test(5541)     DNN:2 -- label:2
# test(5542)     DNN:3 -- label:3
# test(5543)     DNN:1 -- label:1
# test(5544)     DNN:7 -- label:7
# test(5545)     DNN:1 -- label:1
# test(5546)     DNN:3 -- label:3
# test(5547)     DNN:0 -- label:0
# test(5548)     DNN:8 -- label:8
# test(5549)     DNN:0 -- label:0
# test(5550)     DNN:0 -- label:0
# test(5551)     DNN:6 -- label:6
# test(5552)     DNN:2 -- label:2
# test(5553)     DNN:3 -- label:3
# test(5554)     DNN:7 -- label:7
# test(5555)     DNN:3 -- label:3
# test(5556)     DNN:8 -- label:8
# test(5557)     DNN:1 -- label:1
# test(5558)     DNN:3 -- label:3
# test(5559)     DNN:3 -- label:3
# test(5560)     DNN:1 -- label:1
# test(5561)     DNN:4 -- label:9
# test(5562)     DNN:7 -- label:7
# test(5563)     DNN:9 -- label:8
# test(5564)     DNN:4 -- label:4
# test(5565)     DNN:2 -- label:2
# test(5566)     DNN:3 -- label:3
# test(5567)     DNN:7 -- label:8
# test(5568)     DNN:5 -- label:5
# test(5569)     DNN:5 -- label:5
# test(5570)     DNN:4 -- label:4
# test(5571)     DNN:8 -- label:8
# test(5572)     DNN:9 -- label:9
# test(5573)     DNN:2 -- label:2
# test(5574)     DNN:0 -- label:0
# test(5575)     DNN:7 -- label:7
# test(5576)     DNN:8 -- label:8
# test(5577)     DNN:2 -- label:3
# test(5578)     DNN:4 -- label:4
# test(5579)     DNN:8 -- label:8
# test(5580)     DNN:5 -- label:5
# test(5581)     DNN:8 -- label:8
# test(5582)     DNN:0 -- label:6
# test(5583)     DNN:8 -- label:2
# test(5584)     DNN:0 -- label:0
# test(5585)     DNN:7 -- label:7
# test(5586)     DNN:6 -- label:6
# test(5587)     DNN:6 -- label:6
# test(5588)     DNN:2 -- label:2
# test(5589)     DNN:0 -- label:0
# test(5590)     DNN:1 -- label:1
# test(5591)     DNN:5 -- label:5
# test(5592)     DNN:7 -- label:7
# test(5593)     DNN:0 -- label:0
# test(5594)     DNN:0 -- label:0
# test(5595)     DNN:0 -- label:0
# test(5596)     DNN:9 -- label:9
# test(5597)     DNN:4 -- label:4
# test(5598)     DNN:1 -- label:1
# test(5599)     DNN:3 -- label:5
# test(5600)     DNN:8 -- label:8
# test(5601)     DNN:2 -- label:2
# test(5602)     DNN:0 -- label:0
# test(5603)     DNN:1 -- label:1
# test(5604)     DNN:0 -- label:0
# test(5605)     DNN:8 -- label:8
# test(5606)     DNN:6 -- label:6
# test(5607)     DNN:9 -- label:9
# test(5608)     DNN:7 -- label:8
# test(5609)     DNN:9 -- label:2
# test(5610)     DNN:5 -- label:5
# test(5611)     DNN:4 -- label:4
# test(5612)     DNN:0 -- label:0
# test(5613)     DNN:9 -- label:2
# test(5614)     DNN:5 -- label:5
# test(5615)     DNN:3 -- label:3
# test(5616)     DNN:2 -- label:2
# test(5617)     DNN:8 -- label:8
# test(5618)     DNN:2 -- label:2
# test(5619)     DNN:5 -- label:5
# test(5620)     DNN:8 -- label:8
# test(5621)     DNN:1 -- label:1
# test(5622)     DNN:0 -- label:0
# test(5623)     DNN:4 -- label:4
# test(5624)     DNN:6 -- label:6
# test(5625)     DNN:4 -- label:4
# test(5626)     DNN:8 -- label:8
# test(5627)     DNN:8 -- label:8
# test(5628)     DNN:1 -- label:1
# test(5629)     DNN:0 -- label:0
# test(5630)     DNN:8 -- label:8
# test(5631)     DNN:5 -- label:5
# test(5632)     DNN:0 -- label:0
# test(5633)     DNN:3 -- label:3
# test(5634)     DNN:0 -- label:0
# test(5635)     DNN:8 -- label:8
# test(5636)     DNN:7 -- label:7
# test(5637)     DNN:4 -- label:4
# test(5638)     DNN:0 -- label:0
# test(5639)     DNN:0 -- label:0
# test(5640)     DNN:5 -- label:5
# test(5641)     DNN:0 -- label:0
# test(5642)     DNN:7 -- label:7
# test(5643)     DNN:3 -- label:3
# test(5644)     DNN:7 -- label:7
# test(5645)     DNN:2 -- label:2
# test(5646)     DNN:4 -- label:4
# test(5647)     DNN:9 -- label:9
# test(5648)     DNN:1 -- label:1
# test(5649)     DNN:4 -- label:4
# test(5650)     DNN:6 -- label:6
# test(5651)     DNN:8 -- label:8
# test(5652)     DNN:4 -- label:4
# test(5653)     DNN:9 -- label:9
# test(5654)     DNN:2 -- label:2
# test(5655)     DNN:9 -- label:7
# test(5656)     DNN:5 -- label:5
# test(5657)     DNN:8 -- label:8
# test(5658)     DNN:5 -- label:5
# test(5659)     DNN:8 -- label:8
# test(5660)     DNN:1 -- label:1
# test(5661)     DNN:1 -- label:1
# test(5662)     DNN:4 -- label:4
# test(5663)     DNN:8 -- label:1
# test(5664)     DNN:4 -- label:4
# test(5665)     DNN:0 -- label:0
# test(5666)     DNN:2 -- label:2
# test(5667)     DNN:2 -- label:2
# test(5668)     DNN:4 -- label:4
# test(5669)     DNN:0 -- label:0
# test(5670)     DNN:4 -- label:4
# test(5671)     DNN:0 -- label:0
# test(5672)     DNN:4 -- label:4
# test(5673)     DNN:2 -- label:2
# test(5674)     DNN:0 -- label:0
# test(5675)     DNN:5 -- label:5
# test(5676)     DNN:8 -- label:8
# test(5677)     DNN:0 -- label:0
# test(5678)     DNN:1 -- label:1
# test(5679)     DNN:3 -- label:3
# test(5680)     DNN:3 -- label:3
# test(5681)     DNN:6 -- label:6
# test(5682)     DNN:2 -- label:2
# test(5683)     DNN:1 -- label:1
# test(5684)     DNN:3 -- label:3
# test(5685)     DNN:0 -- label:0
# test(5686)     DNN:5 -- label:6
# test(5687)     DNN:6 -- label:6
# test(5688)     DNN:0 -- label:0
# test(5689)     DNN:5 -- label:5
# test(5690)     DNN:2 -- label:1
# test(5691)     DNN:4 -- label:4
# test(5692)     DNN:5 -- label:5
# test(5693)     DNN:4 -- label:4
# test(5694)     DNN:4 -- label:4
# test(5695)     DNN:4 -- label:4
# test(5696)     DNN:0 -- label:0
# test(5697)     DNN:8 -- label:3
# test(5698)     DNN:9 -- label:9
# test(5699)     DNN:4 -- label:4
# test(5700)     DNN:9 -- label:9
# test(5701)     DNN:8 -- label:8
# test(5702)     DNN:5 -- label:5
# test(5703)     DNN:1 -- label:1
# test(5704)     DNN:6 -- label:6
# test(5705)     DNN:6 -- label:6
# test(5706)     DNN:9 -- label:9
# test(5707)     DNN:5 -- label:5
# test(5708)     DNN:2 -- label:2
# test(5709)     DNN:3 -- label:3
# test(5710)     DNN:8 -- label:8
# test(5711)     DNN:3 -- label:3
# test(5712)     DNN:6 -- label:6
# test(5713)     DNN:9 -- label:9
# test(5714)     DNN:2 -- label:2
# test(5715)     DNN:0 -- label:0
# test(5716)     DNN:2 -- label:2
# test(5717)     DNN:7 -- label:7
# test(5718)     DNN:5 -- label:5
# test(5719)     DNN:5 -- label:5
# test(5720)     DNN:7 -- label:7
# test(5721)     DNN:8 -- label:8
# test(5722)     DNN:8 -- label:8
# test(5723)     DNN:1 -- label:1
# test(5724)     DNN:6 -- label:8
# test(5725)     DNN:4 -- label:4
# test(5726)     DNN:3 -- label:1
# test(5727)     DNN:2 -- label:2
# test(5728)     DNN:1 -- label:1
# test(5729)     DNN:7 -- label:7
# test(5730)     DNN:1 -- label:1
# test(5731)     DNN:1 -- label:1
# test(5732)     DNN:7 -- label:7
# test(5733)     DNN:4 -- label:4
# test(5734)     DNN:3 -- label:3
# test(5735)     DNN:6 -- label:6
# test(5736)     DNN:8 -- label:8
# test(5737)     DNN:3 -- label:3
# test(5738)     DNN:1 -- label:1
# test(5739)     DNN:3 -- label:3
# test(5740)     DNN:1 -- label:1
# test(5741)     DNN:0 -- label:2
# test(5742)     DNN:1 -- label:1
# test(5743)     DNN:7 -- label:7
# test(5744)     DNN:0 -- label:0
# test(5745)     DNN:9 -- label:9
# test(5746)     DNN:1 -- label:1
# test(5747)     DNN:7 -- label:7
# test(5748)     DNN:5 -- label:5
# test(5749)     DNN:3 -- label:3
# test(5750)     DNN:8 -- label:8
# test(5751)     DNN:8 -- label:8
# test(5752)     DNN:9 -- label:9
# test(5753)     DNN:8 -- label:8
# test(5754)     DNN:7 -- label:4
# test(5755)     DNN:9 -- label:9
# test(5756)     DNN:1 -- label:1
# test(5757)     DNN:0 -- label:6
# test(5758)     DNN:9 -- label:9
# test(5759)     DNN:9 -- label:9
# test(5760)     DNN:0 -- label:0
# test(5761)     DNN:1 -- label:1
# test(5762)     DNN:8 -- label:8
# test(5763)     DNN:8 -- label:8
# test(5764)     DNN:8 -- label:5
# test(5765)     DNN:2 -- label:2
# test(5766)     DNN:7 -- label:7
# test(5767)     DNN:3 -- label:3
# test(5768)     DNN:6 -- label:6
# test(5769)     DNN:8 -- label:8
# test(5770)     DNN:1 -- label:1
# test(5771)     DNN:7 -- label:7
# test(5772)     DNN:2 -- label:2
# test(5773)     DNN:6 -- label:6
# test(5774)     DNN:4 -- label:4
# test(5775)     DNN:5 -- label:5
# test(5776)     DNN:9 -- label:9
# test(5777)     DNN:5 -- label:5
# test(5778)     DNN:0 -- label:0
# test(5779)     DNN:1 -- label:1
# test(5780)     DNN:6 -- label:6
# test(5781)     DNN:9 -- label:9
# test(5782)     DNN:9 -- label:9
# test(5783)     DNN:6 -- label:6
# test(5784)     DNN:3 -- label:3
# test(5785)     DNN:4 -- label:4
# test(5786)     DNN:6 -- label:6
# test(5787)     DNN:4 -- label:4
# test(5788)     DNN:6 -- label:6
# test(5789)     DNN:5 -- label:5
# test(5790)     DNN:9 -- label:9
# test(5791)     DNN:7 -- label:7
# test(5792)     DNN:2 -- label:2
# test(5793)     DNN:4 -- label:4
# test(5794)     DNN:7 -- label:2
# test(5795)     DNN:3 -- label:1
# test(5796)     DNN:0 -- label:0
# test(5797)     DNN:2 -- label:2
# test(5798)     DNN:2 -- label:2
# test(5799)     DNN:6 -- label:6
# test(5800)     DNN:0 -- label:0
# test(5801)     DNN:2 -- label:2
# test(5802)     DNN:1 -- label:1
# test(5803)     DNN:7 -- label:9
# test(5804)     DNN:8 -- label:8
# test(5805)     DNN:4 -- label:4
# test(5806)     DNN:0 -- label:0
# test(5807)     DNN:1 -- label:1
# test(5808)     DNN:7 -- label:7
# test(5809)     DNN:2 -- label:2
# test(5810)     DNN:4 -- label:4
# test(5811)     DNN:4 -- label:4
# test(5812)     DNN:1 -- label:1
# test(5813)     DNN:0 -- label:0
# test(5814)     DNN:1 -- label:1
# test(5815)     DNN:0 -- label:0
# test(5816)     DNN:8 -- label:8
# test(5817)     DNN:7 -- label:7
# test(5818)     DNN:2 -- label:2
# test(5819)     DNN:4 -- label:4
# test(5820)     DNN:2 -- label:2
# test(5821)     DNN:8 -- label:2
# test(5822)     DNN:4 -- label:4
# test(5823)     DNN:5 -- label:5
# test(5824)     DNN:1 -- label:1
# test(5825)     DNN:5 -- label:5
# test(5826)     DNN:2 -- label:3
# test(5827)     DNN:2 -- label:2
# test(5828)     DNN:4 -- label:4
# test(5829)     DNN:1 -- label:1
# test(5830)     DNN:7 -- label:7
# test(5831)     DNN:5 -- label:5
# test(5832)     DNN:9 -- label:7
# test(5833)     DNN:4 -- label:4
# test(5834)     DNN:4 -- label:4
# test(5835)     DNN:9 -- label:9
# test(5836)     DNN:8 -- label:8
# test(5837)     DNN:0 -- label:0
# test(5838)     DNN:8 -- label:8
# test(5839)     DNN:5 -- label:5
# test(5840)     DNN:3 -- label:3
# test(5841)     DNN:4 -- label:4
# test(5842)     DNN:4 -- label:4
# test(5843)     DNN:1 -- label:1
# test(5844)     DNN:6 -- label:6
# test(5845)     DNN:8 -- label:8
# test(5846)     DNN:5 -- label:5
# test(5847)     DNN:2 -- label:2
# test(5848)     DNN:3 -- label:3
# test(5849)     DNN:1 -- label:1
# test(5850)     DNN:4 -- label:4
# test(5851)     DNN:7 -- label:7
# test(5852)     DNN:9 -- label:9
# test(5853)     DNN:7 -- label:7
# test(5854)     DNN:9 -- label:9
# test(5855)     DNN:7 -- label:7
# test(5856)     DNN:7 -- label:7
# test(5857)     DNN:4 -- label:9
# test(5858)     DNN:2 -- label:2
# test(5859)     DNN:4 -- label:4
# test(5860)     DNN:5 -- label:5
# test(5861)     DNN:9 -- label:9
# test(5862)     DNN:0 -- label:0
# test(5863)     DNN:8 -- label:2
# test(5864)     DNN:2 -- label:2
# test(5865)     DNN:0 -- label:0
# test(5866)     DNN:3 -- label:3
# test(5867)     DNN:6 -- label:6
# test(5868)     DNN:2 -- label:2
# test(5869)     DNN:9 -- label:9
# test(5870)     DNN:0 -- label:0
# test(5871)     DNN:6 -- label:6
# test(5872)     DNN:7 -- label:7
# test(5873)     DNN:2 -- label:2
# test(5874)     DNN:7 -- label:7
# test(5875)     DNN:6 -- label:6
# test(5876)     DNN:5 -- label:5
# test(5877)     DNN:5 -- label:5
# test(5878)     DNN:4 -- label:4
# test(5879)     DNN:7 -- label:7
# test(5880)     DNN:2 -- label:2
# test(5881)     DNN:2 -- label:2
# test(5882)     DNN:0 -- label:0
# test(5883)     DNN:0 -- label:0
# test(5884)     DNN:0 -- label:9
# test(5885)     DNN:0 -- label:9
# test(5886)     DNN:9 -- label:9
# test(5887)     DNN:7 -- label:7
# test(5888)     DNN:4 -- label:5
# test(5889)     DNN:8 -- label:8
# test(5890)     DNN:2 -- label:2
# test(5891)     DNN:3 -- label:3
# test(5892)     DNN:0 -- label:0
# test(5893)     DNN:7 -- label:7
# test(5894)     DNN:2 -- label:2
# test(5895)     DNN:3 -- label:3
# test(5896)     DNN:0 -- label:0
# test(5897)     DNN:4 -- label:4
# test(5898)     DNN:4 -- label:4
# test(5899)     DNN:9 -- label:9
# test(5900)     DNN:3 -- label:3
# test(5901)     DNN:8 -- label:8
# test(5902)     DNN:6 -- label:6
# test(5903)     DNN:9 -- label:9
# test(5904)     DNN:8 -- label:8
# test(5905)     DNN:1 -- label:1
# test(5906)     DNN:8 -- label:5
# test(5907)     DNN:4 -- label:4
# test(5908)     DNN:1 -- label:1
# test(5909)     DNN:9 -- label:9
# test(5910)     DNN:2 -- label:7
# test(5911)     DNN:6 -- label:2
# test(5912)     DNN:2 -- label:2
# test(5913)     DNN:9 -- label:9
# test(5914)     DNN:4 -- label:4
# test(5915)     DNN:7 -- label:7
# test(5916)     DNN:0 -- label:0
# test(5917)     DNN:5 -- label:5
# test(5918)     DNN:6 -- label:6
# test(5919)     DNN:7 -- label:7
# test(5920)     DNN:6 -- label:6
# test(5921)     DNN:8 -- label:8
# test(5922)     DNN:7 -- label:7
# test(5923)     DNN:5 -- label:5
# test(5924)     DNN:7 -- label:7
# test(5925)     DNN:3 -- label:3
# test(5926)     DNN:2 -- label:2
# test(5927)     DNN:1 -- label:9
# test(5928)     DNN:7 -- label:7
# test(5929)     DNN:2 -- label:2
# test(5930)     DNN:1 -- label:1
# test(5931)     DNN:3 -- label:3
# test(5932)     DNN:0 -- label:0
# test(5933)     DNN:5 -- label:5
# test(5934)     DNN:6 -- label:6
# test(5935)     DNN:5 -- label:5
# test(5936)     DNN:6 -- label:0
# test(5937)     DNN:4 -- label:4
# test(5938)     DNN:7 -- label:7
# test(5939)     DNN:9 -- label:9
# test(5940)     DNN:3 -- label:3
# test(5941)     DNN:7 -- label:7
# test(5942)     DNN:1 -- label:1
# test(5943)     DNN:8 -- label:8
# test(5944)     DNN:1 -- label:1
# test(5945)     DNN:8 -- label:8
# test(5946)     DNN:6 -- label:6
# test(5947)     DNN:2 -- label:2
# test(5948)     DNN:9 -- label:9
# test(5949)     DNN:1 -- label:1
# test(5950)     DNN:3 -- label:3
# test(5951)     DNN:4 -- label:4
# test(5952)     DNN:9 -- label:9
# test(5953)     DNN:2 -- label:2
# test(5954)     DNN:3 -- label:3
# test(5955)     DNN:0 -- label:0
# test(5956)     DNN:3 -- label:3
# test(5957)     DNN:3 -- label:3
# test(5958)     DNN:0 -- label:0
# test(5959)     DNN:6 -- label:6
# test(5960)     DNN:5 -- label:5
# test(5961)     DNN:1 -- label:1
# test(5962)     DNN:6 -- label:6
# test(5963)     DNN:7 -- label:7
# test(5964)     DNN:3 -- label:3
# test(5965)     DNN:3 -- label:3
# test(5966)     DNN:4 -- label:4
# test(5967)     DNN:5 -- label:5
# test(5968)     DNN:6 -- label:6
# test(5969)     DNN:4 -- label:4
# test(5970)     DNN:1 -- label:1
# test(5971)     DNN:9 -- label:9
# test(5972)     DNN:5 -- label:3
# test(5973)     DNN:4 -- label:4
# test(5974)     DNN:0 -- label:0
# test(5975)     DNN:5 -- label:8
# test(5976)     DNN:5 -- label:5
# test(5977)     DNN:6 -- label:6
# test(5978)     DNN:4 -- label:4
# test(5979)     DNN:3 -- label:3
# test(5980)     DNN:4 -- label:4
# test(5981)     DNN:4 -- label:4
# test(5982)     DNN:2 -- label:2
# test(5983)     DNN:9 -- label:9
# test(5984)     DNN:3 -- label:3
# test(5985)     DNN:9 -- label:9
# test(5986)     DNN:7 -- label:7
# test(5987)     DNN:1 -- label:1
# test(5988)     DNN:1 -- label:1
# test(5989)     DNN:5 -- label:5
# test(5990)     DNN:7 -- label:9
# test(5991)     DNN:4 -- label:4
# test(5992)     DNN:7 -- label:7
# test(5993)     DNN:8 -- label:8
# test(5994)     DNN:6 -- label:6
# test(5995)     DNN:9 -- label:9
# test(5996)     DNN:0 -- label:0
# test(5997)     DNN:6 -- label:6
# test(5998)     DNN:2 -- label:2
# test(5999)     DNN:7 -- label:7
# test(6000)     DNN:0 -- label:0
# test(6001)     DNN:1 -- label:1
# test(6002)     DNN:8 -- label:8
# test(6003)     DNN:5 -- label:5
# test(6004)     DNN:1 -- label:1
# test(6005)     DNN:9 -- label:9
# test(6006)     DNN:4 -- label:4
# test(6007)     DNN:8 -- label:8
# test(6008)     DNN:7 -- label:7
# test(6009)     DNN:6 -- label:6
# test(6010)     DNN:3 -- label:3
# test(6011)     DNN:7 -- label:7
# test(6012)     DNN:7 -- label:7
# test(6013)     DNN:1 -- label:1
# test(6014)     DNN:4 -- label:2
# test(6015)     DNN:2 -- label:2
# test(6016)     DNN:2 -- label:2
# test(6017)     DNN:5 -- label:6
# test(6018)     DNN:7 -- label:9
# test(6019)     DNN:0 -- label:0
# test(6020)     DNN:9 -- label:9
# test(6021)     DNN:5 -- label:5
# test(6022)     DNN:4 -- label:4
# test(6023)     DNN:7 -- label:7
# test(6024)     DNN:7 -- label:7
# test(6025)     DNN:9 -- label:9
# test(6026)     DNN:7 -- label:2
# test(6027)     DNN:5 -- label:5
# test(6028)     DNN:7 -- label:7
# test(6029)     DNN:2 -- label:2
# test(6030)     DNN:9 -- label:9
# test(6031)     DNN:9 -- label:9
# test(6032)     DNN:3 -- label:9
# test(6033)     DNN:9 -- label:9
# test(6034)     DNN:6 -- label:6
# test(6035)     DNN:0 -- label:0
# test(6036)     DNN:6 -- label:6
# test(6037)     DNN:3 -- label:3
# test(6038)     DNN:6 -- label:6
# test(6039)     DNN:3 -- label:3
# test(6040)     DNN:5 -- label:5
# test(6041)     DNN:1 -- label:1
# test(6042)     DNN:2 -- label:2
# test(6043)     DNN:5 -- label:5
# test(6044)     DNN:4 -- label:4
# test(6045)     DNN:8 -- label:8
# test(6046)     DNN:5 -- label:5
# test(6047)     DNN:7 -- label:7
# test(6048)     DNN:3 -- label:3
# test(6049)     DNN:7 -- label:7
# test(6050)     DNN:7 -- label:7
# test(6051)     DNN:6 -- label:6
# test(6052)     DNN:9 -- label:9
# test(6053)     DNN:4 -- label:4
# test(6054)     DNN:1 -- label:1
# test(6055)     DNN:0 -- label:0
# test(6056)     DNN:3 -- label:3
# test(6057)     DNN:3 -- label:3
# test(6058)     DNN:6 -- label:6
# test(6059)     DNN:4 -- label:9
# test(6060)     DNN:6 -- label:6
# test(6061)     DNN:2 -- label:2
# test(6062)     DNN:4 -- label:4
# test(6063)     DNN:0 -- label:0
# test(6064)     DNN:0 -- label:2
# test(6065)     DNN:7 -- label:7
# test(6066)     DNN:9 -- label:9
# test(6067)     DNN:3 -- label:9
# test(6068)     DNN:4 -- label:9
# test(6069)     DNN:7 -- label:7
# test(6070)     DNN:5 -- label:5
# test(6071)     DNN:6 -- label:6
# test(6072)     DNN:6 -- label:6
# test(6073)     DNN:0 -- label:0
# test(6074)     DNN:7 -- label:7
# test(6075)     DNN:1 -- label:1
# test(6076)     DNN:4 -- label:4
# test(6077)     DNN:2 -- label:2
# test(6078)     DNN:9 -- label:3
# test(6079)     DNN:8 -- label:8
# test(6080)     DNN:0 -- label:0
# test(6081)     DNN:5 -- label:5
# test(6082)     DNN:5 -- label:5
# test(6083)     DNN:9 -- label:9
# test(6084)     DNN:0 -- label:0
# test(6085)     DNN:4 -- label:7
# test(6086)     DNN:2 -- label:3
# test(6087)     DNN:7 -- label:7
# test(6088)     DNN:5 -- label:5
# test(6089)     DNN:8 -- label:8
# test(6090)     DNN:0 -- label:0
# test(6091)     DNN:3 -- label:3
# test(6092)     DNN:7 -- label:7
# test(6093)     DNN:3 -- label:3
# test(6094)     DNN:2 -- label:2
# test(6095)     DNN:3 -- label:3
# test(6096)     DNN:1 -- label:1
# test(6097)     DNN:3 -- label:3
# test(6098)     DNN:6 -- label:6
# test(6099)     DNN:6 -- label:6
# test(6100)     DNN:6 -- label:6
# test(6101)     DNN:7 -- label:7
# test(6102)     DNN:6 -- label:6
# test(6103)     DNN:6 -- label:6
# test(6104)     DNN:7 -- label:7
# test(6105)     DNN:3 -- label:3
# test(6106)     DNN:8 -- label:8
# test(6107)     DNN:2 -- label:7
# test(6108)     DNN:1 -- label:1
# test(6109)     DNN:4 -- label:4
# test(6110)     DNN:6 -- label:6
# test(6111)     DNN:3 -- label:3
# test(6112)     DNN:7 -- label:7
# test(6113)     DNN:3 -- label:3
# test(6114)     DNN:1 -- label:1
# test(6115)     DNN:2 -- label:2
# test(6116)     DNN:9 -- label:9
# test(6117)     DNN:4 -- label:4
# test(6118)     DNN:1 -- label:1
# test(6119)     DNN:8 -- label:8
# test(6120)     DNN:2 -- label:2
# test(6121)     DNN:9 -- label:9
# test(6122)     DNN:8 -- label:8
# test(6123)     DNN:2 -- label:2
# test(6124)     DNN:8 -- label:8
# test(6125)     DNN:4 -- label:4
# test(6126)     DNN:0 -- label:0
# test(6127)     DNN:1 -- label:1
# test(6128)     DNN:2 -- label:2
# test(6129)     DNN:3 -- label:3
# test(6130)     DNN:1 -- label:1
# test(6131)     DNN:1 -- label:1
# test(6132)     DNN:0 -- label:0
# test(6133)     DNN:9 -- label:9
# test(6134)     DNN:0 -- label:0
# test(6135)     DNN:1 -- label:1
# test(6136)     DNN:9 -- label:7
# test(6137)     DNN:0 -- label:0
# test(6138)     DNN:9 -- label:9
# test(6139)     DNN:8 -- label:8
# test(6140)     DNN:1 -- label:1
# test(6141)     DNN:8 -- label:8
# test(6142)     DNN:4 -- label:4
# test(6143)     DNN:5 -- label:5
# test(6144)     DNN:2 -- label:2
# test(6145)     DNN:7 -- label:7
# test(6146)     DNN:0 -- label:0
# test(6147)     DNN:9 -- label:9
# test(6148)     DNN:8 -- label:3
# test(6149)     DNN:0 -- label:0
# test(6150)     DNN:6 -- label:6
# test(6151)     DNN:2 -- label:2
# test(6152)     DNN:8 -- label:8
# test(6153)     DNN:2 -- label:2
# test(6154)     DNN:5 -- label:5
# test(6155)     DNN:7 -- label:7
# test(6156)     DNN:8 -- label:8
# test(6157)     DNN:3 -- label:8
# test(6158)     DNN:6 -- label:6
# test(6159)     DNN:1 -- label:1
# test(6160)     DNN:7 -- label:7
# test(6161)     DNN:1 -- label:1
# test(6162)     DNN:7 -- label:7
# test(6163)     DNN:1 -- label:1
# test(6164)     DNN:3 -- label:3
# test(6165)     DNN:2 -- label:2
# test(6166)     DNN:8 -- label:8
# test(6167)     DNN:2 -- label:2
# test(6168)     DNN:3 -- label:3
# test(6169)     DNN:7 -- label:7
# test(6170)     DNN:6 -- label:0
# test(6171)     DNN:8 -- label:5
# test(6172)     DNN:6 -- label:6
# test(6173)     DNN:0 -- label:0
# test(6174)     DNN:1 -- label:1
# test(6175)     DNN:5 -- label:5
# test(6176)     DNN:3 -- label:3
# test(6177)     DNN:1 -- label:1
# test(6178)     DNN:5 -- label:5
# test(6179)     DNN:9 -- label:9
# test(6180)     DNN:7 -- label:7
# test(6181)     DNN:9 -- label:9
# test(6182)     DNN:9 -- label:9
# test(6183)     DNN:7 -- label:7
# test(6184)     DNN:4 -- label:4
# test(6185)     DNN:0 -- label:0
# test(6186)     DNN:4 -- label:4
# test(6187)     DNN:6 -- label:6
# test(6188)     DNN:3 -- label:3
# test(6189)     DNN:9 -- label:4
# test(6190)     DNN:7 -- label:7
# test(6191)     DNN:7 -- label:7
# test(6192)     DNN:0 -- label:0
# test(6193)     DNN:6 -- label:6
# test(6194)     DNN:6 -- label:6
# test(6195)     DNN:3 -- label:3
# test(6196)     DNN:1 -- label:1
# test(6197)     DNN:5 -- label:5
# test(6198)     DNN:6 -- label:6
# test(6199)     DNN:4 -- label:4
# test(6200)     DNN:8 -- label:8
# test(6201)     DNN:9 -- label:9
# test(6202)     DNN:8 -- label:8
# test(6203)     DNN:6 -- label:4
# test(6204)     DNN:9 -- label:9
# test(6205)     DNN:8 -- label:8
# test(6206)     DNN:1 -- label:1
# test(6207)     DNN:4 -- label:4
# test(6208)     DNN:1 -- label:1
# test(6209)     DNN:6 -- label:6
# test(6210)     DNN:0 -- label:0
# test(6211)     DNN:7 -- label:7
# test(6212)     DNN:0 -- label:6
# test(6213)     DNN:0 -- label:0
# test(6214)     DNN:0 -- label:0
# test(6215)     DNN:5 -- label:5
# test(6216)     DNN:1 -- label:1
# test(6217)     DNN:0 -- label:0
# test(6218)     DNN:8 -- label:8
# test(6219)     DNN:0 -- label:0
# test(6220)     DNN:3 -- label:3
# test(6221)     DNN:7 -- label:7
# test(6222)     DNN:7 -- label:7
# test(6223)     DNN:7 -- label:7
# test(6224)     DNN:9 -- label:9
# test(6225)     DNN:8 -- label:8
# test(6226)     DNN:7 -- label:7
# test(6227)     DNN:4 -- label:4
# test(6228)     DNN:7 -- label:7
# test(6229)     DNN:4 -- label:4
# test(6230)     DNN:9 -- label:9
# test(6231)     DNN:1 -- label:1
# test(6232)     DNN:6 -- label:6
# test(6233)     DNN:1 -- label:1
# test(6234)     DNN:4 -- label:4
# test(6235)     DNN:7 -- label:7
# test(6236)     DNN:3 -- label:3
# test(6237)     DNN:2 -- label:2
# test(6238)     DNN:8 -- label:8
# test(6239)     DNN:9 -- label:9
# test(6240)     DNN:7 -- label:7
# test(6241)     DNN:8 -- label:8
# test(6242)     DNN:1 -- label:1
# test(6243)     DNN:8 -- label:8
# test(6244)     DNN:1 -- label:1
# test(6245)     DNN:0 -- label:0
# test(6246)     DNN:5 -- label:5
# test(6247)     DNN:4 -- label:4
# test(6248)     DNN:0 -- label:0
# test(6249)     DNN:3 -- label:5
# test(6250)     DNN:2 -- label:2
# test(6251)     DNN:2 -- label:2
# test(6252)     DNN:4 -- label:4
# test(6253)     DNN:8 -- label:8
# test(6254)     DNN:2 -- label:2
# test(6255)     DNN:9 -- label:9
# test(6256)     DNN:2 -- label:2
# test(6257)     DNN:1 -- label:1
# test(6258)     DNN:1 -- label:1
# test(6259)     DNN:6 -- label:6
# test(6260)     DNN:6 -- label:6
# test(6261)     DNN:6 -- label:6
# test(6262)     DNN:0 -- label:0
# test(6263)     DNN:0 -- label:0
# test(6264)     DNN:4 -- label:4
# test(6265)     DNN:3 -- label:3
# test(6266)     DNN:1 -- label:1
# test(6267)     DNN:5 -- label:5
# test(6268)     DNN:6 -- label:6
# test(6269)     DNN:4 -- label:4
# test(6270)     DNN:7 -- label:7
# test(6271)     DNN:3 -- label:3
# test(6272)     DNN:4 -- label:4
# test(6273)     DNN:3 -- label:3
# test(6274)     DNN:1 -- label:1
# test(6275)     DNN:6 -- label:1
# test(6276)     DNN:2 -- label:2
# test(6277)     DNN:0 -- label:0
# test(6278)     DNN:7 -- label:7
# test(6279)     DNN:2 -- label:2
# test(6280)     DNN:1 -- label:1
# test(6281)     DNN:5 -- label:5
# test(6282)     DNN:9 -- label:9
# test(6283)     DNN:4 -- label:2
# test(6284)     DNN:1 -- label:1
# test(6285)     DNN:0 -- label:0
# test(6286)     DNN:6 -- label:6
# test(6287)     DNN:8 -- label:3
# test(6288)     DNN:5 -- label:5
# test(6289)     DNN:0 -- label:0
# test(6290)     DNN:5 -- label:5
# test(6291)     DNN:5 -- label:5
# test(6292)     DNN:6 -- label:6
# test(6293)     DNN:9 -- label:9
# test(6294)     DNN:7 -- label:7
# test(6295)     DNN:8 -- label:8
# test(6296)     DNN:4 -- label:4
# test(6297)     DNN:4 -- label:4
# test(6298)     DNN:3 -- label:3
# test(6299)     DNN:1 -- label:1
# test(6300)     DNN:9 -- label:9
# test(6301)     DNN:0 -- label:0
# test(6302)     DNN:2 -- label:2
# test(6303)     DNN:2 -- label:2
# test(6304)     DNN:3 -- label:3
# test(6305)     DNN:8 -- label:8
# test(6306)     DNN:0 -- label:0
# test(6307)     DNN:0 -- label:0
# test(6308)     DNN:2 -- label:2
# test(6309)     DNN:6 -- label:6
# test(6310)     DNN:9 -- label:9
# test(6311)     DNN:9 -- label:9
# test(6312)     DNN:3 -- label:3
# test(6313)     DNN:8 -- label:8
# test(6314)     DNN:1 -- label:1
# test(6315)     DNN:8 -- label:8
# test(6316)     DNN:1 -- label:1
# test(6317)     DNN:5 -- label:5
# test(6318)     DNN:0 -- label:0
# test(6319)     DNN:6 -- label:6
# test(6320)     DNN:7 -- label:8
# test(6321)     DNN:3 -- label:3
# test(6322)     DNN:4 -- label:7
# test(6323)     DNN:8 -- label:8
# test(6324)     DNN:3 -- label:3
# test(6325)     DNN:5 -- label:5
# test(6326)     DNN:4 -- label:4
# test(6327)     DNN:5 -- label:5
# test(6328)     DNN:7 -- label:7
# test(6329)     DNN:5 -- label:5
# test(6330)     DNN:8 -- label:8
# test(6331)     DNN:1 -- label:1
# test(6332)     DNN:2 -- label:2
# test(6333)     DNN:4 -- label:4
# test(6334)     DNN:1 -- label:1
# test(6335)     DNN:1 -- label:1
# test(6336)     DNN:2 -- label:2
# test(6337)     DNN:4 -- label:7
# test(6338)     DNN:1 -- label:7
# test(6339)     DNN:7 -- label:7
# test(6340)     DNN:8 -- label:8
# test(6341)     DNN:3 -- label:3
# test(6342)     DNN:0 -- label:0
# test(6343)     DNN:1 -- label:1
# test(6344)     DNN:0 -- label:0
# test(6345)     DNN:4 -- label:4
# test(6346)     DNN:9 -- label:9
# test(6347)     DNN:4 -- label:4
# test(6348)     DNN:5 -- label:5
# test(6349)     DNN:9 -- label:9
# test(6350)     DNN:3 -- label:3
# test(6351)     DNN:7 -- label:7
# test(6352)     DNN:7 -- label:7
# test(6353)     DNN:2 -- label:2
# test(6354)     DNN:3 -- label:3
# test(6355)     DNN:5 -- label:5
# test(6356)     DNN:9 -- label:9
# test(6357)     DNN:3 -- label:3
# test(6358)     DNN:1 -- label:1
# test(6359)     DNN:2 -- label:2
# test(6360)     DNN:5 -- label:5
# test(6361)     DNN:4 -- label:4
# test(6362)     DNN:2 -- label:2
# test(6363)     DNN:4 -- label:4
# test(6364)     DNN:8 -- label:8
# test(6365)     DNN:8 -- label:8
# test(6366)     DNN:0 -- label:0
# test(6367)     DNN:5 -- label:5
# test(6368)     DNN:2 -- label:2
# test(6369)     DNN:9 -- label:9
# test(6370)     DNN:6 -- label:6
# test(6371)     DNN:6 -- label:6
# test(6372)     DNN:6 -- label:6
# test(6373)     DNN:1 -- label:1
# test(6374)     DNN:9 -- label:9
# test(6375)     DNN:4 -- label:4
# test(6376)     DNN:3 -- label:3
# test(6377)     DNN:9 -- label:9
# test(6378)     DNN:1 -- label:1
# test(6379)     DNN:9 -- label:9
# test(6380)     DNN:2 -- label:2
# test(6381)     DNN:2 -- label:2
# test(6382)     DNN:1 -- label:1
# test(6383)     DNN:1 -- label:1
# test(6384)     DNN:7 -- label:7
# test(6385)     DNN:6 -- label:6
# test(6386)     DNN:1 -- label:1
# test(6387)     DNN:2 -- label:3
# test(6388)     DNN:2 -- label:2
# test(6389)     DNN:5 -- label:5
# test(6390)     DNN:1 -- label:1
# test(6391)     DNN:3 -- label:2
# test(6392)     DNN:8 -- label:8
# test(6393)     DNN:7 -- label:0
# test(6394)     DNN:2 -- label:2
# test(6395)     DNN:4 -- label:4
# test(6396)     DNN:8 -- label:8
# test(6397)     DNN:0 -- label:0
# test(6398)     DNN:5 -- label:5
# test(6399)     DNN:5 -- label:3
# test(6400)     DNN:9 -- label:7
# test(6401)     DNN:6 -- label:6
# test(6402)     DNN:0 -- label:0
# test(6403)     DNN:4 -- label:4
# test(6404)     DNN:8 -- label:8
# test(6405)     DNN:4 -- label:4
# test(6406)     DNN:0 -- label:0
# test(6407)     DNN:8 -- label:8
# test(6408)     DNN:9 -- label:9
# test(6409)     DNN:7 -- label:7
# test(6410)     DNN:9 -- label:9
# test(6411)     DNN:7 -- label:7
# test(6412)     DNN:4 -- label:9
# test(6413)     DNN:3 -- label:3
# test(6414)     DNN:3 -- label:3
# test(6415)     DNN:5 -- label:5
# test(6416)     DNN:7 -- label:7
# test(6417)     DNN:8 -- label:8
# test(6418)     DNN:5 -- label:5
# test(6419)     DNN:4 -- label:4
# test(6420)     DNN:4 -- label:4
# test(6421)     DNN:0 -- label:0
# test(6422)     DNN:9 -- label:9
# test(6423)     DNN:1 -- label:1
# test(6424)     DNN:4 -- label:4
# test(6425)     DNN:9 -- label:9
# test(6426)     DNN:0 -- label:0
# test(6427)     DNN:6 -- label:6
# test(6428)     DNN:7 -- label:7
# test(6429)     DNN:0 -- label:0
# test(6430)     DNN:7 -- label:7
# test(6431)     DNN:2 -- label:2
# test(6432)     DNN:1 -- label:1
# test(6433)     DNN:0 -- label:0
# test(6434)     DNN:8 -- label:8
# test(6435)     DNN:3 -- label:3
# test(6436)     DNN:2 -- label:2
# test(6437)     DNN:7 -- label:7
# test(6438)     DNN:5 -- label:5
# test(6439)     DNN:8 -- label:8
# test(6440)     DNN:7 -- label:7
# test(6441)     DNN:1 -- label:1
# test(6442)     DNN:9 -- label:9
# test(6443)     DNN:2 -- label:2
# test(6444)     DNN:9 -- label:9
# test(6445)     DNN:7 -- label:7
# test(6446)     DNN:6 -- label:6
# test(6447)     DNN:6 -- label:6
# test(6448)     DNN:2 -- label:2
# test(6449)     DNN:5 -- label:5
# test(6450)     DNN:2 -- label:2
# test(6451)     DNN:9 -- label:9
# test(6452)     DNN:1 -- label:1
# test(6453)     DNN:9 -- label:9
# test(6454)     DNN:4 -- label:7
# test(6455)     DNN:3 -- label:3
# test(6456)     DNN:2 -- label:2
# test(6457)     DNN:0 -- label:0
# test(6458)     DNN:3 -- label:3
# test(6459)     DNN:8 -- label:8
# test(6460)     DNN:1 -- label:1
# test(6461)     DNN:4 -- label:2
# test(6462)     DNN:2 -- label:2
# test(6463)     DNN:7 -- label:7
# test(6464)     DNN:0 -- label:0
# test(6465)     DNN:1 -- label:1
# test(6466)     DNN:4 -- label:4
# test(6467)     DNN:0 -- label:0
# test(6468)     DNN:3 -- label:3
# test(6469)     DNN:3 -- label:3
# test(6470)     DNN:1 -- label:1
# test(6471)     DNN:1 -- label:1
# test(6472)     DNN:3 -- label:3
# test(6473)     DNN:5 -- label:5
# test(6474)     DNN:0 -- label:0
# test(6475)     DNN:1 -- label:1
# test(6476)     DNN:2 -- label:2
# test(6477)     DNN:9 -- label:9
# test(6478)     DNN:5 -- label:5
# test(6479)     DNN:1 -- label:1
# test(6480)     DNN:9 -- label:9
# test(6481)     DNN:9 -- label:9
# test(6482)     DNN:3 -- label:3
# test(6483)     DNN:8 -- label:8
# test(6484)     DNN:5 -- label:3
# test(6485)     DNN:6 -- label:6
# test(6486)     DNN:5 -- label:5
# test(6487)     DNN:5 -- label:5
# test(6488)     DNN:1 -- label:1
# test(6489)     DNN:6 -- label:6
# test(6490)     DNN:6 -- label:6
# test(6491)     DNN:7 -- label:7
# test(6492)     DNN:1 -- label:1
# test(6493)     DNN:5 -- label:5
# test(6494)     DNN:4 -- label:4
# test(6495)     DNN:2 -- label:2
# test(6496)     DNN:9 -- label:9
# test(6497)     DNN:2 -- label:2
# test(6498)     DNN:0 -- label:0
# test(6499)     DNN:7 -- label:7
# ...
# test(9501)     DNN:8 -- label:8
# test(9502)     DNN:2 -- label:2
# test(9503)     DNN:4 -- label:4
# test(9504)     DNN:6 -- label:6
# test(9505)     DNN:6 -- label:6
# test(9506)     DNN:3 -- label:3
# test(9507)     DNN:1 -- label:1
# test(9508)     DNN:3 -- label:3
# test(9509)     DNN:4 -- label:4
# test(9510)     DNN:9 -- label:9
# test(9511)     DNN:0 -- label:0
# test(9512)     DNN:0 -- label:0
# test(9513)     DNN:1 -- label:1
# test(9514)     DNN:9 -- label:9
# test(9515)     DNN:4 -- label:4
# test(9516)     DNN:1 -- label:1
# test(9517)     DNN:0 -- label:0
# test(9518)     DNN:1 -- label:1
# test(9519)     DNN:2 -- label:2
# test(9520)     DNN:5 -- label:5
# test(9521)     DNN:1 -- label:1
# test(9522)     DNN:7 -- label:7
# test(9523)     DNN:2 -- label:7
# test(9524)     DNN:6 -- label:6
# test(9525)     DNN:6 -- label:2
# test(9526)     DNN:0 -- label:0
# test(9527)     DNN:2 -- label:2
# test(9528)     DNN:2 -- label:2
# test(9529)     DNN:0 -- label:0
# test(9530)     DNN:5 -- label:6
# test(9531)     DNN:8 -- label:8
# test(9532)     DNN:3 -- label:3
# test(9533)     DNN:9 -- label:9
# test(9534)     DNN:2 -- label:2
# test(9535)     DNN:9 -- label:7
# test(9536)     DNN:4 -- label:4
# test(9537)     DNN:7 -- label:7
# test(9538)     DNN:8 -- label:8
# test(9539)     DNN:4 -- label:4
# test(9540)     DNN:8 -- label:8
# test(9541)     DNN:1 -- label:1
# test(9542)     DNN:1 -- label:1
# test(9543)     DNN:4 -- label:4
# test(9544)     DNN:4 -- label:4
# test(9545)     DNN:8 -- label:5
# test(9546)     DNN:5 -- label:5
# test(9547)     DNN:1 -- label:1
# test(9548)     DNN:3 -- label:3
# test(9549)     DNN:7 -- label:7
# test(9550)     DNN:8 -- label:8
# test(9551)     DNN:6 -- label:6
# test(9552)     DNN:0 -- label:0
# test(9553)     DNN:3 -- label:3
# test(9554)     DNN:0 -- label:7
# test(9555)     DNN:6 -- label:6
# test(9556)     DNN:2 -- label:7
# test(9557)     DNN:7 -- label:7
# test(9558)     DNN:9 -- label:9
# test(9559)     DNN:7 -- label:7
# test(9560)     DNN:1 -- label:1
# test(9561)     DNN:1 -- label:1
# test(9562)     DNN:6 -- label:6
# test(9563)     DNN:4 -- label:4
# test(9564)     DNN:3 -- label:3
# test(9565)     DNN:0 -- label:0
# test(9566)     DNN:0 -- label:0
# test(9567)     DNN:1 -- label:1
# test(9568)     DNN:3 -- label:9
# test(9569)     DNN:5 -- label:5
# test(9570)     DNN:7 -- label:7
# test(9571)     DNN:9 -- label:9
# test(9572)     DNN:8 -- label:8
# test(9573)     DNN:8 -- label:8
# test(9574)     DNN:8 -- label:8
# test(9575)     DNN:7 -- label:7
# test(9576)     DNN:1 -- label:1
# test(9577)     DNN:7 -- label:7
# test(9578)     DNN:6 -- label:6
# test(9579)     DNN:6 -- label:6
# test(9580)     DNN:4 -- label:4
# test(9581)     DNN:4 -- label:4
# test(9582)     DNN:7 -- label:7
# test(9583)     DNN:4 -- label:4
# test(9584)     DNN:1 -- label:1
# test(9585)     DNN:8 -- label:8
# test(9586)     DNN:2 -- label:4
# test(9587)     DNN:9 -- label:9
# test(9588)     DNN:2 -- label:2
# test(9589)     DNN:2 -- label:2
# test(9590)     DNN:0 -- label:0
# test(9591)     DNN:0 -- label:0
# test(9592)     DNN:8 -- label:8
# test(9593)     DNN:2 -- label:2
# test(9594)     DNN:8 -- label:8
# test(9595)     DNN:4 -- label:4
# test(9596)     DNN:9 -- label:9
# test(9597)     DNN:4 -- label:4
# test(9598)     DNN:2 -- label:2
# test(9599)     DNN:0 -- label:0
# test(9600)     DNN:1 -- label:1
# test(9601)     DNN:5 -- label:5
# test(9602)     DNN:1 -- label:1
# test(9603)     DNN:9 -- label:9
# test(9604)     DNN:7 -- label:7
# test(9605)     DNN:6 -- label:6
# test(9606)     DNN:3 -- label:3
# test(9607)     DNN:0 -- label:0
# test(9608)     DNN:3 -- label:3
# test(9609)     DNN:1 -- label:1
# test(9610)     DNN:7 -- label:7
# test(9611)     DNN:6 -- label:6
# test(9612)     DNN:2 -- label:7
# test(9613)     DNN:4 -- label:4
# test(9614)     DNN:0 -- label:0
# test(9615)     DNN:0 -- label:0
# test(9616)     DNN:7 -- label:7
# test(9617)     DNN:2 -- label:2
# test(9618)     DNN:2 -- label:2
# test(9619)     DNN:1 -- label:1
# test(9620)     DNN:1 -- label:1
# test(9621)     DNN:2 -- label:2
# test(9622)     DNN:6 -- label:6
# test(9623)     DNN:2 -- label:2
# test(9624)     DNN:0 -- label:0
# test(9625)     DNN:8 -- label:8
# test(9626)     DNN:0 -- label:0
# test(9627)     DNN:4 -- label:4
# test(9628)     DNN:3 -- label:3
# test(9629)     DNN:7 -- label:7
# test(9630)     DNN:1 -- label:9
# test(9631)     DNN:9 -- label:9
# test(9632)     DNN:8 -- label:8
# test(9633)     DNN:4 -- label:4
# test(9634)     DNN:5 -- label:5
# test(9635)     DNN:1 -- label:1
# test(9636)     DNN:6 -- label:6
# test(9637)     DNN:7 -- label:7
# test(9638)     DNN:7 -- label:7
# test(9639)     DNN:2 -- label:2
# test(9640)     DNN:9 -- label:9
# test(9641)     DNN:1 -- label:1
# test(9642)     DNN:2 -- label:2
# test(9643)     DNN:2 -- label:2
# test(9644)     DNN:4 -- label:4
# test(9645)     DNN:7 -- label:7
# test(9646)     DNN:8 -- label:8
# test(9647)     DNN:2 -- label:2
# test(9648)     DNN:2 -- label:2
# test(9649)     DNN:5 -- label:5
# test(9650)     DNN:6 -- label:6
# test(9651)     DNN:8 -- label:2
# test(9652)     DNN:2 -- label:2
# test(9653)     DNN:6 -- label:6
# test(9654)     DNN:2 -- label:2
# test(9655)     DNN:9 -- label:9
# test(9656)     DNN:4 -- label:4
# test(9657)     DNN:7 -- label:5
# test(9658)     DNN:1 -- label:1
# test(9659)     DNN:8 -- label:8
# test(9660)     DNN:5 -- label:5
# test(9661)     DNN:7 -- label:7
# test(9662)     DNN:2 -- label:2
# test(9663)     DNN:7 -- label:7
# test(9664)     DNN:7 -- label:7
# test(9665)     DNN:6 -- label:6
# test(9666)     DNN:9 -- label:9
# test(9667)     DNN:1 -- label:1
# test(9668)     DNN:4 -- label:4
# test(9669)     DNN:9 -- label:4
# test(9670)     DNN:6 -- label:6
# test(9671)     DNN:2 -- label:2
# test(9672)     DNN:7 -- label:7
# test(9673)     DNN:8 -- label:2
# test(9674)     DNN:5 -- label:5
# test(9675)     DNN:9 -- label:9
# test(9676)     DNN:8 -- label:8
# test(9677)     DNN:5 -- label:5
# test(9678)     DNN:1 -- label:1
# test(9679)     DNN:0 -- label:3
# test(9680)     DNN:5 -- label:5
# test(9681)     DNN:0 -- label:0
# test(9682)     DNN:3 -- label:3
# test(9683)     DNN:1 -- label:1
# test(9684)     DNN:2 -- label:2
# test(9685)     DNN:2 -- label:2
# test(9686)     DNN:3 -- label:3
# test(9687)     DNN:4 -- label:4
# test(9688)     DNN:6 -- label:6
# test(9689)     DNN:1 -- label:1
# test(9690)     DNN:5 -- label:5
# test(9691)     DNN:5 -- label:5
# test(9692)     DNN:7 -- label:7
# test(9693)     DNN:9 -- label:9
# test(9694)     DNN:6 -- label:6
# test(9695)     DNN:6 -- label:6
# test(9696)     DNN:8 -- label:8
# test(9697)     DNN:3 -- label:3
# test(9698)     DNN:5 -- label:5
# test(9699)     DNN:7 -- label:7
# test(9700)     DNN:7 -- label:7
# test(9701)     DNN:8 -- label:8
# test(9702)     DNN:5 -- label:5
# test(9703)     DNN:2 -- label:2
# test(9704)     DNN:6 -- label:6
# test(9705)     DNN:0 -- label:0
# test(9706)     DNN:2 -- label:2
# test(9707)     DNN:0 -- label:0
# test(9708)     DNN:4 -- label:4
# test(9709)     DNN:0 -- label:0
# test(9710)     DNN:1 -- label:1
# test(9711)     DNN:4 -- label:4
# test(9712)     DNN:1 -- label:1
# test(9713)     DNN:0 -- label:0
# test(9714)     DNN:3 -- label:3
# test(9715)     DNN:9 -- label:9
# test(9716)     DNN:9 -- label:9
# test(9717)     DNN:5 -- label:5
# test(9718)     DNN:7 -- label:7
# test(9719)     DNN:2 -- label:2
# test(9720)     DNN:1 -- label:1
# test(9721)     DNN:1 -- label:1
# test(9722)     DNN:4 -- label:4
# test(9723)     DNN:9 -- label:9
# test(9724)     DNN:9 -- label:9
# test(9725)     DNN:1 -- label:1
# test(9726)     DNN:6 -- label:6
# test(9727)     DNN:5 -- label:5
# test(9728)     DNN:2 -- label:2
# test(9729)     DNN:1 -- label:1
# test(9730)     DNN:0 -- label:0
# test(9731)     DNN:6 -- label:6
# test(9732)     DNN:9 -- label:9
# test(9733)     DNN:3 -- label:3
# test(9734)     DNN:8 -- label:8
# test(9735)     DNN:3 -- label:3
# test(9736)     DNN:7 -- label:7
# test(9737)     DNN:4 -- label:4
# test(9738)     DNN:4 -- label:4
# test(9739)     DNN:3 -- label:3
# test(9740)     DNN:7 -- label:7
# test(9741)     DNN:9 -- label:9
# test(9742)     DNN:2 -- label:2
# test(9743)     DNN:9 -- label:9
# test(9744)     DNN:7 -- label:7
# test(9745)     DNN:1 -- label:7
# test(9746)     DNN:1 -- label:1
# test(9747)     DNN:5 -- label:5
# test(9748)     DNN:4 -- label:4
# test(9749)     DNN:2 -- label:2
# test(9750)     DNN:2 -- label:2
# test(9751)     DNN:6 -- label:6
# test(9752)     DNN:8 -- label:2
# test(9753)     DNN:0 -- label:0
# test(9754)     DNN:9 -- label:9
# test(9755)     DNN:0 -- label:0
# test(9756)     DNN:9 -- label:9
# test(9757)     DNN:1 -- label:1
# test(9758)     DNN:3 -- label:3
# test(9759)     DNN:6 -- label:6
# test(9760)     DNN:8 -- label:8
# test(9761)     DNN:1 -- label:9
# test(9762)     DNN:3 -- label:3
# test(9763)     DNN:6 -- label:6
# test(9764)     DNN:1 -- label:1
# test(9765)     DNN:8 -- label:8
# test(9766)     DNN:0 -- label:0
# test(9767)     DNN:1 -- label:1
# test(9768)     DNN:5 -- label:5
# test(9769)     DNN:7 -- label:7
# test(9770)     DNN:5 -- label:5
# test(9771)     DNN:8 -- label:8
# test(9772)     DNN:5 -- label:3
# test(9773)     DNN:3 -- label:3
# test(9774)     DNN:3 -- label:8
# test(9775)     DNN:9 -- label:9
# test(9776)     DNN:5 -- label:5
# test(9777)     DNN:3 -- label:3
# test(9778)     DNN:5 -- label:5
# test(9779)     DNN:0 -- label:0
# test(9780)     DNN:8 -- label:3
# test(9781)     DNN:6 -- label:6
# test(9782)     DNN:8 -- label:8
# test(9783)     DNN:1 -- label:1
# test(9784)     DNN:6 -- label:6
# test(9785)     DNN:5 -- label:5
# test(9786)     DNN:8 -- label:4
# test(9787)     DNN:9 -- label:9
# test(9788)     DNN:7 -- label:7
# test(9789)     DNN:9 -- label:9
# test(9790)     DNN:7 -- label:7
# test(9791)     DNN:8 -- label:8
# test(9792)     DNN:7 -- label:7
# test(9793)     DNN:1 -- label:1
# test(9794)     DNN:8 -- label:8
# test(9795)     DNN:0 -- label:0
# test(9796)     DNN:9 -- label:9
# test(9797)     DNN:3 -- label:5
# test(9798)     DNN:8 -- label:8
# test(9799)     DNN:7 -- label:7
# test(9800)     DNN:2 -- label:2
# test(9801)     DNN:5 -- label:5
# test(9802)     DNN:3 -- label:3
# test(9803)     DNN:3 -- label:3
# test(9804)     DNN:6 -- label:6
# test(9805)     DNN:8 -- label:8
# test(9806)     DNN:8 -- label:8
# test(9807)     DNN:7 -- label:7
# test(9808)     DNN:2 -- label:2
# test(9809)     DNN:7 -- label:3
# test(9810)     DNN:8 -- label:5
# test(9811)     DNN:8 -- label:8
# test(9812)     DNN:4 -- label:4
# test(9813)     DNN:8 -- label:2
# test(9814)     DNN:4 -- label:4
# test(9815)     DNN:4 -- label:9
# test(9816)     DNN:4 -- label:4
# test(9817)     DNN:6 -- label:6
# test(9818)     DNN:7 -- label:7
# test(9819)     DNN:2 -- label:2
# test(9820)     DNN:8 -- label:8
# test(9821)     DNN:4 -- label:4
# test(9822)     DNN:2 -- label:2
# test(9823)     DNN:1 -- label:1
# test(9824)     DNN:7 -- label:7
# test(9825)     DNN:5 -- label:5
# test(9826)     DNN:3 -- label:5
# test(9827)     DNN:4 -- label:4
# test(9828)     DNN:7 -- label:7
# test(9829)     DNN:8 -- label:8
# test(9830)     DNN:9 -- label:9
# test(9831)     DNN:5 -- label:5
# test(9832)     DNN:7 -- label:7
# test(9833)     DNN:0 -- label:0
# test(9834)     DNN:9 -- label:9
# test(9835)     DNN:4 -- label:4
# test(9836)     DNN:1 -- label:1
# test(9837)     DNN:6 -- label:6
# test(9838)     DNN:2 -- label:2
# test(9839)     DNN:7 -- label:7
# test(9840)     DNN:1 -- label:1
# test(9841)     DNN:4 -- label:4
# test(9842)     DNN:6 -- label:6
# test(9843)     DNN:9 -- label:9
# test(9844)     DNN:0 -- label:0
# test(9845)     DNN:7 -- label:7
# test(9846)     DNN:0 -- label:0
# test(9847)     DNN:4 -- label:4
# test(9848)     DNN:7 -- label:7
# test(9849)     DNN:2 -- label:2
# test(9850)     DNN:5 -- label:5
# test(9851)     DNN:0 -- label:0
# test(9852)     DNN:4 -- label:4
# test(9853)     DNN:5 -- label:5
# test(9854)     DNN:4 -- label:4
# test(9855)     DNN:7 -- label:7
# test(9856)     DNN:7 -- label:7
# test(9857)     DNN:3 -- label:3
# test(9858)     DNN:4 -- label:4
# test(9859)     DNN:4 -- label:4
# test(9860)     DNN:1 -- label:1
# test(9861)     DNN:3 -- label:5
# test(9862)     DNN:3 -- label:3
# test(9863)     DNN:1 -- label:1
# test(9864)     DNN:2 -- label:2
# test(9865)     DNN:9 -- label:9
# test(9866)     DNN:0 -- label:0
# test(9867)     DNN:5 -- label:5
# test(9868)     DNN:0 -- label:0
# test(9869)     DNN:7 -- label:7
# test(9870)     DNN:9 -- label:9
# test(9871)     DNN:2 -- label:2
# test(9872)     DNN:6 -- label:6
# test(9873)     DNN:0 -- label:0
# test(9874)     DNN:4 -- label:4
# test(9875)     DNN:7 -- label:7
# test(9876)     DNN:0 -- label:0
# test(9877)     DNN:4 -- label:4
# test(9878)     DNN:0 -- label:0
# test(9879)     DNN:2 -- label:2
# test(9880)     DNN:3 -- label:3
# test(9881)     DNN:5 -- label:5
# test(9882)     DNN:8 -- label:8
# test(9883)     DNN:2 -- label:2
# test(9884)     DNN:8 -- label:8
# test(9885)     DNN:3 -- label:5
# test(9886)     DNN:1 -- label:1
# test(9887)     DNN:0 -- label:9
# test(9888)     DNN:3 -- label:3
# test(9889)     DNN:0 -- label:8
# test(9890)     DNN:4 -- label:4
# test(9891)     DNN:4 -- label:4
# test(9892)     DNN:2 -- label:2
# test(9893)     DNN:8 -- label:8
# test(9894)     DNN:8 -- label:8
# test(9895)     DNN:0 -- label:0
# test(9896)     DNN:4 -- label:4
# test(9897)     DNN:4 -- label:4
# test(9898)     DNN:2 -- label:2
# test(9899)     DNN:1 -- label:1
# test(9900)     DNN:9 -- label:9
# test(9901)     DNN:9 -- label:9
# test(9902)     DNN:4 -- label:4
# test(9903)     DNN:4 -- label:4
# test(9904)     DNN:9 -- label:9
# test(9905)     DNN:6 -- label:6
# test(9906)     DNN:2 -- label:2
# test(9907)     DNN:3 -- label:3
# test(9908)     DNN:5 -- label:5
# test(9909)     DNN:8 -- label:8
# test(9910)     DNN:6 -- label:6
# test(9911)     DNN:1 -- label:1
# test(9912)     DNN:0 -- label:0
# test(9913)     DNN:1 -- label:1
# test(9914)     DNN:3 -- label:3
# test(9915)     DNN:4 -- label:4
# test(9916)     DNN:5 -- label:5
# test(9917)     DNN:6 -- label:6
# test(9918)     DNN:6 -- label:6
# test(9919)     DNN:0 -- label:0
# test(9920)     DNN:4 -- label:2
# test(9921)     DNN:7 -- label:7
# test(9922)     DNN:8 -- label:8
# test(9923)     DNN:1 -- label:1
# test(9924)     DNN:5 -- label:5
# test(9925)     DNN:5 -- label:5
# test(9926)     DNN:7 -- label:7
# test(9927)     DNN:9 -- label:9
# test(9928)     DNN:8 -- label:3
# test(9929)     DNN:6 -- label:6
# test(9930)     DNN:1 -- label:1
# test(9931)     DNN:4 -- label:4
# test(9932)     DNN:8 -- label:8
# test(9933)     DNN:2 -- label:2
# test(9934)     DNN:3 -- label:3
# test(9935)     DNN:1 -- label:7
# test(9936)     DNN:9 -- label:4
# test(9937)     DNN:2 -- label:2
# test(9938)     DNN:2 -- label:2
# test(9939)     DNN:4 -- label:4
# test(9940)     DNN:2 -- label:2
# test(9941)     DNN:9 -- label:9
# test(9942)     DNN:3 -- label:3
# test(9943)     DNN:5 -- label:5
# test(9944)     DNN:2 -- label:2
# test(9945)     DNN:5 -- label:5
# test(9946)     DNN:5 -- label:5
# test(9947)     DNN:4 -- label:4
# test(9948)     DNN:3 -- label:3
# test(9949)     DNN:5 -- label:5
# test(9950)     DNN:6 -- label:6
# test(9951)     DNN:3 -- label:7
# test(9952)     DNN:3 -- label:3
# test(9953)     DNN:5 -- label:5
# test(9954)     DNN:1 -- label:1
# test(9955)     DNN:0 -- label:0
# test(9956)     DNN:8 -- label:8
# test(9957)     DNN:7 -- label:7
# test(9958)     DNN:1 -- label:1
# test(9959)     DNN:5 -- label:5
# test(9960)     DNN:7 -- label:7
# test(9961)     DNN:4 -- label:4
# test(9962)     DNN:6 -- label:6
# test(9963)     DNN:5 -- label:5
# test(9964)     DNN:3 -- label:3
# test(9965)     DNN:3 -- label:3
# test(9966)     DNN:8 -- label:8
# test(9967)     DNN:0 -- label:0
# test(9968)     DNN:0 -- label:0
# test(9969)     DNN:7 -- label:7
# test(9970)     DNN:7 -- label:7
# test(9971)     DNN:6 -- label:6
# test(9972)     DNN:9 -- label:9
# test(9973)     DNN:8 -- label:2
# test(9974)     DNN:2 -- label:2
# test(9975)     DNN:3 -- label:3
# test(9976)     DNN:6 -- label:6
# test(9977)     DNN:0 -- label:0
# test(9978)     DNN:9 -- label:4
# test(9979)     DNN:5 -- label:5
# test(9980)     DNN:7 -- label:7
# test(9981)     DNN:4 -- label:4
# test(9982)     DNN:3 -- label:3
# test(9983)     DNN:8 -- label:8
# test(9984)     DNN:1 -- label:1
# test(9985)     DNN:6 -- label:6
# test(9986)     DNN:1 -- label:1
# test(9987)     DNN:2 -- label:2
# test(9988)     DNN:9 -- label:9
# test(9989)     DNN:6 -- label:6
# test(9990)     DNN:8 -- label:8
# test(9991)     DNN:9 -- label:9
# test(9992)     DNN:8 -- label:8
# test(9993)     DNN:8 -- label:8
# test(9994)     DNN:1 -- label:4
# test(9995)     DNN:0 -- label:0
# test(9996)     DNN:6 -- label:6
# test(9997)     DNN:1 -- label:1
# test(9998)     DNN:6 -- label:6
# test(9999)     DNN:1 -- label:1
# accuracy： 0.9217

# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
from torch.utils.data import DataLoader

# 分批次训练，一批 64 个
BATCH_SIZE = 64
# 所有样本训练 3 次
EPOCHS = 3
# 学习率设置为 0.0006
LEARN_RATE = 6e-4

# 若当前 Pytorch 版本以及电脑支持GPU，则使用 GPU 训练，否则使用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# 训练集数据加载
train_data = torchvision.datasets.MNIST(
    root='./mnist',
    train=True,
    transform=torchvision.transforms.ToTensor()
)
# 构建训练集的数据装载器，一次迭代有 BATCH_SIZE 张图片
train_loader = DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)

# 测试集数据加载
test_data = torchvision.datasets.MNIST(
    root='./mnist',
    train=False,
    transform=torchvision.transforms.ToTensor()
)
# 构建测试集的数据加载器，一次迭代 1 张图片，我们一张一张的测试
test_loader = DataLoader(dataset=test_data, batch_size=1, shuffle = True)

"""
此处我们定义了一个 3 层的网络
隐藏层 1：40 个神经元
隐藏层 2：20 个神经元
输出层：10 个神经元
"""
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        # 隐藏层 1，使用 sigmoid 激活函数
        self.layer1 = nn.Sequential(
            nn.Linear(784, 40),
            nn.Sigmoid()
		)
        # 隐藏层 2，使用 sigmoid 激活函数
        self.layer2 = nn.Sequential(
            nn.Linear(40, 20),
            nn.Sigmoid()
        )
        # 输出层
        self.layer_out = nn.Linear(20, 10)

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        self.out = self.layer_out(x)
        return self.out

# 实例化DNN，并将模型放在 GPU 训练
model = DNN().to(device)
# 同样，将损失函数放在 GPU
loss_fn = nn.MSELoss(reduction='mean').to(device)
#大数据常用Adam优化器，参数需要model的参数，以及学习率
optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE)

for epoch in range(EPOCHS):
    # 加载训练数据
    for step, data in enumerate(train_loader):
        x, y = data
        """
        因为此时的训练集即 x 大小为 （BATCH_SIZE, 1, 28, 28）
        因此这里需要一个形状转换为（BATCH_SIZE, 784）;

        y 中代表的是每张照片对应的数字，而我们输出的是 10 个神经元，
        即代表每个数字的概率
        因此这里将 y 也转换为该数字对应的 one-hot形式来表示
        """
        x = x.view(x.size(0), 784)
        yy = np.zeros((x.size(0), 10))
        for j in range(x.size(0)):
            yy[j][y[j].item()] = 1
        yy = torch.from_numpy(yy)
        yy = yy.float()
        x, yy = x.to(device), yy.to(device)

        # 调用模型预测
        output = model(x).to(device)
        # 计算损失值
        loss = loss_fn(output, yy)
        # 输出看一下损失变化
        print(f'EPOCH({epoch})   loss = {loss.item()}')
        # 每一次循环之前，将梯度清零
        optimizer.zero_grad()
        # 反向传播
        loss.backward()
        # 梯度下降，更新参数
        optimizer.step()

sum = 0
# test：
for i, data in enumerate(test_loader):

    x, y = data
    # 这里 仅对 x 进行处理
    x = x.view(x.size(0), 784)
    x, y = x.to(device), y.to(device)
    res = model(x).to(device)
    # 得到 模型预测值
    r = torch.argmax(res)
    # 标签，即真实值
    l = y.item()
    sum += 1 if r == l else 0
    print(f'test({i})     DNN:{r} -- label:{l}')

print('accuracy：', sum / 10000)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# test(5001)     DNN:9 -- label:9
# test(5002)     DNN:4 -- label:4
# test(5003)     DNN:4 -- label:4
# test(5004)     DNN:1 -- label:1
# test(5005)     DNN:8 -- label:8
# test(5006)     DNN:2 -- label:2
# test(5007)     DNN:0 -- label:0
# test(5008)     DNN:2 -- label:2
# test(5009)     DNN:4 -- label:4
# test(5010)     DNN:5 -- label:5
# test(5011)     DNN:5 -- label:5
# test(5012)     DNN:4 -- label:2
# test(5013)     DNN:3 -- label:3
# test(5014)     DNN:0 -- label:0
# test(5015)     DNN:9 -- label:9
# test(5016)     DNN:0 -- label:0
# test(5017)     DNN:6 -- label:6
# test(5018)     DNN:1 -- label:1
# test(5019)     DNN:8 -- label:8
# test(5020)     DNN:7 -- label:8
# test(5021)     DNN:3 -- label:3
# test(5022)     DNN:1 -- label:1
# test(5023)     DNN:5 -- label:5
# test(5024)     DNN:7 -- label:7
# test(5025)     DNN:3 -- label:3
# test(5026)     DNN:6 -- label:6
# test(5027)     DNN:5 -- label:5
# test(5028)     DNN:0 -- label:0
# test(5029)     DNN:5 -- label:5
# test(5030)     DNN:8 -- label:8
# test(5031)     DNN:2 -- label:2
# test(5032)     DNN:9 -- label:9
# test(5033)     DNN:6 -- label:6
# test(5034)     DNN:4 -- label:4
# test(5035)     DNN:7 -- label:7
# test(5036)     DNN:6 -- label:6
# test(5037)     DNN:0 -- label:0
# test(5038)     DNN:1 -- label:1
# test(5039)     DNN:5 -- label:5
# test(5040)     DNN:9 -- label:9
# test(5041)     DNN:0 -- label:0
# test(5042)     DNN:0 -- label:0
# test(5043)     DNN:0 -- label:0
# test(5044)     DNN:8 -- label:8
# test(5045)     DNN:0 -- label:0
# test(5046)     DNN:5 -- label:5
# test(5047)     DNN:2 -- label:2
# test(5048)     DNN:2 -- label:2
# test(5049)     DNN:2 -- label:2
# test(5050)     DNN:4 -- label:4
# test(5051)     DNN:3 -- label:3
# test(5052)     DNN:7 -- label:7
# test(5053)     DNN:1 -- label:1
# test(5054)     DNN:9 -- label:9
# test(5055)     DNN:4 -- label:4
# test(5056)     DNN:7 -- label:7
# test(5057)     DNN:7 -- label:7
# test(5058)     DNN:0 -- label:0
# test(5059)     DNN:4 -- label:5
# test(5060)     DNN:3 -- label:3
# test(5061)     DNN:4 -- label:4
# test(5062)     DNN:1 -- label:1
# test(5063)     DNN:0 -- label:2
# test(5064)     DNN:6 -- label:6
# test(5065)     DNN:7 -- label:7
# test(5066)     DNN:2 -- label:2
# test(5067)     DNN:8 -- label:8
# test(5068)     DNN:4 -- label:4
# test(5069)     DNN:5 -- label:5
# test(5070)     DNN:2 -- label:2
# test(5071)     DNN:0 -- label:0
# test(5072)     DNN:1 -- label:1
# test(5073)     DNN:2 -- label:2
# test(5074)     DNN:5 -- label:5
# test(5075)     DNN:6 -- label:6
# test(5076)     DNN:4 -- label:4
# test(5077)     DNN:0 -- label:0
# test(5078)     DNN:0 -- label:0
# test(5079)     DNN:5 -- label:5
# test(5080)     DNN:1 -- label:1
# test(5081)     DNN:6 -- label:6
# test(5082)     DNN:5 -- label:5
# test(5083)     DNN:5 -- label:5
# test(5084)     DNN:1 -- label:1
# test(5085)     DNN:0 -- label:0
# test(5086)     DNN:6 -- label:6
# test(5087)     DNN:6 -- label:6
# test(5088)     DNN:6 -- label:6
# test(5089)     DNN:4 -- label:4
# test(5090)     DNN:7 -- label:7
# test(5091)     DNN:2 -- label:2
# test(5092)     DNN:0 -- label:0
# test(5093)     DNN:1 -- label:7
# test(5094)     DNN:6 -- label:6
# test(5095)     DNN:4 -- label:4
# test(5096)     DNN:8 -- label:8
# test(5097)     DNN:2 -- label:2
# test(5098)     DNN:8 -- label:8
# test(5099)     DNN:5 -- label:5
# test(5100)     DNN:5 -- label:5
# test(5101)     DNN:4 -- label:4
# test(5102)     DNN:2 -- label:2
# test(5103)     DNN:5 -- label:5
# test(5104)     DNN:6 -- label:6
# test(5105)     DNN:1 -- label:1
# test(5106)     DNN:4 -- label:4
# test(5107)     DNN:4 -- label:4
# test(5108)     DNN:3 -- label:3
# test(5109)     DNN:5 -- label:5
# test(5110)     DNN:3 -- label:3
# test(5111)     DNN:3 -- label:3
# test(5112)     DNN:8 -- label:8
# test(5113)     DNN:3 -- label:3
# test(5114)     DNN:0 -- label:0
# test(5115)     DNN:2 -- label:2
# test(5116)     DNN:2 -- label:2
# test(5117)     DNN:6 -- label:6
# test(5118)     DNN:2 -- label:2
# test(5119)     DNN:0 -- label:0
# test(5120)     DNN:0 -- label:0
# test(5121)     DNN:6 -- label:6
# test(5122)     DNN:5 -- label:5
# test(5123)     DNN:4 -- label:4
# test(5124)     DNN:1 -- label:1
# test(5125)     DNN:9 -- label:4
# test(5126)     DNN:1 -- label:1
# test(5127)     DNN:4 -- label:4
# test(5128)     DNN:5 -- label:5
# test(5129)     DNN:7 -- label:7
# test(5130)     DNN:6 -- label:6
# test(5131)     DNN:9 -- label:7
# test(5132)     DNN:0 -- label:0
# test(5133)     DNN:3 -- label:3
# test(5134)     DNN:2 -- label:2
# test(5135)     DNN:7 -- label:7
# test(5136)     DNN:4 -- label:4
# test(5137)     DNN:3 -- label:3
# test(5138)     DNN:2 -- label:2
# test(5139)     DNN:6 -- label:6
# test(5140)     DNN:0 -- label:0
# test(5141)     DNN:3 -- label:2
# test(5142)     DNN:3 -- label:3
# test(5143)     DNN:9 -- label:9
# test(5144)     DNN:2 -- label:2
# test(5145)     DNN:3 -- label:2
# test(5146)     DNN:6 -- label:6
# test(5147)     DNN:6 -- label:6
# test(5148)     DNN:7 -- label:7
# test(5149)     DNN:3 -- label:3
# test(5150)     DNN:0 -- label:0
# test(5151)     DNN:5 -- label:3
# test(5152)     DNN:7 -- label:7
# test(5153)     DNN:7 -- label:7
# test(5154)     DNN:0 -- label:0
# test(5155)     DNN:6 -- label:6
# test(5156)     DNN:4 -- label:4
# test(5157)     DNN:1 -- label:1
# test(5158)     DNN:5 -- label:5
# test(5159)     DNN:1 -- label:1
# test(5160)     DNN:5 -- label:5
# test(5161)     DNN:7 -- label:7
# test(5162)     DNN:3 -- label:3
# test(5163)     DNN:0 -- label:0
# test(5164)     DNN:5 -- label:5
# test(5165)     DNN:6 -- label:6
# test(5166)     DNN:1 -- label:1
# test(5167)     DNN:0 -- label:0
# test(5168)     DNN:4 -- label:4
# test(5169)     DNN:2 -- label:2
# test(5170)     DNN:5 -- label:5
# test(5171)     DNN:0 -- label:0
# test(5172)     DNN:6 -- label:6
# test(5173)     DNN:6 -- label:6
# test(5174)     DNN:7 -- label:7
# test(5175)     DNN:7 -- label:7
# test(5176)     DNN:9 -- label:7
# test(5177)     DNN:3 -- label:3
# test(5178)     DNN:3 -- label:3
# test(5179)     DNN:8 -- label:8
# test(5180)     DNN:8 -- label:8
# test(5181)     DNN:5 -- label:5
# test(5182)     DNN:3 -- label:9
# test(5183)     DNN:1 -- label:1
# test(5184)     DNN:2 -- label:2
# test(5185)     DNN:4 -- label:4
# test(5186)     DNN:0 -- label:0
# test(5187)     DNN:1 -- label:1
# test(5188)     DNN:3 -- label:3
# test(5189)     DNN:6 -- label:6
# test(5190)     DNN:4 -- label:4
# test(5191)     DNN:6 -- label:6
# test(5192)     DNN:1 -- label:1
# test(5193)     DNN:4 -- label:4
# test(5194)     DNN:0 -- label:0
# test(5195)     DNN:3 -- label:7
# test(5196)     DNN:2 -- label:2
# test(5197)     DNN:7 -- label:4
# test(5198)     DNN:7 -- label:7
# test(5199)     DNN:3 -- label:3
# test(5200)     DNN:8 -- label:8
# test(5201)     DNN:1 -- label:1
# test(5202)     DNN:2 -- label:2
# test(5203)     DNN:7 -- label:7
# test(5204)     DNN:0 -- label:0
# test(5205)     DNN:8 -- label:8
# test(5206)     DNN:0 -- label:0
# test(5207)     DNN:9 -- label:9
# test(5208)     DNN:3 -- label:3
# test(5209)     DNN:4 -- label:4
# test(5210)     DNN:0 -- label:0
# test(5211)     DNN:4 -- label:4
# test(5212)     DNN:0 -- label:0
# test(5213)     DNN:3 -- label:3
# test(5214)     DNN:0 -- label:9
# test(5215)     DNN:7 -- label:3
# test(5216)     DNN:4 -- label:4
# test(5217)     DNN:2 -- label:2
# test(5218)     DNN:5 -- label:5
# test(5219)     DNN:3 -- label:3
# test(5220)     DNN:5 -- label:5
# test(5221)     DNN:0 -- label:6
# test(5222)     DNN:2 -- label:2
# test(5223)     DNN:2 -- label:2
# test(5224)     DNN:6 -- label:6
# test(5225)     DNN:5 -- label:5
# test(5226)     DNN:2 -- label:2
# test(5227)     DNN:5 -- label:5
# test(5228)     DNN:8 -- label:8
# test(5229)     DNN:3 -- label:3
# test(5230)     DNN:9 -- label:9
# test(5231)     DNN:1 -- label:1
# test(5232)     DNN:0 -- label:0
# test(5233)     DNN:1 -- label:1
# test(5234)     DNN:0 -- label:0
# test(5235)     DNN:5 -- label:5
# test(5236)     DNN:7 -- label:7
# test(5237)     DNN:6 -- label:6
# test(5238)     DNN:7 -- label:7
# test(5239)     DNN:7 -- label:7
# test(5240)     DNN:7 -- label:7
# test(5241)     DNN:1 -- label:1
# test(5242)     DNN:6 -- label:6
# test(5243)     DNN:7 -- label:7
# test(5244)     DNN:6 -- label:6
# test(5245)     DNN:6 -- label:6
# test(5246)     DNN:3 -- label:3
# test(5247)     DNN:7 -- label:7
# test(5248)     DNN:2 -- label:2
# test(5249)     DNN:4 -- label:4
# test(5250)     DNN:9 -- label:9
# test(5251)     DNN:8 -- label:8
# test(5252)     DNN:3 -- label:3
# test(5253)     DNN:6 -- label:6
# test(5254)     DNN:4 -- label:4
# test(5255)     DNN:3 -- label:3
# test(5256)     DNN:9 -- label:9
# test(5257)     DNN:8 -- label:8
# test(5258)     DNN:3 -- label:3
# test(5259)     DNN:0 -- label:0
# test(5260)     DNN:4 -- label:4
# test(5261)     DNN:3 -- label:3
# test(5262)     DNN:0 -- label:0
# test(5263)     DNN:7 -- label:7
# test(5264)     DNN:6 -- label:6
# test(5265)     DNN:9 -- label:4
# test(5266)     DNN:4 -- label:4
# test(5267)     DNN:5 -- label:3
# test(5268)     DNN:6 -- label:6
# test(5269)     DNN:0 -- label:0
# test(5270)     DNN:5 -- label:5
# test(5271)     DNN:9 -- label:9
# test(5272)     DNN:8 -- label:8
# test(5273)     DNN:4 -- label:4
# test(5274)     DNN:5 -- label:5
# test(5275)     DNN:0 -- label:0
# test(5276)     DNN:1 -- label:1
# test(5277)     DNN:8 -- label:8
# test(5278)     DNN:4 -- label:4
# test(5279)     DNN:1 -- label:1
# test(5280)     DNN:1 -- label:1
# test(5281)     DNN:3 -- label:3
# test(5282)     DNN:6 -- label:6
# test(5283)     DNN:9 -- label:9
# test(5284)     DNN:9 -- label:9
# test(5285)     DNN:2 -- label:2
# test(5286)     DNN:5 -- label:5
# test(5287)     DNN:3 -- label:3
# test(5288)     DNN:7 -- label:7
# test(5289)     DNN:6 -- label:6
# test(5290)     DNN:8 -- label:8
# test(5291)     DNN:1 -- label:1
# test(5292)     DNN:6 -- label:6
# test(5293)     DNN:2 -- label:2
# test(5294)     DNN:3 -- label:3
# test(5295)     DNN:1 -- label:1
# test(5296)     DNN:1 -- label:1
# test(5297)     DNN:6 -- label:6
# test(5298)     DNN:9 -- label:9
# test(5299)     DNN:6 -- label:6
# test(5300)     DNN:8 -- label:8
# test(5301)     DNN:9 -- label:4
# test(5302)     DNN:5 -- label:5
# test(5303)     DNN:4 -- label:4
# test(5304)     DNN:7 -- label:7
# test(5305)     DNN:2 -- label:2
# test(5306)     DNN:4 -- label:4
# test(5307)     DNN:3 -- label:3
# test(5308)     DNN:9 -- label:9
# test(5309)     DNN:9 -- label:9
# test(5310)     DNN:8 -- label:8
# test(5311)     DNN:3 -- label:3
# test(5312)     DNN:5 -- label:5
# test(5313)     DNN:4 -- label:4
# test(5314)     DNN:8 -- label:8
# test(5315)     DNN:6 -- label:6
# test(5316)     DNN:4 -- label:4
# test(5317)     DNN:9 -- label:9
# test(5318)     DNN:0 -- label:0
# test(5319)     DNN:1 -- label:1
# test(5320)     DNN:3 -- label:2
# test(5321)     DNN:9 -- label:9
# test(5322)     DNN:3 -- label:3
# test(5323)     DNN:6 -- label:6
# test(5324)     DNN:6 -- label:6
# test(5325)     DNN:6 -- label:6
# test(5326)     DNN:7 -- label:7
# test(5327)     DNN:0 -- label:0
# test(5328)     DNN:0 -- label:0
# test(5329)     DNN:7 -- label:7
# test(5330)     DNN:4 -- label:4
# test(5331)     DNN:4 -- label:9
# test(5332)     DNN:5 -- label:5
# test(5333)     DNN:0 -- label:0
# test(5334)     DNN:8 -- label:8
# test(5335)     DNN:0 -- label:0
# test(5336)     DNN:8 -- label:8
# test(5337)     DNN:1 -- label:1
# test(5338)     DNN:3 -- label:3
# test(5339)     DNN:9 -- label:9
# test(5340)     DNN:1 -- label:1
# test(5341)     DNN:8 -- label:8
# test(5342)     DNN:5 -- label:5
# test(5343)     DNN:5 -- label:0
# test(5344)     DNN:8 -- label:2
# test(5345)     DNN:4 -- label:4
# test(5346)     DNN:2 -- label:2
# test(5347)     DNN:8 -- label:8
# test(5348)     DNN:5 -- label:5
# test(5349)     DNN:8 -- label:8
# test(5350)     DNN:4 -- label:4
# test(5351)     DNN:0 -- label:0
# test(5352)     DNN:9 -- label:9
# test(5353)     DNN:0 -- label:0
# test(5354)     DNN:0 -- label:0
# test(5355)     DNN:1 -- label:1
# test(5356)     DNN:0 -- label:0
# test(5357)     DNN:0 -- label:0
# test(5358)     DNN:4 -- label:4
# test(5359)     DNN:8 -- label:1
# test(5360)     DNN:0 -- label:5
# test(5361)     DNN:0 -- label:0
# test(5362)     DNN:7 -- label:7
# test(5363)     DNN:0 -- label:0
# test(5364)     DNN:4 -- label:4
# test(5365)     DNN:1 -- label:1
# test(5366)     DNN:0 -- label:0
# test(5367)     DNN:8 -- label:8
# test(5368)     DNN:4 -- label:4
# test(5369)     DNN:5 -- label:5
# test(5370)     DNN:2 -- label:2
# test(5371)     DNN:2 -- label:2
# test(5372)     DNN:0 -- label:0
# test(5373)     DNN:4 -- label:4
# test(5374)     DNN:3 -- label:3
# test(5375)     DNN:3 -- label:3
# test(5376)     DNN:3 -- label:3
# test(5377)     DNN:3 -- label:3
# test(5378)     DNN:8 -- label:8
# test(5379)     DNN:8 -- label:8
# test(5380)     DNN:2 -- label:2
# test(5381)     DNN:5 -- label:5
# test(5382)     DNN:4 -- label:4
# test(5383)     DNN:4 -- label:4
# test(5384)     DNN:0 -- label:0
# test(5385)     DNN:2 -- label:2
# test(5386)     DNN:3 -- label:3
# test(5387)     DNN:1 -- label:1
# test(5388)     DNN:2 -- label:2
# test(5389)     DNN:0 -- label:0
# test(5390)     DNN:8 -- label:8
# test(5391)     DNN:5 -- label:5
# test(5392)     DNN:0 -- label:0
# test(5393)     DNN:3 -- label:3
# test(5394)     DNN:1 -- label:1
# test(5395)     DNN:1 -- label:1
# test(5396)     DNN:0 -- label:0
# test(5397)     DNN:8 -- label:4
# test(5398)     DNN:1 -- label:1
# test(5399)     DNN:8 -- label:8
# test(5400)     DNN:4 -- label:4
# test(5401)     DNN:3 -- label:3
# test(5402)     DNN:5 -- label:5
# test(5403)     DNN:4 -- label:4
# test(5404)     DNN:4 -- label:4
# test(5405)     DNN:2 -- label:2
# test(5406)     DNN:1 -- label:1
# test(5407)     DNN:7 -- label:7
# test(5408)     DNN:5 -- label:5
# test(5409)     DNN:0 -- label:0
# test(5410)     DNN:0 -- label:0
# test(5411)     DNN:8 -- label:8
# test(5412)     DNN:6 -- label:6
# test(5413)     DNN:1 -- label:1
# test(5414)     DNN:5 -- label:5
# test(5415)     DNN:9 -- label:9
# test(5416)     DNN:0 -- label:0
# test(5417)     DNN:6 -- label:0
# test(5418)     DNN:2 -- label:2
# test(5419)     DNN:3 -- label:3
# test(5420)     DNN:9 -- label:9
# test(5421)     DNN:3 -- label:3
# test(5422)     DNN:8 -- label:8
# test(5423)     DNN:8 -- label:8
# test(5424)     DNN:2 -- label:2
# test(5425)     DNN:1 -- label:1
# test(5426)     DNN:2 -- label:2
# test(5427)     DNN:6 -- label:6
# test(5428)     DNN:8 -- label:8
# test(5429)     DNN:7 -- label:7
# test(5430)     DNN:8 -- label:8
# test(5431)     DNN:0 -- label:0
# test(5432)     DNN:0 -- label:0
# test(5433)     DNN:1 -- label:1
# test(5434)     DNN:1 -- label:1
# test(5435)     DNN:0 -- label:0
# test(5436)     DNN:0 -- label:0
# test(5437)     DNN:2 -- label:2
# test(5438)     DNN:9 -- label:9
# test(5439)     DNN:8 -- label:8
# test(5440)     DNN:3 -- label:3
# test(5441)     DNN:1 -- label:1
# test(5442)     DNN:6 -- label:6
# test(5443)     DNN:5 -- label:5
# test(5444)     DNN:8 -- label:8
# test(5445)     DNN:3 -- label:3
# test(5446)     DNN:1 -- label:7
# test(5447)     DNN:8 -- label:8
# test(5448)     DNN:9 -- label:9
# test(5449)     DNN:6 -- label:8
# test(5450)     DNN:7 -- label:7
# test(5451)     DNN:4 -- label:4
# test(5452)     DNN:3 -- label:3
# test(5453)     DNN:0 -- label:0
# test(5454)     DNN:3 -- label:3
# test(5455)     DNN:1 -- label:1
# test(5456)     DNN:9 -- label:9
# test(5457)     DNN:0 -- label:0
# test(5458)     DNN:6 -- label:6
# test(5459)     DNN:3 -- label:3
# test(5460)     DNN:3 -- label:3
# test(5461)     DNN:9 -- label:9
# test(5462)     DNN:2 -- label:2
# test(5463)     DNN:9 -- label:9
# test(5464)     DNN:2 -- label:2
# test(5465)     DNN:8 -- label:8
# test(5466)     DNN:1 -- label:1
# test(5467)     DNN:3 -- label:1
# test(5468)     DNN:9 -- label:9
# test(5469)     DNN:0 -- label:0
# test(5470)     DNN:5 -- label:5
# test(5471)     DNN:4 -- label:4
# test(5472)     DNN:6 -- label:6
# test(5473)     DNN:5 -- label:5
# test(5474)     DNN:9 -- label:7
# test(5475)     DNN:7 -- label:7
# test(5476)     DNN:4 -- label:4
# test(5477)     DNN:1 -- label:1
# test(5478)     DNN:8 -- label:8
# test(5479)     DNN:1 -- label:7
# test(5480)     DNN:8 -- label:8
# test(5481)     DNN:6 -- label:6
# test(5482)     DNN:0 -- label:0
# test(5483)     DNN:4 -- label:4
# test(5484)     DNN:6 -- label:6
# test(5485)     DNN:1 -- label:1
# test(5486)     DNN:7 -- label:7
# test(5487)     DNN:8 -- label:8
# test(5488)     DNN:8 -- label:8
# test(5489)     DNN:5 -- label:5
# test(5490)     DNN:2 -- label:2
# test(5491)     DNN:1 -- label:1
# test(5492)     DNN:9 -- label:4
# test(5493)     DNN:8 -- label:8
# test(5494)     DNN:3 -- label:3
# test(5495)     DNN:2 -- label:2
# test(5496)     DNN:0 -- label:0
# test(5497)     DNN:0 -- label:0
# test(5498)     DNN:5 -- label:9
# test(5499)     DNN:7 -- label:7
# test(5500)     DNN:1 -- label:1
# test(5501)     DNN:9 -- label:9
# test(5502)     DNN:5 -- label:5
# test(5503)     DNN:7 -- label:9
# test(5504)     DNN:7 -- label:7
# test(5505)     DNN:0 -- label:0
# test(5506)     DNN:0 -- label:0
# test(5507)     DNN:8 -- label:8
# test(5508)     DNN:8 -- label:8
# test(5509)     DNN:0 -- label:0
# test(5510)     DNN:8 -- label:3
# test(5511)     DNN:8 -- label:8
# test(5512)     DNN:5 -- label:5
# test(5513)     DNN:8 -- label:3
# test(5514)     DNN:1 -- label:1
# test(5515)     DNN:3 -- label:3
# test(5516)     DNN:5 -- label:5
# test(5517)     DNN:0 -- label:0
# test(5518)     DNN:2 -- label:2
# test(5519)     DNN:6 -- label:6
# test(5520)     DNN:9 -- label:9
# test(5521)     DNN:8 -- label:8
# test(5522)     DNN:3 -- label:3
# test(5523)     DNN:2 -- label:2
# test(5524)     DNN:4 -- label:4
# test(5525)     DNN:1 -- label:1
# test(5526)     DNN:7 -- label:7
# test(5527)     DNN:6 -- label:6
# test(5528)     DNN:8 -- label:8
# test(5529)     DNN:7 -- label:7
# test(5530)     DNN:7 -- label:7
# test(5531)     DNN:1 -- label:1
# test(5532)     DNN:3 -- label:3
# test(5533)     DNN:0 -- label:0
# test(5534)     DNN:5 -- label:5
# test(5535)     DNN:5 -- label:8
# test(5536)     DNN:9 -- label:9
# test(5537)     DNN:7 -- label:7
# test(5538)     DNN:4 -- label:4
# test(5539)     DNN:1 -- label:1
# test(5540)     DNN:7 -- label:7
# test(5541)     DNN:6 -- label:6
# test(5542)     DNN:5 -- label:5
# test(5543)     DNN:1 -- label:1
# test(5544)     DNN:1 -- label:1
# test(5545)     DNN:2 -- label:2
# test(5546)     DNN:4 -- label:4
# test(5547)     DNN:6 -- label:6
# test(5548)     DNN:3 -- label:3
# test(5549)     DNN:1 -- label:1
# test(5550)     DNN:9 -- label:9
# test(5551)     DNN:1 -- label:1
# test(5552)     DNN:0 -- label:0
# test(5553)     DNN:3 -- label:3
# test(5554)     DNN:9 -- label:9
# test(5555)     DNN:4 -- label:4
# test(5556)     DNN:6 -- label:6
# test(5557)     DNN:0 -- label:0
# test(5558)     DNN:2 -- label:2
# test(5559)     DNN:3 -- label:3
# test(5560)     DNN:1 -- label:1
# test(5561)     DNN:0 -- label:0
# test(5562)     DNN:2 -- label:7
# test(5563)     DNN:4 -- label:4
# test(5564)     DNN:5 -- label:5
# test(5565)     DNN:2 -- label:2
# test(5566)     DNN:4 -- label:4
# test(5567)     DNN:7 -- label:7
# test(5568)     DNN:1 -- label:1
# test(5569)     DNN:1 -- label:7
# test(5570)     DNN:3 -- label:3
# test(5571)     DNN:1 -- label:1
# test(5572)     DNN:1 -- label:1
# test(5573)     DNN:2 -- label:2
# test(5574)     DNN:3 -- label:3
# test(5575)     DNN:7 -- label:7
# test(5576)     DNN:4 -- label:4
# test(5577)     DNN:3 -- label:3
# test(5578)     DNN:2 -- label:2
# test(5579)     DNN:0 -- label:0
# test(5580)     DNN:6 -- label:6
# test(5581)     DNN:0 -- label:0
# test(5582)     DNN:2 -- label:2
# test(5583)     DNN:1 -- label:1
# test(5584)     DNN:3 -- label:3
# test(5585)     DNN:6 -- label:6
# test(5586)     DNN:1 -- label:1
# test(5587)     DNN:6 -- label:6
# test(5588)     DNN:5 -- label:5
# test(5589)     DNN:2 -- label:2
# test(5590)     DNN:1 -- label:1
# test(5591)     DNN:3 -- label:3
# test(5592)     DNN:9 -- label:9
# test(5593)     DNN:7 -- label:7
# test(5594)     DNN:1 -- label:1
# test(5595)     DNN:4 -- label:4
# test(5596)     DNN:9 -- label:9
# test(5597)     DNN:1 -- label:1
# test(5598)     DNN:6 -- label:6
# test(5599)     DNN:0 -- label:0
# test(5600)     DNN:6 -- label:6
# test(5601)     DNN:2 -- label:2
# test(5602)     DNN:5 -- label:5
# test(5603)     DNN:8 -- label:8
# test(5604)     DNN:8 -- label:8
# test(5605)     DNN:7 -- label:7
# test(5606)     DNN:7 -- label:7
# test(5607)     DNN:5 -- label:5
# test(5608)     DNN:6 -- label:6
# test(5609)     DNN:1 -- label:4
# test(5610)     DNN:1 -- label:1
# test(5611)     DNN:4 -- label:4
# test(5612)     DNN:3 -- label:3
# test(5613)     DNN:1 -- label:1
# test(5614)     DNN:7 -- label:7
# test(5615)     DNN:1 -- label:1
# test(5616)     DNN:8 -- label:8
# test(5617)     DNN:1 -- label:1
# test(5618)     DNN:6 -- label:6
# test(5619)     DNN:1 -- label:1
# test(5620)     DNN:3 -- label:3
# test(5621)     DNN:3 -- label:3
# test(5622)     DNN:9 -- label:9
# test(5623)     DNN:7 -- label:7
# test(5624)     DNN:9 -- label:9
# test(5625)     DNN:4 -- label:4
# test(5626)     DNN:2 -- label:2
# test(5627)     DNN:6 -- label:6
# test(5628)     DNN:7 -- label:7
# test(5629)     DNN:9 -- label:9
# test(5630)     DNN:1 -- label:1
# test(5631)     DNN:2 -- label:2
# test(5632)     DNN:6 -- label:6
# test(5633)     DNN:9 -- label:9
# test(5634)     DNN:5 -- label:5
# test(5635)     DNN:8 -- label:8
# test(5636)     DNN:0 -- label:0
# test(5637)     DNN:0 -- label:0
# test(5638)     DNN:8 -- label:8
# test(5639)     DNN:2 -- label:2
# test(5640)     DNN:1 -- label:1
# test(5641)     DNN:1 -- label:1
# test(5642)     DNN:6 -- label:6
# test(5643)     DNN:2 -- label:2
# test(5644)     DNN:8 -- label:8
# test(5645)     DNN:3 -- label:3
# test(5646)     DNN:0 -- label:0
# test(5647)     DNN:1 -- label:1
# test(5648)     DNN:8 -- label:8
# test(5649)     DNN:9 -- label:9
# test(5650)     DNN:3 -- label:3
# test(5651)     DNN:2 -- label:3
# test(5652)     DNN:7 -- label:7
# test(5653)     DNN:7 -- label:7
# test(5654)     DNN:7 -- label:7
# test(5655)     DNN:4 -- label:4
# test(5656)     DNN:3 -- label:3
# test(5657)     DNN:1 -- label:1
# test(5658)     DNN:3 -- label:3
# test(5659)     DNN:2 -- label:2
# test(5660)     DNN:7 -- label:7
# test(5661)     DNN:9 -- label:9
# test(5662)     DNN:4 -- label:4
# test(5663)     DNN:5 -- label:5
# test(5664)     DNN:4 -- label:4
# test(5665)     DNN:3 -- label:3
# test(5666)     DNN:9 -- label:9
# test(5667)     DNN:8 -- label:7
# test(5668)     DNN:8 -- label:8
# test(5669)     DNN:5 -- label:5
# test(5670)     DNN:6 -- label:6
# test(5671)     DNN:9 -- label:9
# test(5672)     DNN:4 -- label:4
# test(5673)     DNN:1 -- label:1
# test(5674)     DNN:1 -- label:1
# test(5675)     DNN:8 -- label:8
# test(5676)     DNN:1 -- label:1
# test(5677)     DNN:5 -- label:5
# test(5678)     DNN:0 -- label:0
# test(5679)     DNN:9 -- label:9
# test(5680)     DNN:2 -- label:7
# test(5681)     DNN:2 -- label:3
# test(5682)     DNN:5 -- label:5
# test(5683)     DNN:8 -- label:8
# test(5684)     DNN:5 -- label:5
# test(5685)     DNN:2 -- label:2
# test(5686)     DNN:3 -- label:3
# test(5687)     DNN:4 -- label:4
# test(5688)     DNN:1 -- label:1
# test(5689)     DNN:4 -- label:4
# test(5690)     DNN:7 -- label:7
# test(5691)     DNN:1 -- label:1
# test(5692)     DNN:1 -- label:1
# test(5693)     DNN:4 -- label:4
# test(5694)     DNN:3 -- label:3
# test(5695)     DNN:6 -- label:6
# test(5696)     DNN:0 -- label:0
# test(5697)     DNN:6 -- label:6
# test(5698)     DNN:2 -- label:2
# test(5699)     DNN:3 -- label:3
# test(5700)     DNN:0 -- label:0
# test(5701)     DNN:4 -- label:5
# test(5702)     DNN:8 -- label:8
# test(5703)     DNN:6 -- label:6
# test(5704)     DNN:3 -- label:3
# test(5705)     DNN:3 -- label:3
# test(5706)     DNN:2 -- label:2
# test(5707)     DNN:3 -- label:3
# test(5708)     DNN:3 -- label:3
# test(5709)     DNN:1 -- label:1
# test(5710)     DNN:6 -- label:6
# test(5711)     DNN:5 -- label:5
# test(5712)     DNN:9 -- label:9
# test(5713)     DNN:8 -- label:8
# test(5714)     DNN:4 -- label:4
# test(5715)     DNN:8 -- label:3
# test(5716)     DNN:5 -- label:5
# test(5717)     DNN:6 -- label:6
# test(5718)     DNN:0 -- label:0
# test(5719)     DNN:9 -- label:9
# test(5720)     DNN:8 -- label:8
# test(5721)     DNN:4 -- label:2
# test(5722)     DNN:8 -- label:8
# test(5723)     DNN:2 -- label:2
# test(5724)     DNN:0 -- label:0
# test(5725)     DNN:6 -- label:6
# test(5726)     DNN:6 -- label:6
# test(5727)     DNN:2 -- label:2
# test(5728)     DNN:4 -- label:4
# test(5729)     DNN:6 -- label:6
# test(5730)     DNN:8 -- label:1
# test(5731)     DNN:9 -- label:9
# test(5732)     DNN:4 -- label:4
# test(5733)     DNN:9 -- label:9
# test(5734)     DNN:2 -- label:2
# test(5735)     DNN:3 -- label:3
# test(5736)     DNN:5 -- label:5
# test(5737)     DNN:6 -- label:6
# test(5738)     DNN:4 -- label:8
# test(5739)     DNN:8 -- label:8
# test(5740)     DNN:1 -- label:1
# test(5741)     DNN:4 -- label:4
# test(5742)     DNN:4 -- label:4
# test(5743)     DNN:4 -- label:4
# test(5744)     DNN:4 -- label:4
# test(5745)     DNN:6 -- label:6
# test(5746)     DNN:4 -- label:4
# test(5747)     DNN:0 -- label:0
# test(5748)     DNN:6 -- label:6
# test(5749)     DNN:1 -- label:1
# test(5750)     DNN:7 -- label:7
# test(5751)     DNN:7 -- label:7
# test(5752)     DNN:6 -- label:4
# test(5753)     DNN:1 -- label:6
# test(5754)     DNN:6 -- label:6
# test(5755)     DNN:4 -- label:4
# test(5756)     DNN:4 -- label:4
# test(5757)     DNN:9 -- label:9
# test(5758)     DNN:9 -- label:9
# test(5759)     DNN:8 -- label:8
# test(5760)     DNN:2 -- label:2
# test(5761)     DNN:9 -- label:9
# test(5762)     DNN:4 -- label:4
# test(5763)     DNN:6 -- label:1
# test(5764)     DNN:6 -- label:6
# test(5765)     DNN:3 -- label:3
# test(5766)     DNN:0 -- label:0
# test(5767)     DNN:0 -- label:0
# test(5768)     DNN:1 -- label:1
# test(5769)     DNN:9 -- label:9
# test(5770)     DNN:5 -- label:5
# test(5771)     DNN:1 -- label:1
# test(5772)     DNN:6 -- label:6
# test(5773)     DNN:0 -- label:0
# test(5774)     DNN:5 -- label:5
# test(5775)     DNN:7 -- label:7
# test(5776)     DNN:7 -- label:7
# test(5777)     DNN:7 -- label:7
# test(5778)     DNN:1 -- label:1
# test(5779)     DNN:1 -- label:1
# test(5780)     DNN:6 -- label:6
# test(5781)     DNN:1 -- label:1
# test(5782)     DNN:8 -- label:8
# test(5783)     DNN:3 -- label:3
# test(5784)     DNN:5 -- label:5
# test(5785)     DNN:3 -- label:3
# test(5786)     DNN:3 -- label:3
# test(5787)     DNN:0 -- label:0
# test(5788)     DNN:7 -- label:5
# test(5789)     DNN:1 -- label:1
# test(5790)     DNN:4 -- label:8
# test(5791)     DNN:3 -- label:3
# test(5792)     DNN:9 -- label:9
# test(5793)     DNN:4 -- label:4
# test(5794)     DNN:0 -- label:0
# test(5795)     DNN:8 -- label:8
# test(5796)     DNN:1 -- label:1
# test(5797)     DNN:4 -- label:4
# test(5798)     DNN:7 -- label:2
# test(5799)     DNN:8 -- label:8
# test(5800)     DNN:9 -- label:7
# test(5801)     DNN:5 -- label:5
# test(5802)     DNN:8 -- label:8
# test(5803)     DNN:9 -- label:9
# test(5804)     DNN:4 -- label:4
# test(5805)     DNN:4 -- label:4
# test(5806)     DNN:1 -- label:1
# test(5807)     DNN:2 -- label:2
# test(5808)     DNN:7 -- label:7
# test(5809)     DNN:1 -- label:1
# test(5810)     DNN:1 -- label:1
# test(5811)     DNN:2 -- label:2
# test(5812)     DNN:2 -- label:2
# test(5813)     DNN:8 -- label:8
# test(5814)     DNN:7 -- label:7
# test(5815)     DNN:1 -- label:1
# test(5816)     DNN:2 -- label:2
# test(5817)     DNN:6 -- label:5
# test(5818)     DNN:1 -- label:5
# test(5819)     DNN:7 -- label:7
# test(5820)     DNN:4 -- label:9
# test(5821)     DNN:7 -- label:7
# test(5822)     DNN:1 -- label:1
# test(5823)     DNN:7 -- label:7
# test(5824)     DNN:7 -- label:7
# test(5825)     DNN:0 -- label:0
# test(5826)     DNN:9 -- label:9
# test(5827)     DNN:9 -- label:9
# test(5828)     DNN:4 -- label:4
# test(5829)     DNN:5 -- label:5
# test(5830)     DNN:5 -- label:5
# test(5831)     DNN:4 -- label:4
# test(5832)     DNN:9 -- label:9
# test(5833)     DNN:3 -- label:3
# test(5834)     DNN:8 -- label:8
# test(5835)     DNN:8 -- label:8
# test(5836)     DNN:9 -- label:8
# test(5837)     DNN:1 -- label:1
# test(5838)     DNN:5 -- label:5
# test(5839)     DNN:8 -- label:8
# test(5840)     DNN:0 -- label:0
# test(5841)     DNN:8 -- label:8
# test(5842)     DNN:0 -- label:0
# test(5843)     DNN:9 -- label:9
# test(5844)     DNN:1 -- label:1
# test(5845)     DNN:6 -- label:6
# test(5846)     DNN:4 -- label:4
# test(5847)     DNN:6 -- label:6
# test(5848)     DNN:4 -- label:4
# test(5849)     DNN:1 -- label:1
# test(5850)     DNN:6 -- label:6
# test(5851)     DNN:7 -- label:7
# test(5852)     DNN:7 -- label:7
# test(5853)     DNN:1 -- label:1
# test(5854)     DNN:5 -- label:9
# test(5855)     DNN:2 -- label:2
# test(5856)     DNN:9 -- label:5
# test(5857)     DNN:3 -- label:3
# test(5858)     DNN:8 -- label:8
# test(5859)     DNN:1 -- label:1
# test(5860)     DNN:3 -- label:3
# test(5861)     DNN:6 -- label:6
# test(5862)     DNN:5 -- label:5
# test(5863)     DNN:1 -- label:1
# test(5864)     DNN:9 -- label:9
# test(5865)     DNN:6 -- label:6
# test(5866)     DNN:7 -- label:7
# test(5867)     DNN:1 -- label:1
# test(5868)     DNN:2 -- label:2
# test(5869)     DNN:1 -- label:1
# test(5870)     DNN:0 -- label:8
# test(5871)     DNN:7 -- label:7
# test(5872)     DNN:4 -- label:4
# test(5873)     DNN:1 -- label:1
# test(5874)     DNN:2 -- label:4
# test(5875)     DNN:4 -- label:4
# test(5876)     DNN:9 -- label:9
# test(5877)     DNN:3 -- label:3
# test(5878)     DNN:2 -- label:2
# test(5879)     DNN:7 -- label:7
# test(5880)     DNN:0 -- label:0
# test(5881)     DNN:1 -- label:1
# test(5882)     DNN:7 -- label:7
# test(5883)     DNN:8 -- label:8
# test(5884)     DNN:5 -- label:5
# test(5885)     DNN:9 -- label:9
# test(5886)     DNN:9 -- label:9
# test(5887)     DNN:7 -- label:7
# test(5888)     DNN:7 -- label:7
# test(5889)     DNN:2 -- label:7
# test(5890)     DNN:7 -- label:7
# test(5891)     DNN:3 -- label:2
# test(5892)     DNN:0 -- label:0
# test(5893)     DNN:5 -- label:5
# test(5894)     DNN:9 -- label:9
# test(5895)     DNN:2 -- label:2
# test(5896)     DNN:0 -- label:0
# test(5897)     DNN:7 -- label:7
# test(5898)     DNN:6 -- label:0
# test(5899)     DNN:2 -- label:2
# test(5900)     DNN:2 -- label:2
# test(5901)     DNN:7 -- label:7
# test(5902)     DNN:7 -- label:7
# test(5903)     DNN:1 -- label:1
# test(5904)     DNN:6 -- label:6
# test(5905)     DNN:4 -- label:4
# test(5906)     DNN:0 -- label:0
# test(5907)     DNN:2 -- label:2
# test(5908)     DNN:6 -- label:6
# test(5909)     DNN:2 -- label:7
# test(5910)     DNN:0 -- label:0
# test(5911)     DNN:1 -- label:1
# test(5912)     DNN:4 -- label:2
# test(5913)     DNN:0 -- label:0
# test(5914)     DNN:5 -- label:5
# test(5915)     DNN:1 -- label:1
# test(5916)     DNN:6 -- label:6
# test(5917)     DNN:2 -- label:2
# test(5918)     DNN:3 -- label:3
# test(5919)     DNN:8 -- label:8
# test(5920)     DNN:5 -- label:5
# test(5921)     DNN:9 -- label:9
# test(5922)     DNN:6 -- label:6
# test(5923)     DNN:2 -- label:2
# test(5924)     DNN:5 -- label:5
# test(5925)     DNN:5 -- label:5
# test(5926)     DNN:1 -- label:1
# test(5927)     DNN:4 -- label:4
# test(5928)     DNN:2 -- label:2
# test(5929)     DNN:0 -- label:0
# test(5930)     DNN:6 -- label:6
# test(5931)     DNN:1 -- label:1
# test(5932)     DNN:8 -- label:4
# test(5933)     DNN:2 -- label:2
# test(5934)     DNN:8 -- label:8
# test(5935)     DNN:8 -- label:8
# test(5936)     DNN:6 -- label:6
# test(5937)     DNN:7 -- label:7
# test(5938)     DNN:8 -- label:8
# test(5939)     DNN:0 -- label:0
# test(5940)     DNN:7 -- label:7
# test(5941)     DNN:3 -- label:3
# test(5942)     DNN:7 -- label:7
# test(5943)     DNN:9 -- label:9
# test(5944)     DNN:3 -- label:3
# test(5945)     DNN:1 -- label:1
# test(5946)     DNN:3 -- label:3
# test(5947)     DNN:3 -- label:3
# test(5948)     DNN:2 -- label:2
# test(5949)     DNN:7 -- label:7
# test(5950)     DNN:5 -- label:5
# test(5951)     DNN:3 -- label:3
# test(5952)     DNN:5 -- label:5
# test(5953)     DNN:4 -- label:4
# test(5954)     DNN:9 -- label:9
# test(5955)     DNN:4 -- label:4
# test(5956)     DNN:2 -- label:2
# test(5957)     DNN:0 -- label:0
# test(5958)     DNN:8 -- label:8
# test(5959)     DNN:2 -- label:2
# test(5960)     DNN:7 -- label:7
# test(5961)     DNN:8 -- label:8
# test(5962)     DNN:8 -- label:8
# test(5963)     DNN:8 -- label:8
# test(5964)     DNN:1 -- label:1
# test(5965)     DNN:9 -- label:9
# test(5966)     DNN:2 -- label:8
# test(5967)     DNN:3 -- label:3
# test(5968)     DNN:9 -- label:9
# test(5969)     DNN:9 -- label:7
# test(5970)     DNN:2 -- label:2
# test(5971)     DNN:1 -- label:1
# test(5972)     DNN:1 -- label:1
# test(5973)     DNN:8 -- label:8
# test(5974)     DNN:7 -- label:7
# test(5975)     DNN:2 -- label:2
# test(5976)     DNN:5 -- label:5
# test(5977)     DNN:1 -- label:1
# test(5978)     DNN:9 -- label:9
# test(5979)     DNN:2 -- label:2
# test(5980)     DNN:7 -- label:7
# test(5981)     DNN:2 -- label:2
# test(5982)     DNN:8 -- label:8
# test(5983)     DNN:5 -- label:5
# test(5984)     DNN:2 -- label:2
# test(5985)     DNN:5 -- label:5
# test(5986)     DNN:4 -- label:4
# test(5987)     DNN:0 -- label:0
# test(5988)     DNN:1 -- label:1
# test(5989)     DNN:1 -- label:1
# test(5990)     DNN:0 -- label:0
# test(5991)     DNN:7 -- label:7
# test(5992)     DNN:2 -- label:2
# test(5993)     DNN:8 -- label:8
# test(5994)     DNN:2 -- label:2
# test(5995)     DNN:8 -- label:8
# test(5996)     DNN:1 -- label:1
# test(5997)     DNN:2 -- label:2
# test(5998)     DNN:9 -- label:9
# test(5999)     DNN:9 -- label:9
# test(6000)     DNN:3 -- label:3
# test(6001)     DNN:1 -- label:1
# test(6002)     DNN:0 -- label:0
# test(6003)     DNN:3 -- label:5
# test(6004)     DNN:2 -- label:2
# test(6005)     DNN:3 -- label:3
# test(6006)     DNN:1 -- label:1
# test(6007)     DNN:3 -- label:3
# test(6008)     DNN:7 -- label:7
# test(6009)     DNN:2 -- label:2
# test(6010)     DNN:7 -- label:8
# test(6011)     DNN:8 -- label:8
# test(6012)     DNN:4 -- label:4
# test(6013)     DNN:8 -- label:8
# test(6014)     DNN:8 -- label:8
# test(6015)     DNN:8 -- label:8
# test(6016)     DNN:0 -- label:0
# test(6017)     DNN:9 -- label:9
# test(6018)     DNN:0 -- label:0
# test(6019)     DNN:3 -- label:7
# test(6020)     DNN:5 -- label:5
# test(6021)     DNN:9 -- label:9
# test(6022)     DNN:1 -- label:1
# test(6023)     DNN:2 -- label:3
# test(6024)     DNN:3 -- label:7
# test(6025)     DNN:9 -- label:9
# test(6026)     DNN:7 -- label:7
# test(6027)     DNN:2 -- label:2
# test(6028)     DNN:7 -- label:7
# test(6029)     DNN:5 -- label:5
# test(6030)     DNN:3 -- label:3
# test(6031)     DNN:3 -- label:3
# test(6032)     DNN:8 -- label:8
# test(6033)     DNN:1 -- label:1
# test(6034)     DNN:0 -- label:0
# test(6035)     DNN:0 -- label:0
# test(6036)     DNN:2 -- label:2
# test(6037)     DNN:7 -- label:7
# test(6038)     DNN:6 -- label:6
# test(6039)     DNN:3 -- label:3
# test(6040)     DNN:2 -- label:2
# test(6041)     DNN:6 -- label:6
# test(6042)     DNN:5 -- label:5
# test(6043)     DNN:3 -- label:3
# test(6044)     DNN:7 -- label:7
# test(6045)     DNN:3 -- label:3
# test(6046)     DNN:4 -- label:4
# test(6047)     DNN:1 -- label:1
# test(6048)     DNN:4 -- label:4
# test(6049)     DNN:3 -- label:3
# test(6050)     DNN:0 -- label:0
# test(6051)     DNN:8 -- label:8
# test(6052)     DNN:7 -- label:7
# test(6053)     DNN:8 -- label:8
# test(6054)     DNN:3 -- label:3
# test(6055)     DNN:7 -- label:7
# test(6056)     DNN:4 -- label:4
# test(6057)     DNN:0 -- label:0
# test(6058)     DNN:5 -- label:5
# test(6059)     DNN:1 -- label:1
# test(6060)     DNN:3 -- label:3
# test(6061)     DNN:5 -- label:5
# test(6062)     DNN:8 -- label:8
# test(6063)     DNN:0 -- label:0
# test(6064)     DNN:6 -- label:6
# test(6065)     DNN:8 -- label:8
# test(6066)     DNN:6 -- label:6
# test(6067)     DNN:0 -- label:0
# test(6068)     DNN:8 -- label:8
# test(6069)     DNN:7 -- label:7
# test(6070)     DNN:0 -- label:0
# test(6071)     DNN:7 -- label:7
# test(6072)     DNN:5 -- label:5
# test(6073)     DNN:3 -- label:3
# test(6074)     DNN:3 -- label:3
# test(6075)     DNN:7 -- label:7
# test(6076)     DNN:6 -- label:6
# test(6077)     DNN:9 -- label:9
# test(6078)     DNN:9 -- label:9
# test(6079)     DNN:1 -- label:1
# test(6080)     DNN:4 -- label:4
# test(6081)     DNN:3 -- label:3
# test(6082)     DNN:2 -- label:2
# test(6083)     DNN:5 -- label:3
# test(6084)     DNN:3 -- label:3
# test(6085)     DNN:2 -- label:2
# test(6086)     DNN:7 -- label:5
# test(6087)     DNN:4 -- label:4
# test(6088)     DNN:0 -- label:0
# test(6089)     DNN:1 -- label:1
# test(6090)     DNN:0 -- label:0
# test(6091)     DNN:8 -- label:8
# test(6092)     DNN:7 -- label:7
# test(6093)     DNN:5 -- label:8
# test(6094)     DNN:6 -- label:6
# test(6095)     DNN:9 -- label:9
# test(6096)     DNN:8 -- label:8
# test(6097)     DNN:0 -- label:6
# test(6098)     DNN:1 -- label:1
# test(6099)     DNN:8 -- label:8
# test(6100)     DNN:9 -- label:9
# test(6101)     DNN:5 -- label:5
# test(6102)     DNN:4 -- label:4
# test(6103)     DNN:3 -- label:3
# test(6104)     DNN:7 -- label:7
# test(6105)     DNN:4 -- label:4
# test(6106)     DNN:9 -- label:9
# test(6107)     DNN:9 -- label:9
# test(6108)     DNN:5 -- label:5
# test(6109)     DNN:5 -- label:5
# test(6110)     DNN:0 -- label:0
# test(6111)     DNN:1 -- label:1
# test(6112)     DNN:1 -- label:1
# test(6113)     DNN:8 -- label:8
# test(6114)     DNN:9 -- label:9
# test(6115)     DNN:9 -- label:9
# test(6116)     DNN:3 -- label:3
# test(6117)     DNN:0 -- label:0
# test(6118)     DNN:7 -- label:7
# test(6119)     DNN:8 -- label:8
# test(6120)     DNN:7 -- label:7
# test(6121)     DNN:7 -- label:7
# test(6122)     DNN:6 -- label:6
# test(6123)     DNN:9 -- label:5
# test(6124)     DNN:0 -- label:0
# test(6125)     DNN:0 -- label:0
# test(6126)     DNN:0 -- label:0
# test(6127)     DNN:2 -- label:2
# test(6128)     DNN:5 -- label:5
# test(6129)     DNN:6 -- label:6
# test(6130)     DNN:4 -- label:4
# test(6131)     DNN:1 -- label:1
# test(6132)     DNN:2 -- label:8
# test(6133)     DNN:2 -- label:2
# test(6134)     DNN:1 -- label:1
# test(6135)     DNN:3 -- label:8
# test(6136)     DNN:2 -- label:2
# test(6137)     DNN:6 -- label:6
# test(6138)     DNN:0 -- label:9
# test(6139)     DNN:1 -- label:1
# test(6140)     DNN:3 -- label:3
# test(6141)     DNN:4 -- label:4
# test(6142)     DNN:8 -- label:8
# test(6143)     DNN:8 -- label:3
# test(6144)     DNN:4 -- label:4
# test(6145)     DNN:1 -- label:1
# test(6146)     DNN:0 -- label:0
# test(6147)     DNN:5 -- label:5
# test(6148)     DNN:8 -- label:8
# test(6149)     DNN:3 -- label:3
# test(6150)     DNN:0 -- label:0
# test(6151)     DNN:8 -- label:8
# test(6152)     DNN:5 -- label:5
# test(6153)     DNN:3 -- label:3
# test(6154)     DNN:6 -- label:6
# test(6155)     DNN:1 -- label:1
# test(6156)     DNN:4 -- label:4
# test(6157)     DNN:5 -- label:5
# test(6158)     DNN:9 -- label:9
# test(6159)     DNN:0 -- label:0
# test(6160)     DNN:1 -- label:1
# test(6161)     DNN:7 -- label:7
# test(6162)     DNN:8 -- label:1
# test(6163)     DNN:8 -- label:8
# test(6164)     DNN:1 -- label:1
# test(6165)     DNN:9 -- label:9
# test(6166)     DNN:4 -- label:4
# test(6167)     DNN:7 -- label:3
# test(6168)     DNN:3 -- label:3
# test(6169)     DNN:5 -- label:5
# test(6170)     DNN:8 -- label:2
# test(6171)     DNN:8 -- label:3
# test(6172)     DNN:5 -- label:5
# test(6173)     DNN:1 -- label:1
# test(6174)     DNN:4 -- label:4
# test(6175)     DNN:4 -- label:4
# test(6176)     DNN:4 -- label:4
# test(6177)     DNN:0 -- label:0
# test(6178)     DNN:6 -- label:6
# test(6179)     DNN:9 -- label:9
# test(6180)     DNN:1 -- label:1
# test(6181)     DNN:8 -- label:8
# test(6182)     DNN:8 -- label:8
# test(6183)     DNN:0 -- label:0
# test(6184)     DNN:6 -- label:6
# test(6185)     DNN:8 -- label:2
# test(6186)     DNN:4 -- label:4
# test(6187)     DNN:0 -- label:0
# test(6188)     DNN:8 -- label:8
# test(6189)     DNN:8 -- label:8
# test(6190)     DNN:6 -- label:6
# test(6191)     DNN:1 -- label:1
# test(6192)     DNN:5 -- label:5
# test(6193)     DNN:9 -- label:9
# test(6194)     DNN:6 -- label:6
# test(6195)     DNN:4 -- label:8
# test(6196)     DNN:0 -- label:0
# test(6197)     DNN:1 -- label:1
# test(6198)     DNN:9 -- label:9
# test(6199)     DNN:4 -- label:4
# test(6200)     DNN:6 -- label:6
# test(6201)     DNN:3 -- label:3
# test(6202)     DNN:8 -- label:8
# test(6203)     DNN:2 -- label:2
# test(6204)     DNN:3 -- label:3
# test(6205)     DNN:3 -- label:3
# test(6206)     DNN:9 -- label:9
# test(6207)     DNN:6 -- label:6
# test(6208)     DNN:1 -- label:1
# test(6209)     DNN:9 -- label:9
# test(6210)     DNN:6 -- label:6
# test(6211)     DNN:4 -- label:4
# test(6212)     DNN:1 -- label:1
# test(6213)     DNN:2 -- label:2
# test(6214)     DNN:3 -- label:3
# test(6215)     DNN:0 -- label:0
# test(6216)     DNN:0 -- label:0
# test(6217)     DNN:1 -- label:1
# test(6218)     DNN:9 -- label:7
# test(6219)     DNN:3 -- label:3
# test(6220)     DNN:8 -- label:2
# test(6221)     DNN:6 -- label:6
# test(6222)     DNN:0 -- label:0
# test(6223)     DNN:9 -- label:9
# test(6224)     DNN:6 -- label:6
# test(6225)     DNN:6 -- label:2
# test(6226)     DNN:4 -- label:4
# test(6227)     DNN:4 -- label:4
# test(6228)     DNN:2 -- label:2
# test(6229)     DNN:2 -- label:2
# test(6230)     DNN:5 -- label:5
# test(6231)     DNN:3 -- label:3
# test(6232)     DNN:1 -- label:1
# test(6233)     DNN:1 -- label:1
# test(6234)     DNN:2 -- label:2
# test(6235)     DNN:0 -- label:0
# test(6236)     DNN:1 -- label:1
# test(6237)     DNN:8 -- label:8
# test(6238)     DNN:8 -- label:1
# test(6239)     DNN:4 -- label:4
# test(6240)     DNN:7 -- label:7
# test(6241)     DNN:9 -- label:9
# test(6242)     DNN:1 -- label:1
# test(6243)     DNN:4 -- label:4
# test(6244)     DNN:3 -- label:3
# test(6245)     DNN:8 -- label:8
# test(6246)     DNN:6 -- label:6
# test(6247)     DNN:6 -- label:6
# test(6248)     DNN:0 -- label:0
# test(6249)     DNN:5 -- label:5
# test(6250)     DNN:8 -- label:8
# test(6251)     DNN:9 -- label:9
# test(6252)     DNN:0 -- label:0
# test(6253)     DNN:4 -- label:4
# test(6254)     DNN:7 -- label:7
# test(6255)     DNN:1 -- label:1
# test(6256)     DNN:2 -- label:7
# test(6257)     DNN:3 -- label:3
# test(6258)     DNN:6 -- label:6
# test(6259)     DNN:7 -- label:9
# test(6260)     DNN:6 -- label:6
# test(6261)     DNN:1 -- label:1
# test(6262)     DNN:0 -- label:0
# test(6263)     DNN:7 -- label:7
# test(6264)     DNN:1 -- label:1
# test(6265)     DNN:1 -- label:1
# test(6266)     DNN:8 -- label:8
# test(6267)     DNN:5 -- label:5
# test(6268)     DNN:2 -- label:2
# test(6269)     DNN:8 -- label:8
# test(6270)     DNN:8 -- label:8
# test(6271)     DNN:6 -- label:6
# test(6272)     DNN:7 -- label:7
# test(6273)     DNN:6 -- label:6
# test(6274)     DNN:4 -- label:4
# test(6275)     DNN:9 -- label:9
# test(6276)     DNN:1 -- label:1
# test(6277)     DNN:0 -- label:0
# test(6278)     DNN:6 -- label:6
# test(6279)     DNN:8 -- label:8
# test(6280)     DNN:0 -- label:0
# test(6281)     DNN:9 -- label:4
# test(6282)     DNN:3 -- label:3
# test(6283)     DNN:3 -- label:3
# test(6284)     DNN:6 -- label:5
# test(6285)     DNN:6 -- label:6
# test(6286)     DNN:6 -- label:6
# test(6287)     DNN:1 -- label:1
# test(6288)     DNN:8 -- label:1
# test(6289)     DNN:2 -- label:2
# test(6290)     DNN:9 -- label:9
# test(6291)     DNN:6 -- label:6
# test(6292)     DNN:7 -- label:7
# test(6293)     DNN:7 -- label:9
# test(6294)     DNN:4 -- label:4
# test(6295)     DNN:1 -- label:1
# test(6296)     DNN:3 -- label:3
# test(6297)     DNN:3 -- label:3
# test(6298)     DNN:9 -- label:9
# test(6299)     DNN:0 -- label:0
# test(6300)     DNN:4 -- label:4
# test(6301)     DNN:6 -- label:6
# test(6302)     DNN:5 -- label:5
# test(6303)     DNN:2 -- label:2
# test(6304)     DNN:7 -- label:7
# test(6305)     DNN:7 -- label:7
# test(6306)     DNN:6 -- label:6
# test(6307)     DNN:1 -- label:7
# test(6308)     DNN:1 -- label:1
# test(6309)     DNN:4 -- label:4
# test(6310)     DNN:1 -- label:1
# test(6311)     DNN:4 -- label:4
# test(6312)     DNN:5 -- label:5
# test(6313)     DNN:6 -- label:6
# test(6314)     DNN:9 -- label:9
# test(6315)     DNN:0 -- label:0
# test(6316)     DNN:0 -- label:0
# test(6317)     DNN:6 -- label:6
# test(6318)     DNN:1 -- label:1
# test(6319)     DNN:6 -- label:6
# test(6320)     DNN:7 -- label:7
# test(6321)     DNN:0 -- label:0
# test(6322)     DNN:9 -- label:9
# test(6323)     DNN:9 -- label:9
# test(6324)     DNN:4 -- label:9
# test(6325)     DNN:6 -- label:6
# test(6326)     DNN:1 -- label:1
# test(6327)     DNN:1 -- label:1
# test(6328)     DNN:9 -- label:9
# test(6329)     DNN:7 -- label:7
# test(6330)     DNN:2 -- label:2
# test(6331)     DNN:8 -- label:8
# test(6332)     DNN:4 -- label:4
# test(6333)     DNN:8 -- label:8
# test(6334)     DNN:4 -- label:4
# test(6335)     DNN:6 -- label:2
# test(6336)     DNN:7 -- label:7
# test(6337)     DNN:7 -- label:7
# test(6338)     DNN:3 -- label:3
# test(6339)     DNN:8 -- label:8
# test(6340)     DNN:0 -- label:0
# test(6341)     DNN:1 -- label:1
# test(6342)     DNN:4 -- label:4
# test(6343)     DNN:4 -- label:4
# test(6344)     DNN:1 -- label:1
# test(6345)     DNN:8 -- label:8
# test(6346)     DNN:5 -- label:5
# test(6347)     DNN:8 -- label:2
# test(6348)     DNN:6 -- label:6
# test(6349)     DNN:2 -- label:1
# test(6350)     DNN:3 -- label:3
# test(6351)     DNN:6 -- label:4
# test(6352)     DNN:9 -- label:9
# test(6353)     DNN:0 -- label:0
# test(6354)     DNN:6 -- label:6
# test(6355)     DNN:8 -- label:8
# test(6356)     DNN:8 -- label:8
# test(6357)     DNN:4 -- label:9
# test(6358)     DNN:5 -- label:5
# test(6359)     DNN:0 -- label:0
# test(6360)     DNN:5 -- label:5
# test(6361)     DNN:3 -- label:3
# test(6362)     DNN:0 -- label:0
# test(6363)     DNN:2 -- label:2
# test(6364)     DNN:1 -- label:1
# test(6365)     DNN:2 -- label:2
# test(6366)     DNN:6 -- label:6
# test(6367)     DNN:5 -- label:9
# test(6368)     DNN:2 -- label:2
# test(6369)     DNN:3 -- label:3
# test(6370)     DNN:6 -- label:6
# test(6371)     DNN:0 -- label:0
# test(6372)     DNN:0 -- label:0
# test(6373)     DNN:7 -- label:7
# test(6374)     DNN:5 -- label:5
# test(6375)     DNN:1 -- label:1
# test(6376)     DNN:4 -- label:4
# test(6377)     DNN:0 -- label:0
# test(6378)     DNN:1 -- label:1
# test(6379)     DNN:1 -- label:1
# test(6380)     DNN:2 -- label:2
# test(6381)     DNN:7 -- label:7
# test(6382)     DNN:4 -- label:4
# test(6383)     DNN:7 -- label:7
# test(6384)     DNN:8 -- label:8
# test(6385)     DNN:6 -- label:6
# test(6386)     DNN:4 -- label:4
# test(6387)     DNN:7 -- label:7
# test(6388)     DNN:3 -- label:3
# test(6389)     DNN:3 -- label:3
# test(6390)     DNN:7 -- label:7
# test(6391)     DNN:1 -- label:1
# test(6392)     DNN:4 -- label:4
# test(6393)     DNN:7 -- label:7
# test(6394)     DNN:4 -- label:9
# test(6395)     DNN:9 -- label:9
# test(6396)     DNN:9 -- label:9
# test(6397)     DNN:2 -- label:2
# test(6398)     DNN:9 -- label:9
# test(6399)     DNN:1 -- label:1
# test(6400)     DNN:8 -- label:8
# test(6401)     DNN:9 -- label:9
# test(6402)     DNN:6 -- label:6
# test(6403)     DNN:9 -- label:9
# test(6404)     DNN:9 -- label:9
# test(6405)     DNN:1 -- label:1
# test(6406)     DNN:1 -- label:1
# test(6407)     DNN:8 -- label:8
# test(6408)     DNN:5 -- label:5
# test(6409)     DNN:0 -- label:0
# test(6410)     DNN:0 -- label:0
# test(6411)     DNN:3 -- label:3
# test(6412)     DNN:9 -- label:9
# test(6413)     DNN:7 -- label:7
# test(6414)     DNN:0 -- label:2
# test(6415)     DNN:9 -- label:9
# test(6416)     DNN:6 -- label:6
# test(6417)     DNN:9 -- label:9
# test(6418)     DNN:0 -- label:0
# test(6419)     DNN:9 -- label:9
# test(6420)     DNN:1 -- label:1
# test(6421)     DNN:1 -- label:1
# test(6422)     DNN:1 -- label:1
# test(6423)     DNN:9 -- label:9
# test(6424)     DNN:9 -- label:9
# test(6425)     DNN:3 -- label:3
# test(6426)     DNN:2 -- label:2
# test(6427)     DNN:4 -- label:4
# test(6428)     DNN:7 -- label:7
# test(6429)     DNN:9 -- label:9
# test(6430)     DNN:9 -- label:9
# test(6431)     DNN:6 -- label:6
# test(6432)     DNN:7 -- label:7
# test(6433)     DNN:2 -- label:2
# test(6434)     DNN:2 -- label:2
# test(6435)     DNN:9 -- label:9
# test(6436)     DNN:0 -- label:0
# test(6437)     DNN:0 -- label:0
# test(6438)     DNN:7 -- label:7
# test(6439)     DNN:7 -- label:7
# test(6440)     DNN:6 -- label:6
# test(6441)     DNN:9 -- label:9
# test(6442)     DNN:3 -- label:3
# test(6443)     DNN:8 -- label:8
# test(6444)     DNN:7 -- label:7
# test(6445)     DNN:9 -- label:9
# test(6446)     DNN:9 -- label:9
# test(6447)     DNN:3 -- label:3
# test(6448)     DNN:0 -- label:0
# test(6449)     DNN:7 -- label:7
# test(6450)     DNN:1 -- label:1
# test(6451)     DNN:2 -- label:3
# test(6452)     DNN:7 -- label:7
# test(6453)     DNN:3 -- label:3
# test(6454)     DNN:5 -- label:5
# test(6455)     DNN:2 -- label:2
# test(6456)     DNN:4 -- label:4
# test(6457)     DNN:8 -- label:8
# test(6458)     DNN:9 -- label:9
# test(6459)     DNN:5 -- label:5
# test(6460)     DNN:7 -- label:7
# test(6461)     DNN:6 -- label:6
# test(6462)     DNN:3 -- label:5
# test(6463)     DNN:6 -- label:6
# test(6464)     DNN:3 -- label:3
# test(6465)     DNN:1 -- label:1
# test(6466)     DNN:7 -- label:7
# test(6467)     DNN:0 -- label:0
# test(6468)     DNN:2 -- label:2
# test(6469)     DNN:7 -- label:7
# test(6470)     DNN:0 -- label:0
# test(6471)     DNN:2 -- label:2
# test(6472)     DNN:2 -- label:2
# test(6473)     DNN:2 -- label:2
# test(6474)     DNN:2 -- label:2
# test(6475)     DNN:0 -- label:0
# test(6476)     DNN:3 -- label:3
# test(6477)     DNN:8 -- label:8
# test(6478)     DNN:7 -- label:7
# test(6479)     DNN:1 -- label:1
# test(6480)     DNN:9 -- label:9
# test(6481)     DNN:5 -- label:5
# test(6482)     DNN:7 -- label:7
# test(6483)     DNN:8 -- label:8
# test(6484)     DNN:3 -- label:3
# test(6485)     DNN:7 -- label:7
# test(6486)     DNN:1 -- label:1
# test(6487)     DNN:9 -- label:9
# test(6488)     DNN:2 -- label:2
# test(6489)     DNN:2 -- label:2
# test(6490)     DNN:6 -- label:6
# test(6491)     DNN:4 -- label:4
# test(6492)     DNN:7 -- label:7
# test(6493)     DNN:2 -- label:2
# test(6494)     DNN:2 -- label:7
# test(6495)     DNN:3 -- label:9
# test(6496)     DNN:0 -- label:0
# test(6497)     DNN:9 -- label:9
# test(6498)     DNN:8 -- label:8
# test(6499)     DNN:6 -- label:6
# ...
# test(9501)     DNN:3 -- label:3
# test(9502)     DNN:7 -- label:7
# test(9503)     DNN:3 -- label:3
# test(9504)     DNN:7 -- label:7
# test(9505)     DNN:8 -- label:8
# test(9506)     DNN:6 -- label:6
# test(9507)     DNN:9 -- label:9
# test(9508)     DNN:9 -- label:9
# test(9509)     DNN:5 -- label:5
# test(9510)     DNN:7 -- label:7
# test(9511)     DNN:2 -- label:2
# test(9512)     DNN:5 -- label:5
# test(9513)     DNN:8 -- label:8
# test(9514)     DNN:1 -- label:1
# test(9515)     DNN:4 -- label:4
# test(9516)     DNN:5 -- label:5
# test(9517)     DNN:6 -- label:6
# test(9518)     DNN:8 -- label:8
# test(9519)     DNN:1 -- label:1
# test(9520)     DNN:8 -- label:8
# test(9521)     DNN:4 -- label:4
# test(9522)     DNN:1 -- label:1
# test(9523)     DNN:7 -- label:7
# test(9524)     DNN:5 -- label:5
# test(9525)     DNN:9 -- label:9
# test(9526)     DNN:3 -- label:3
# test(9527)     DNN:5 -- label:3
# test(9528)     DNN:5 -- label:5
# test(9529)     DNN:0 -- label:0
# test(9530)     DNN:7 -- label:7
# test(9531)     DNN:3 -- label:3
# test(9532)     DNN:7 -- label:7
# test(9533)     DNN:4 -- label:4
# test(9534)     DNN:6 -- label:6
# test(9535)     DNN:6 -- label:6
# test(9536)     DNN:8 -- label:9
# test(9537)     DNN:6 -- label:6
# test(9538)     DNN:6 -- label:0
# test(9539)     DNN:3 -- label:3
# test(9540)     DNN:9 -- label:9
# test(9541)     DNN:4 -- label:4
# test(9542)     DNN:8 -- label:8
# test(9543)     DNN:4 -- label:4
# test(9544)     DNN:1 -- label:1
# test(9545)     DNN:7 -- label:7
# test(9546)     DNN:7 -- label:7
# test(9547)     DNN:2 -- label:2
# test(9548)     DNN:1 -- label:1
# test(9549)     DNN:7 -- label:7
# test(9550)     DNN:1 -- label:1
# test(9551)     DNN:7 -- label:7
# test(9552)     DNN:4 -- label:4
# test(9553)     DNN:2 -- label:2
# test(9554)     DNN:9 -- label:9
# test(9555)     DNN:4 -- label:4
# test(9556)     DNN:2 -- label:2
# test(9557)     DNN:3 -- label:3
# test(9558)     DNN:6 -- label:6
# test(9559)     DNN:6 -- label:6
# test(9560)     DNN:1 -- label:1
# test(9561)     DNN:7 -- label:7
# test(9562)     DNN:4 -- label:4
# test(9563)     DNN:4 -- label:4
# test(9564)     DNN:4 -- label:4
# test(9565)     DNN:2 -- label:2
# test(9566)     DNN:0 -- label:0
# test(9567)     DNN:8 -- label:8
# test(9568)     DNN:6 -- label:6
# test(9569)     DNN:4 -- label:4
# test(9570)     DNN:0 -- label:0
# test(9571)     DNN:9 -- label:9
# test(9572)     DNN:0 -- label:0
# test(9573)     DNN:3 -- label:3
# test(9574)     DNN:5 -- label:3
# test(9575)     DNN:4 -- label:4
# test(9576)     DNN:4 -- label:4
# test(9577)     DNN:5 -- label:5
# test(9578)     DNN:3 -- label:3
# test(9579)     DNN:6 -- label:6
# test(9580)     DNN:0 -- label:0
# test(9581)     DNN:2 -- label:2
# test(9582)     DNN:5 -- label:5
# test(9583)     DNN:4 -- label:4
# test(9584)     DNN:6 -- label:6
# test(9585)     DNN:1 -- label:1
# test(9586)     DNN:3 -- label:2
# test(9587)     DNN:2 -- label:2
# test(9588)     DNN:0 -- label:0
# test(9589)     DNN:4 -- label:4
# test(9590)     DNN:5 -- label:5
# test(9591)     DNN:1 -- label:1
# test(9592)     DNN:7 -- label:7
# test(9593)     DNN:0 -- label:0
# test(9594)     DNN:2 -- label:2
# test(9595)     DNN:8 -- label:3
# test(9596)     DNN:4 -- label:4
# test(9597)     DNN:8 -- label:3
# test(9598)     DNN:8 -- label:8
# test(9599)     DNN:3 -- label:3
# test(9600)     DNN:3 -- label:3
# test(9601)     DNN:5 -- label:5
# test(9602)     DNN:7 -- label:7
# test(9603)     DNN:0 -- label:0
# test(9604)     DNN:6 -- label:6
# test(9605)     DNN:6 -- label:6
# test(9606)     DNN:4 -- label:9
# test(9607)     DNN:3 -- label:3
# test(9608)     DNN:8 -- label:8
# test(9609)     DNN:9 -- label:9
# test(9610)     DNN:1 -- label:1
# test(9611)     DNN:5 -- label:5
# test(9612)     DNN:3 -- label:3
# test(9613)     DNN:3 -- label:3
# test(9614)     DNN:0 -- label:0
# test(9615)     DNN:3 -- label:3
# test(9616)     DNN:1 -- label:1
# test(9617)     DNN:1 -- label:1
# test(9618)     DNN:3 -- label:3
# test(9619)     DNN:3 -- label:3
# test(9620)     DNN:1 -- label:1
# test(9621)     DNN:2 -- label:2
# test(9622)     DNN:4 -- label:4
# test(9623)     DNN:6 -- label:6
# test(9624)     DNN:6 -- label:6
# test(9625)     DNN:8 -- label:8
# test(9626)     DNN:1 -- label:1
# test(9627)     DNN:6 -- label:7
# test(9628)     DNN:8 -- label:8
# test(9629)     DNN:7 -- label:5
# test(9630)     DNN:0 -- label:0
# test(9631)     DNN:1 -- label:1
# test(9632)     DNN:9 -- label:3
# test(9633)     DNN:9 -- label:9
# test(9634)     DNN:1 -- label:1
# test(9635)     DNN:9 -- label:9
# test(9636)     DNN:5 -- label:5
# test(9637)     DNN:4 -- label:6
# test(9638)     DNN:1 -- label:1
# test(9639)     DNN:6 -- label:6
# test(9640)     DNN:5 -- label:5
# test(9641)     DNN:3 -- label:3
# test(9642)     DNN:0 -- label:9
# test(9643)     DNN:7 -- label:7
# test(9644)     DNN:3 -- label:3
# test(9645)     DNN:6 -- label:6
# test(9646)     DNN:2 -- label:2
# test(9647)     DNN:5 -- label:9
# test(9648)     DNN:5 -- label:5
# test(9649)     DNN:5 -- label:5
# test(9650)     DNN:7 -- label:7
# test(9651)     DNN:8 -- label:8
# test(9652)     DNN:6 -- label:6
# test(9653)     DNN:4 -- label:4
# test(9654)     DNN:6 -- label:6
# test(9655)     DNN:7 -- label:7
# test(9656)     DNN:5 -- label:5
# test(9657)     DNN:2 -- label:2
# test(9658)     DNN:5 -- label:9
# test(9659)     DNN:9 -- label:4
# test(9660)     DNN:4 -- label:4
# test(9661)     DNN:6 -- label:6
# test(9662)     DNN:3 -- label:3
# test(9663)     DNN:2 -- label:2
# test(9664)     DNN:1 -- label:1
# test(9665)     DNN:8 -- label:8
# test(9666)     DNN:5 -- label:5
# test(9667)     DNN:1 -- label:1
# test(9668)     DNN:1 -- label:1
# test(9669)     DNN:4 -- label:9
# test(9670)     DNN:3 -- label:3
# test(9671)     DNN:9 -- label:9
# test(9672)     DNN:6 -- label:6
# test(9673)     DNN:4 -- label:9
# test(9674)     DNN:7 -- label:7
# test(9675)     DNN:9 -- label:9
# test(9676)     DNN:8 -- label:8
# test(9677)     DNN:3 -- label:3
# test(9678)     DNN:5 -- label:5
# test(9679)     DNN:9 -- label:9
# test(9680)     DNN:3 -- label:3
# test(9681)     DNN:6 -- label:4
# test(9682)     DNN:2 -- label:2
# test(9683)     DNN:3 -- label:3
# test(9684)     DNN:2 -- label:2
# test(9685)     DNN:2 -- label:2
# test(9686)     DNN:2 -- label:2
# test(9687)     DNN:9 -- label:9
# test(9688)     DNN:5 -- label:5
# test(9689)     DNN:6 -- label:6
# test(9690)     DNN:0 -- label:0
# test(9691)     DNN:1 -- label:1
# test(9692)     DNN:0 -- label:0
# test(9693)     DNN:8 -- label:8
# test(9694)     DNN:1 -- label:1
# test(9695)     DNN:5 -- label:5
# test(9696)     DNN:4 -- label:4
# test(9697)     DNN:7 -- label:2
# test(9698)     DNN:5 -- label:5
# test(9699)     DNN:7 -- label:7
# test(9700)     DNN:1 -- label:1
# test(9701)     DNN:0 -- label:0
# test(9702)     DNN:3 -- label:3
# test(9703)     DNN:0 -- label:0
# test(9704)     DNN:4 -- label:4
# test(9705)     DNN:5 -- label:5
# test(9706)     DNN:5 -- label:5
# test(9707)     DNN:2 -- label:2
# test(9708)     DNN:6 -- label:6
# test(9709)     DNN:3 -- label:3
# test(9710)     DNN:3 -- label:3
# test(9711)     DNN:2 -- label:2
# test(9712)     DNN:9 -- label:9
# test(9713)     DNN:5 -- label:5
# test(9714)     DNN:8 -- label:8
# test(9715)     DNN:0 -- label:0
# test(9716)     DNN:3 -- label:3
# test(9717)     DNN:1 -- label:1
# test(9718)     DNN:1 -- label:1
# test(9719)     DNN:4 -- label:4
# test(9720)     DNN:3 -- label:3
# test(9721)     DNN:3 -- label:3
# test(9722)     DNN:2 -- label:2
# test(9723)     DNN:3 -- label:8
# test(9724)     DNN:8 -- label:8
# test(9725)     DNN:0 -- label:0
# test(9726)     DNN:0 -- label:0
# test(9727)     DNN:4 -- label:4
# test(9728)     DNN:3 -- label:3
# test(9729)     DNN:6 -- label:6
# test(9730)     DNN:8 -- label:2
# test(9731)     DNN:6 -- label:6
# test(9732)     DNN:3 -- label:3
# test(9733)     DNN:9 -- label:9
# test(9734)     DNN:9 -- label:9
# test(9735)     DNN:3 -- label:3
# test(9736)     DNN:1 -- label:1
# test(9737)     DNN:7 -- label:7
# test(9738)     DNN:6 -- label:6
# test(9739)     DNN:5 -- label:5
# test(9740)     DNN:7 -- label:7
# test(9741)     DNN:1 -- label:1
# test(9742)     DNN:5 -- label:5
# test(9743)     DNN:1 -- label:1
# test(9744)     DNN:4 -- label:4
# test(9745)     DNN:0 -- label:0
# test(9746)     DNN:4 -- label:4
# test(9747)     DNN:1 -- label:1
# test(9748)     DNN:7 -- label:7
# test(9749)     DNN:1 -- label:1
# test(9750)     DNN:8 -- label:5
# test(9751)     DNN:1 -- label:1
# test(9752)     DNN:3 -- label:3
# test(9753)     DNN:1 -- label:1
# test(9754)     DNN:9 -- label:9
# test(9755)     DNN:6 -- label:6
# test(9756)     DNN:7 -- label:7
# test(9757)     DNN:2 -- label:8
# test(9758)     DNN:0 -- label:0
# test(9759)     DNN:8 -- label:8
# test(9760)     DNN:6 -- label:6
# test(9761)     DNN:3 -- label:7
# test(9762)     DNN:5 -- label:5
# test(9763)     DNN:9 -- label:9
# test(9764)     DNN:4 -- label:4
# test(9765)     DNN:6 -- label:6
# test(9766)     DNN:2 -- label:2
# test(9767)     DNN:9 -- label:9
# test(9768)     DNN:0 -- label:0
# test(9769)     DNN:5 -- label:5
# test(9770)     DNN:5 -- label:5
# test(9771)     DNN:0 -- label:0
# test(9772)     DNN:2 -- label:2
# test(9773)     DNN:1 -- label:1
# test(9774)     DNN:4 -- label:4
# test(9775)     DNN:9 -- label:9
# test(9776)     DNN:4 -- label:6
# test(9777)     DNN:0 -- label:0
# test(9778)     DNN:0 -- label:0
# test(9779)     DNN:5 -- label:5
# test(9780)     DNN:2 -- label:2
# test(9781)     DNN:1 -- label:1
# test(9782)     DNN:7 -- label:7
# test(9783)     DNN:9 -- label:9
# test(9784)     DNN:7 -- label:7
# test(9785)     DNN:8 -- label:8
# test(9786)     DNN:7 -- label:7
# test(9787)     DNN:8 -- label:8
# test(9788)     DNN:7 -- label:7
# test(9789)     DNN:2 -- label:2
# test(9790)     DNN:1 -- label:1
# test(9791)     DNN:8 -- label:8
# test(9792)     DNN:3 -- label:3
# test(9793)     DNN:1 -- label:1
# test(9794)     DNN:7 -- label:9
# test(9795)     DNN:8 -- label:8
# test(9796)     DNN:6 -- label:6
# test(9797)     DNN:0 -- label:0
# test(9798)     DNN:8 -- label:8
# test(9799)     DNN:5 -- label:5
# test(9800)     DNN:5 -- label:5
# test(9801)     DNN:0 -- label:0
# test(9802)     DNN:3 -- label:3
# test(9803)     DNN:5 -- label:5
# test(9804)     DNN:0 -- label:0
# test(9805)     DNN:1 -- label:1
# test(9806)     DNN:9 -- label:9
# test(9807)     DNN:1 -- label:1
# test(9808)     DNN:2 -- label:2
# test(9809)     DNN:4 -- label:4
# test(9810)     DNN:0 -- label:6
# test(9811)     DNN:0 -- label:0
# test(9812)     DNN:1 -- label:1
# test(9813)     DNN:0 -- label:0
# test(9814)     DNN:3 -- label:3
# test(9815)     DNN:9 -- label:9
# test(9816)     DNN:0 -- label:0
# test(9817)     DNN:3 -- label:3
# test(9818)     DNN:0 -- label:0
# test(9819)     DNN:6 -- label:6
# test(9820)     DNN:7 -- label:7
# test(9821)     DNN:2 -- label:2
# test(9822)     DNN:6 -- label:6
# test(9823)     DNN:8 -- label:8
# test(9824)     DNN:8 -- label:3
# test(9825)     DNN:4 -- label:4
# test(9826)     DNN:5 -- label:5
# test(9827)     DNN:0 -- label:0
# test(9828)     DNN:7 -- label:7
# test(9829)     DNN:1 -- label:1
# test(9830)     DNN:8 -- label:8
# test(9831)     DNN:2 -- label:2
# test(9832)     DNN:0 -- label:0
# test(9833)     DNN:4 -- label:4
# test(9834)     DNN:3 -- label:8
# test(9835)     DNN:0 -- label:0
# test(9836)     DNN:1 -- label:1
# test(9837)     DNN:8 -- label:8
# test(9838)     DNN:0 -- label:6
# test(9839)     DNN:9 -- label:9
# test(9840)     DNN:0 -- label:0
# test(9841)     DNN:9 -- label:9
# test(9842)     DNN:7 -- label:7
# test(9843)     DNN:6 -- label:6
# test(9844)     DNN:7 -- label:7
# test(9845)     DNN:7 -- label:7
# test(9846)     DNN:1 -- label:1
# test(9847)     DNN:5 -- label:5
# test(9848)     DNN:3 -- label:5
# test(9849)     DNN:1 -- label:1
# test(9850)     DNN:8 -- label:8
# test(9851)     DNN:3 -- label:3
# test(9852)     DNN:5 -- label:5
# test(9853)     DNN:9 -- label:9
# test(9854)     DNN:8 -- label:8
# test(9855)     DNN:1 -- label:1
# test(9856)     DNN:0 -- label:0
# test(9857)     DNN:1 -- label:1
# test(9858)     DNN:1 -- label:1
# test(9859)     DNN:8 -- label:8
# test(9860)     DNN:0 -- label:0
# test(9861)     DNN:9 -- label:9
# test(9862)     DNN:2 -- label:2
# test(9863)     DNN:2 -- label:2
# test(9864)     DNN:0 -- label:0
# test(9865)     DNN:0 -- label:0
# test(9866)     DNN:4 -- label:4
# test(9867)     DNN:6 -- label:6
# test(9868)     DNN:1 -- label:1
# test(9869)     DNN:1 -- label:1
# test(9870)     DNN:9 -- label:9
# test(9871)     DNN:2 -- label:2
# test(9872)     DNN:3 -- label:3
# test(9873)     DNN:0 -- label:0
# test(9874)     DNN:7 -- label:7
# test(9875)     DNN:4 -- label:4
# test(9876)     DNN:0 -- label:0
# test(9877)     DNN:5 -- label:5
# test(9878)     DNN:3 -- label:3
# test(9879)     DNN:9 -- label:9
# test(9880)     DNN:7 -- label:7
# test(9881)     DNN:1 -- label:1
# test(9882)     DNN:0 -- label:0
# test(9883)     DNN:9 -- label:9
# test(9884)     DNN:1 -- label:1
# test(9885)     DNN:1 -- label:1
# test(9886)     DNN:3 -- label:3
# test(9887)     DNN:5 -- label:5
# test(9888)     DNN:9 -- label:9
# test(9889)     DNN:0 -- label:0
# test(9890)     DNN:6 -- label:6
# test(9891)     DNN:8 -- label:8
# test(9892)     DNN:8 -- label:8
# test(9893)     DNN:5 -- label:5
# test(9894)     DNN:9 -- label:9
# test(9895)     DNN:6 -- label:6
# test(9896)     DNN:5 -- label:5
# test(9897)     DNN:4 -- label:9
# test(9898)     DNN:7 -- label:7
# test(9899)     DNN:6 -- label:6
# test(9900)     DNN:8 -- label:8
# test(9901)     DNN:5 -- label:5
# test(9902)     DNN:2 -- label:2
# test(9903)     DNN:7 -- label:7
# test(9904)     DNN:5 -- label:5
# test(9905)     DNN:3 -- label:3
# test(9906)     DNN:2 -- label:2
# test(9907)     DNN:9 -- label:9
# test(9908)     DNN:2 -- label:2
# test(9909)     DNN:0 -- label:0
# test(9910)     DNN:6 -- label:6
# test(9911)     DNN:8 -- label:8
# test(9912)     DNN:2 -- label:2
# test(9913)     DNN:8 -- label:8
# test(9914)     DNN:4 -- label:4
# test(9915)     DNN:4 -- label:4
# test(9916)     DNN:0 -- label:0
# test(9917)     DNN:7 -- label:7
# test(9918)     DNN:9 -- label:9
# test(9919)     DNN:6 -- label:6
# test(9920)     DNN:7 -- label:7
# test(9921)     DNN:8 -- label:8
# test(9922)     DNN:1 -- label:1
# test(9923)     DNN:0 -- label:0
# test(9924)     DNN:5 -- label:5
# test(9925)     DNN:9 -- label:9
# test(9926)     DNN:0 -- label:0
# test(9927)     DNN:3 -- label:3
# test(9928)     DNN:7 -- label:7
# test(9929)     DNN:4 -- label:4
# test(9930)     DNN:7 -- label:7
# test(9931)     DNN:3 -- label:3
# test(9932)     DNN:7 -- label:7
# test(9933)     DNN:3 -- label:3
# test(9934)     DNN:1 -- label:1
# test(9935)     DNN:9 -- label:9
# test(9936)     DNN:4 -- label:4
# test(9937)     DNN:8 -- label:8
# test(9938)     DNN:9 -- label:9
# test(9939)     DNN:5 -- label:5
# test(9940)     DNN:1 -- label:1
# test(9941)     DNN:1 -- label:1
# test(9942)     DNN:0 -- label:0
# test(9943)     DNN:1 -- label:1
# test(9944)     DNN:0 -- label:0
# test(9945)     DNN:1 -- label:1
# test(9946)     DNN:5 -- label:5
# test(9947)     DNN:8 -- label:5
# test(9948)     DNN:7 -- label:7
# test(9949)     DNN:0 -- label:0
# test(9950)     DNN:1 -- label:1
# test(9951)     DNN:4 -- label:4
# test(9952)     DNN:2 -- label:2
# test(9953)     DNN:4 -- label:4
# test(9954)     DNN:7 -- label:7
# test(9955)     DNN:7 -- label:7
# test(9956)     DNN:8 -- label:8
# test(9957)     DNN:4 -- label:4
# test(9958)     DNN:6 -- label:4
# test(9959)     DNN:2 -- label:2
# test(9960)     DNN:9 -- label:9
# test(9961)     DNN:1 -- label:1
# test(9962)     DNN:1 -- label:1
# test(9963)     DNN:7 -- label:5
# test(9964)     DNN:1 -- label:1
# test(9965)     DNN:6 -- label:2
# test(9966)     DNN:1 -- label:1
# test(9967)     DNN:7 -- label:7
# test(9968)     DNN:3 -- label:3
# test(9969)     DNN:3 -- label:3
# test(9970)     DNN:1 -- label:1
# test(9971)     DNN:1 -- label:1
# test(9972)     DNN:2 -- label:2
# test(9973)     DNN:3 -- label:3
# test(9974)     DNN:2 -- label:2
# test(9975)     DNN:6 -- label:6
# test(9976)     DNN:2 -- label:2
# test(9977)     DNN:1 -- label:1
# test(9978)     DNN:7 -- label:7
# test(9979)     DNN:1 -- label:1
# test(9980)     DNN:5 -- label:5
# test(9981)     DNN:5 -- label:6
# test(9982)     DNN:7 -- label:7
# test(9983)     DNN:9 -- label:9
# test(9984)     DNN:4 -- label:4
# test(9985)     DNN:4 -- label:4
# test(9986)     DNN:8 -- label:8
# test(9987)     DNN:3 -- label:3
# test(9988)     DNN:2 -- label:2
# test(9989)     DNN:3 -- label:3
# test(9990)     DNN:8 -- label:8
# test(9991)     DNN:6 -- label:6
# test(9992)     DNN:8 -- label:8
# test(9993)     DNN:3 -- label:3
# test(9994)     DNN:4 -- label:4
# test(9995)     DNN:6 -- label:6
# test(9996)     DNN:8 -- label:8
# test(9997)     DNN:5 -- label:3
# test(9998)     DNN:8 -- label:8
# test(9999)     DNN:5 -- label:5
# accuracy： 0.9198
